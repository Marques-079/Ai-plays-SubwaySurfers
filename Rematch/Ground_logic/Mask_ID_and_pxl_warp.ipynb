# %%
#Accounts for warp depending on curr lane the pxl head search is offset by n1-4 degrees from vertical

# %%
#!/usr/bin/env python3
# Ultra-fast, batched pipeline with threaded I/O + per-frame timing & counts
# Renders ALL masks + triangles coloured by the mask sampled N px along a ray
# + Scout lines (render only)
# + Starburst lines from each triangle tip to Jake's lane point
# + Lane-bearing selector for Jake's triangle
# + Lane-aware angled sampling for mask lookup with per-ray degree labels

import os, glob, sys, time, math
import cv2, torch, numpy as np
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from ultralytics import YOLO

# =======================
# Config
# =======================
home       = os.path.expanduser("~")
weights    = f"{home}/models/jakes-loped/jakes-finder-mk1/1/weights.pt"
frames_dir = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "frames"

# SAVE HERE
out_dir    = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "out_overlays6"
out_dir.mkdir(parents=True, exist_ok=True)

RAIL_ID    = 9
IMG_SIZE   = 512
CONF, IOU  = 0.30, 0.45
MAX_DET    = 30

# Color/region filter
TARGET_COLORS_RGB  = [(119,104,67), (81,42,45)]
TOLERANCE          = 20.0
MIN_REGION_SIZE    = 30
MIN_REGION_HEIGHT  = 150

# Heat/triangle
HEAT_BLUR_KSIZE     = 51
RED_SCORE_THRESH    = 220
EXCLUDE_TOP_FRAC    = 0.40
EXCLUDE_BOTTOM_FRAC = 0.15
MIN_DARK_RED_AREA   = 1200
MIN_DARK_FRACTION   = 0.15
TRI_SIZE_PX         = 18

# Sampling ray length (pixels in frame space)
SAMPLE_UP_PX        = 65

# ===== BEND PARAMETERS (degrees; + = lean LEFT, - = lean RIGHT)
# If JAKE_POINT = LANE_LEFT, triangles to the RIGHT bend LEFT by N1
BEND_LEFT_STATE_RIGHT_DEG  = -20.0  # N1
# If JAKE_POINT = LANE_MID, triangles RIGHT of JakeTri bend LEFT by N2
BEND_MID_STATE_RIGHT_DEG   = -20.0  # N2
# If JAKE_POINT = LANE_MID, triangles LEFT of JakeTri bend RIGHT by N3
BEND_MID_STATE_LEFT_DEG    = +20.0  # N3
# If JAKE_POINT = LANE_RIGHT, triangles to the LEFT bend RIGHT by N4
BEND_RIGHT_STATE_LEFT_DEG  = +20.0  # N4

# Colours (BGR)
COLOR_GREEN  = (0, 255, 0)
COLOR_PINK   = (203, 192, 255)
COLOR_YELLOW = (0, 255, 255)
COLOR_RED    = (0, 0, 255)
COLOR_WHITE  = (255, 255, 255)
COLOR_CYAN   = (255, 255, 0)
COLOR_BLACK  = (0, 0, 0)

# Runtime
BATCH               = 1
THREADS_IO          = max(2, (os.cpu_count() or 4) // 2)
SHOW_FIRST_N        = None   # None → all frames
RENDER_FIRST_N      = 300    # render overlays for first N frames only

# =======================
# Jake lane points
# =======================
LANE_LEFT   = (300, 1340)
LANE_MID    = (490, 1340)
LANE_RIGHT  = (680, 1340)
JAKE_POINT  = LANE_MID  # pick one: LANE_LEFT / LANE_MID / LANE_RIGHT

# Lane target bearings (degrees from vertical; left=positive, right=negative)
LANE_TARGET_DEG = {
    "left":  -10.7,
    "mid":   +1.5,
    "right": +15.0,
}

def lane_name_from_point(p):
    if p == LANE_LEFT:  return "left"
    if p == LANE_MID:   return "mid"
    if p == LANE_RIGHT: return "right"
    return "mid"

# =======================
# System/Backends
# =======================
cv2.setUseOptimized(True)
try: cv2.setNumThreads(max(1, (os.cpu_count() or 1) - 1))
except Exception: pass

if torch.cuda.is_available():
    device, half = 0, True
    torch.backends.cudnn.benchmark = True
    try: torch.set_float32_matmul_precision('high')
    except Exception: pass
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device, half = "mps", False
else:
    device, half = "cpu", False

# =======================
# Model
# =======================
model = YOLO(weights)
try: model.fuse()
except Exception: pass

# Warmup
_dummy = np.zeros((IMG_SIZE, IMG_SIZE, 3), np.uint8)
_ = model.predict(_dummy, task="segment", imgsz=IMG_SIZE, device=device,
                  conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET)

# =======================
# Precomputed
# =======================
TARGETS_BGR_F32 = np.array([(r,g,b)[::-1] for (r,g,b) in TARGET_COLORS_RGB], dtype=np.float32)
TOL2            = TOLERANCE * TOLERANCE

CLASS_COLOURS = {
    0:(255,255,0),1:(192,192,192),2:(0,128,255),3:(0,255,0),
    4:(255,0,255),5:(0,255,255),6:(255,128,0),7:(128,0,255),
    8:(0,0,128),9:(0,0,255),10:(128,128,0),11:(255,255,102)
}
LABELS = {
    0:"BOOTS",1:"GREYTRAIN",2:"HIGHBARRIER1",3:"JUMP",4:"LOWBARRIER1",
    5:"LOWBARRIER2",6:"ORANGETRAIN",7:"PILLAR",8:"RAMP",9:"RAILS",
    10:"SIDEWALK",11:"YELLOWTRAIN"
}

SAFE_GREEN = {9, 10}
WARN_YELLOW = {2,3,4,5,8}

# =======================
# Helpers
# =======================
def load_image_with_time(path: str):
    t0 = time.perf_counter()
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    t1 = time.perf_counter()
    return img, (t1 - t0) * 1000.0

def chunked(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

def highlight_rails_mask_only_fast(img_bgr, rail_mask):
    H, W = img_bgr.shape[:2]
    if not rail_mask.any():
        return np.zeros((H, W), dtype=bool)

    ys, xs = np.where(rail_mask)
    y0, y1 = ys.min(), ys.max()+1
    x0, x1 = xs.min(), xs.max()+1

    img_roi  = img_bgr[y0:y1, x0:x1]
    mask_roi = rail_mask[y0:y1, x0:x1]

    img_f = img_roi.astype(np.float32)
    diff  = img_f[:, :, None, :] - TARGETS_BGR_F32[None, None, :, :]
    dist2 = np.sum(diff * diff, axis=-1)
    colour_hit = np.any(dist2 <= TOL2, axis=-1)

    combined = np.logical_and(colour_hit, mask_roi)
    comp = combined.astype(np.uint8)
    n, lbls, stats, _ = cv2.connectedComponentsWithStats(comp, 8)
    if n <= 1:
        return np.zeros((H, W), dtype=bool)

    good = np.zeros_like(combined)
    areas  = stats[1:, cv2.CC_STAT_AREA]
    hs     = stats[1:, cv2.CC_STAT_HEIGHT]
    keep   = np.where((areas >= MIN_REGION_SIZE) & (hs >= MIN_REGION_HEIGHT))[0] + 1
    for k in keep:
        good[lbls == k] = True

    full = np.zeros((H, W), dtype=bool)
    full[y0:y1, x0:x1] = good
    return full

def red_vs_green_score(red_mask, green_mask):
    k = (HEAT_BLUR_KSIZE, HEAT_BLUR_KSIZE)
    r = cv2.blur(red_mask.astype(np.float32), k)
    g = cv2.blur(green_mask.astype(np.float32), k)
    diff = r - g
    amax = float(np.max(np.abs(diff))) + 1e-6
    norm = (diff / (2.0 * amax) + 0.5)
    return np.clip(norm * 255.0, 0, 255.0).astype(np.uint8)

def purple_triangles(score, H):
    top_ex = int(H * EXCLUDE_TOP_FRAC)
    bot_ex = int(H * EXCLUDE_BOTTOM_FRAC)

    dark = (score >= RED_SCORE_THRESH).astype(np.uint8)
    if top_ex: dark[:top_ex, :] = 0
    if bot_ex: dark[-bot_ex:, :] = 0

    dark = cv2.morphologyEx(
        dark, cv2.MORPH_OPEN,
        cv2.getStructuringElement(cv2.MORPH_RECT, (5, 9)),
        iterations=1
    )
    total_dark = int(dark.sum())
    if total_dark == 0:
        return [], None

    frac_thresh = int(np.ceil(MIN_DARK_FRACTION * total_dark))
    n_lbl, lbls, stats, _ = cv2.connectedComponentsWithStats(dark, 8)
    if n_lbl <= 1:
        return [], None

    tris = []
    for lbl in range(1, n_lbl):
        area = stats[lbl, cv2.CC_STAT_AREA]
        if area >= MIN_DARK_RED_AREA and area >= frac_thresh:
            ys, xs = np.where(lbls == lbl)
            if ys.size == 0:
                continue
            y_top = ys.min()
            x_mid = int(xs[ys == y_top].mean())
            tris.append((int(x_mid), int(y_top)))

    if not tris:
        return [], None

    best = min(tris, key=lambda xy: xy[1])
    return tris, best

# ===== Angled-bend helper =====
def pick_bend_angle(jake_point, xt, x_ref, idx, best_idx):
    """Return θ (deg from vertical; +left, -right) for sampling.
       Jake's triangle (best_idx) always returns 0°."""
    if idx == best_idx:
        return 0.0

    if jake_point == LANE_LEFT:
        # Triangles to the RIGHT of Jake bend LEFT by N1
        return BEND_LEFT_STATE_RIGHT_DEG if xt > x_ref else 0.0

    if jake_point == LANE_RIGHT:
        # Triangles to the LEFT of Jake bend RIGHT by N4
        return BEND_RIGHT_STATE_LEFT_DEG if xt < x_ref else 0.0

    # Middle lane: use JakeTri's x as the divider; right bends LEFT (N2), left bends RIGHT (N3)
    if xt > x_ref:
        return BEND_MID_STATE_RIGHT_DEG
    elif xt < x_ref:
        return BEND_MID_STATE_LEFT_DEG
    return 0.0

# ===== Bearing-based Jake triangle selection =====
def signed_degrees_from_vertical(dx, dy):
    if dx == 0 and dy == 0:
        return 0.0
    return -math.degrees(math.atan2(dx, -dy))

def select_triangle_by_bearing(tri_positions, jx, jy, target_deg, min_dy=6):
    best_i, best_deg, best_err = -1, None, None
    for i, (xt, yt) in enumerate(tri_positions):
        dx = xt - jx
        dy = yt - jy
        if dy >= -min_dy:  # must be above Jake
            continue
        deg = signed_degrees_from_vertical(dx, dy)
        err = abs(deg - target_deg)
        if (best_err is None) or (err < best_err):
            best_i, best_deg, best_err = i, deg, err
    return best_i, best_deg, best_err

# ===== UPDATED: triangle classification using angled sampling =====
def classify_triangles_at_sample_curved(
    tri_positions, masks_np, classes_np, frame_H, frame_W,
    jake_point, x_ref, best_idx, sample_px=SAMPLE_UP_PX
):
    """
    For each triangle tip (x,y), sample masks at a point N px away along a lane-aware
    angled ray. Returns:
      colours: list of BGR colours per triangle
      rays:    list of ((x0,y0),(x1,y1),theta_deg) for debug drawing/labels
    """
    if masks_np is None or classes_np is None or len(tri_positions) == 0:
        return [], []

    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (frame_W - 1))
    sy = (mh - 1) / max(1, (frame_H - 1))

    colours, rays = [], []

    for idx, (x, y) in enumerate(tri_positions):
        # Choose bend angle (Jake tri = 0°, others per lane rules)
        theta = pick_bend_angle(jake_point, x, x_ref, idx, best_idx)

        # Direction from vertical (0,-1) rotated by theta (deg)
        rad = math.radians(theta)
        dx = math.sin(rad)          # +left, -right
        dy = -math.cos(rad)         # up

        xs = int(round(x + dx * sample_px))
        ys = int(round(y + dy * sample_px))

        # Clamp to frame
        xs = max(0, min(frame_W - 1, xs))
        ys = max(0, min(frame_H - 1, ys))

        # Map to mask space
        mx = int(round(xs * sx))
        my = int(round(ys * sy))
        mx = 0 if mx < 0 else (mw - 1 if mx >= mw else mx)
        my = 0 if my < 0 else (mh - 1 if my >= mh else my)

        # Class at sample point
        cls_here = None
        for m, c in zip(masks_np, classes_np):
            if m[my, mx] > 0.5:
                cls_here = int(c)
                break

        if (cls_here is None) or (cls_here in SAFE_GREEN):
            colours.append(COLOR_GREEN)
        elif cls_here == 0:
            colours.append(COLOR_PINK)
        elif cls_here in WARN_YELLOW:
            colours.append(COLOR_YELLOW)
        else:
            colours.append(COLOR_RED)

        rays.append(((int(x), int(y)), (xs, ys), float(theta)))

    return colours, rays

# Returns: (..., tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref)
def process_frame_post(frame_bgr, yolo_res):
    H, W = frame_bgr.shape[:2]
    if yolo_res.masks is None:
        return None, 0, 0, 0.0, 0.0, None, None, None, None, [], [], [], None, None, None

    t0_to_cpu = time.perf_counter()
    masks_np = yolo_res.masks.data.cpu().numpy()  # [n,h,w]
    mask_count = int(masks_np.shape[0])
    if hasattr(yolo_res.masks, "cls") and yolo_res.masks.cls is not None:
        classes_np = yolo_res.masks.cls.cpu().numpy().astype(int)
    else:
        classes_np = yolo_res.boxes.cls.cpu().numpy().astype(int)
    t1_to_cpu = time.perf_counter()
    to_cpu_ms = (t1_to_cpu - t0_to_cpu) * 1000.0

    if mask_count == 0 or classes_np.size == 0:
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    rail_sel = (classes_np == RAIL_ID)
    if not np.any(rail_sel):
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    t0_post = time.perf_counter()
    rail_masks = masks_np[rail_sel].astype(bool)        # [k,h,w]
    union = np.any(rail_masks, axis=0).astype(np.uint8) # [h,w]
    rail_mask = cv2.resize(union, (W, H), interpolation=cv2.INTER_NEAREST).astype(bool)

    green = highlight_rails_mask_only_fast(frame_bgr, rail_mask)
    red   = np.logical_and(rail_mask, np.logical_not(green))
    score = red_vs_green_score(red, green)
    tri_positions, tri_best = purple_triangles(score, H)

    # --- decide Jake triangle first (bearing vs target)
    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    xj, yj = JAKE_POINT
    best_idx, best_deg, _ = select_triangle_by_bearing(tri_positions, xj, yj, target_deg, min_dy=6)

    # x reference for bending:
    # mid lane -> x of JakeTri if found, else Jake point x; side lanes -> Jake point x
    if lane_name == "mid" and best_idx is not None and 0 <= best_idx < len(tri_positions):
        x_ref = tri_positions[best_idx][0]
    else:
        x_ref = xj

    # classify with angled sampling (JakeTri ray = 0°)
    tri_colours, tri_rays = classify_triangles_at_sample_curved(
        tri_positions, masks_np, classes_np, H, W, JAKE_POINT, x_ref, best_idx, SAMPLE_UP_PX
    )

    t1_post = time.perf_counter()
    post_ms = (t1_post - t0_post) * 1000.0

    return tri_best, len(tri_positions), mask_count, to_cpu_ms, post_ms, masks_np, classes_np, rail_mask, green, tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref

def _colour_for_point(x, y, masks_np, classes_np, frame_H, frame_W):
    if masks_np is None or classes_np is None or masks_np.size == 0:
        return COLOR_GREEN
    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (frame_W - 1))
    sy = (mh - 1) / max(1, (frame_H - 1))
    mx = int(round(x * sx)); my = int(round(y * sy))
    mx = 0 if mx < 0 else (mw - 1 if mx >= mw else mx)
    my = 0 if my < 0 else (mh - 1 if my >= mh else my)
    cls_here = None
    for m, c in zip(masks_np, classes_np):
        if m[my, mx] > 0.5:
            cls_here = int(c); break
    if (cls_here is None) or (cls_here in SAFE_GREEN): return COLOR_GREEN
    if cls_here == 0: return COLOR_PINK
    if cls_here in WARN_YELLOW: return COLOR_YELLOW
    return COLOR_RED

def draw_triangle(img, x, y, size=TRI_SIZE_PX, colour=COLOR_RED):
    h = int(size * 1.2)
    pts = np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)
    cv2.fillConvexPoly(img, pts, colour)
    cv2.polylines(img, [pts.reshape(-1,1,2)], True, COLOR_BLACK, 1, cv2.LINE_AA)

def triangle_pts(x, y, size=TRI_SIZE_PX):
    h = int(size * 1.2)
    return np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)

# --- rendering (excluded from timing) ---
def render_overlays(frame_bgr, masks_np, classes_np, rail_mask, green_mask,
                    tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref):
    out = frame_bgr.copy()
    H, W = out.shape[:2]
    alpha = 0.45

    # masks
    if masks_np is not None and classes_np is not None and masks_np.size:
        for m, c in zip(masks_np, classes_np):
            m_full = m
            if m.shape != (H, W):
                m_full = cv2.resize(m.astype(np.uint8), (W, H), interpolation=cv2.INTER_NEAREST).astype(bool)
            color = CLASS_COLOURS.get(int(c), (255,255,255))
            out[m_full] = (np.array(color, dtype=np.uint8) * alpha + out[m_full] * (1 - alpha)).astype(np.uint8)
            ys, xs = np.where(m_full)
            if xs.size:
                xc, yc = int(xs.mean()), int(ys.mean())
                label = LABELS.get(int(c), f"C{int(c)}")
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, COLOR_BLACK, 2, cv2.LINE_AA)
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1, cv2.LINE_AA)

    if rail_mask is not None:
        tint = out.copy()
        tint[rail_mask] = (0, 0, 255)
        out = cv2.addWeighted(tint, 0.30, out, 0.70, 0)
    if green_mask is not None:
        out[green_mask] = (0, 255, 0)

    # Scout lines (tiny)
    if tri_positions:
        for (x, y) in tri_positions:
            y_end = max(0, y - SAMPLE_UP_PX)
            for yy in range(y, y_end - 1, -1):
                col = _colour_for_point(x, yy, masks_np, classes_np, H, W)
                out[yy, x] = col

    # Starburst lines to Jake with degree labels
    xj, yj = JAKE_POINT
    for idx, (xt, yt) in enumerate(tri_positions):
        xt = max(0, min(W-1, int(xt)))
        yt = max(0, min(H-1, int(yt)))
        dx = xt - xj; dy = yt - yj
        deg_signed = signed_degrees_from_vertical(dx, dy)
        line_color = COLOR_CYAN if idx == best_idx else COLOR_WHITE
        cv2.line(out, (xj, yj), (xt, yt), line_color, 2, cv2.LINE_AA)
        mid_x = int((xj + xt) / 2); mid_y = int((yj + yt) / 2)
        cv2.putText(out, f"{deg_signed:.1f}°", (mid_x, mid_y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, f"{deg_signed:.1f}°", (mid_x, mid_y),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    # Draw angled sampling rays + bend-degree labels (JakeTri shows 0.0°)
    for (p0, p1, theta) in tri_rays:
        cv2.line(out, p0, p1, (255,255,255), 2, cv2.LINE_AA)
        mx = (p0[0] + p1[0]) // 2
        my = (p0[1] + p1[1]) // 2
        txt = f"{theta:+.1f}°"
        cv2.putText(out, txt, (mx, my),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, txt, (mx, my),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    # Triangles after lines
    for (x, y), col in zip(tri_positions, tri_colours):
        draw_triangle(out, x, y, colour=col)

    # Emphasize selected triangle + tag
    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    if best_idx is not None and 0 <= best_idx < len(tri_positions):
        xt, yt = tri_positions[best_idx]
        pts = triangle_pts(int(xt), int(yt), size=TRI_SIZE_PX)
        cv2.polylines(out, [pts.reshape(-1,1,2)], True, COLOR_CYAN, 3, cv2.LINE_AA)
        tag = f"JAKE_TRI ({lane_name}: target {target_deg:.1f}°)"
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    return out

# =======================
# Batched execution with prints; overlays saved for first N
# =======================
def run_pipeline_with_prints_and_overlays():
    paths = (
        glob.glob(str(frames_dir/"frame_*.jpg")) +
        glob.glob(str(frames_dir/"frame_*.png")) +
        glob.glob(str(frames_dir/"*.jpg")) +
        glob.glob(str(frames_dir/"*.png"))
    )
    paths = sorted(set(paths))
    if not paths:
        raise FileNotFoundError(f"No images in: {frames_dir}")
    if SHOW_FIRST_N is not None:
        paths = paths[:SHOW_FIRST_N]

    N = len(paths)
    results_triangle_xy = [None] * N

    def load_batch(batch_paths):
        imgs = [None] * len(batch_paths)
        read_ms = [0.0] * len(batch_paths)
        with ThreadPoolExecutor(max_workers=THREADS_IO) as ex:
            fut2idx = {ex.submit(load_image_with_time, p): i for i, p in enumerate(batch_paths)}
            for fut in as_completed(fut2idx):
                i = fut2idx[fut]
                img, r_ms = fut.result()
                imgs[i] = img
                read_ms[i] = r_ms
        ok = [(p, im, rm) for p, im, rm in zip(batch_paths, imgs, read_ms) if im is not None]
        if not ok:
            return [], [], []
        b_paths, b_imgs, b_read = zip(*ok)
        return list(b_paths), list(b_imgs), list(b_read)

    idx_global = 0
    for batch_paths in chunked(paths, BATCH):
        batch_paths, imgs_bgr, read_ms_list = load_batch(batch_paths)
        B = len(imgs_bgr)
        if B == 0:
            idx_global += len(batch_paths)
            continue

        t0_inf = time.perf_counter()
        res_list = model.predict(
            imgs_bgr, task="segment", imgsz=IMG_SIZE, device=device,
            conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET,
            batch=B
        )
        try:
            if device == 0 and torch.cuda.is_available():
                torch.cuda.synchronize()
            elif device == "mps" and getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
                torch.mps.synchronize()
        except Exception:
            pass
        t1_inf = time.perf_counter()
        infer_ms_share = ((t1_inf - t0_inf) * 1000.0) / B

        for j, (img, yres, read_ms) in enumerate(zip(imgs_bgr, res_list, read_ms_list)):
            (tri_best_xy, tri_count, mask_count, to_cpu_ms, post_ms,
             masks_np, classes_np, rail_mask, green_mask, tri_positions, tri_colours,
             tri_rays, best_idx, best_deg, x_ref) = process_frame_post(img, yres)

            results_triangle_xy[idx_global + j] = tri_best_xy
            proc_ms = infer_ms_share + to_cpu_ms + post_ms
            fname = os.path.basename(batch_paths[j])
            frame_idx = idx_global + j + 1

            print(f"[{frame_idx}/{N}] {fname}  "
                  f"read {read_ms:.1f} | infer {infer_ms_share:.1f} | "
                  f"to_cpu {to_cpu_ms:.1f} | post {post_ms:.1f} | "
                  f"masks {mask_count} | triangles {tri_count} "
                  f"=> proc {proc_ms:.1f} ms")

            if frame_idx <= RENDER_FIRST_N:
                overlay = render_overlays(img, masks_np, classes_np, rail_mask, green_mask,
                                          tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref)
                out_path = out_dir / f"overlay_{frame_idx:04d}_{fname}"
                cv2.imwrite(str(out_path), overlay)

        idx_global += B

    return results_triangle_xy

# =======================
# Entry
# =======================
if __name__ == "__main__":
    _ = run_pipeline_with_prints_and_overlays()
# Out:
# YOLO11n-seg summary (fused): 113 layers, 2,836,908 parameters, 0 gradients, 10.2 GFLOPs
# [1/312] frame_00000.png  read 37.5 | infer 2179.2 | to_cpu 0.7 | post 0.0 | masks 1 | triangles 0 => proc 2179.9 ms
# [2/312] frame_00001.png  read 36.6 | infer 197.2 | to_cpu 1.0 | post 78.1 | masks 3 | triangles 1 => proc 276.3 ms
# [3/312] frame_00002.png  read 36.3 | infer 76.3 | to_cpu 0.6 | post 119.5 | masks 3 | triangles 3 => proc 196.4 ms
# [4/312] frame_00003.png  read 52.7 | infer 84.2 | to_cpu 0.8 | post 130.0 | masks 3 | triangles 2 => proc 215.0 ms
# [5/312] frame_00004.png  read 48.5 | infer 206.7 | to_cpu 3.5 | post 1259.1 | masks 4 | triangles 1 => proc 1469.3 ms
# [6/312] frame_00005.png  read 51.9 | infer 545.2 | to_cpu 1.1 | post 302.6 | masks 5 | triangles 1 => proc 848.9 ms
# [7/312] frame_00006.png  read 73.1 | infer 118.9 | to_cpu 0.8 | post 240.1 | masks 5 | triangles 2 => proc 359.8 ms
# [8/312] frame_00007.png  read 41.5 | infer 123.2 | to_cpu 1.2 | post 285.7 | masks 4 | triangles 2 => proc 410.2 ms
# [9/312] frame_00008.png  read 39.1 | infer 78.9 | to_cpu 0.9 | post 169.3 | masks 5 | triangles 2 => proc 249.2 ms
# [10/312] frame_00009.png  read 40.3 | infer 81.0 | to_cpu 0.8 | post 186.6 | masks 4 | triangles 2 => proc 268.3 ms
# [11/312] frame_00010.png  read 39.3 | infer 39.4 | to_cpu 0.9 | post 315.8 | masks 4 | triangles 2 => proc 356.2 ms
# [12/312] frame_00011.png  read 49.7 | infer 313.2 | to_cpu 1.2 | post 300.6 | masks 3 | triangles 3 => proc 615.0 ms
# [13/312] frame_00012.png  read 46.1 | infer 412.8 | to_cpu 1.8 | post 393.1 | masks 3 | triangles 3 => proc 807.7 ms
# [14/312] frame_00013.png  read 37.8 | infer 95.0 | to_cpu 2.6 | post 176.5 | masks 3 | triangles 3 => proc 274.1 ms
# [15/312] frame_00014.png  read 40.3 | infer 74.8 | to_cpu 0.8 | post 158.4 | masks 4 | triangles 2 => proc 233.9 ms
# [16/312] frame_00015.png  read 40.8 | infer 75.8 | to_cpu 1.0 | post 154.2 | masks 5 | triangles 2 => proc 231.0 ms
# [17/312] frame_00016.png  read 36.8 | infer 39.9 | to_cpu 0.8 | post 153.1 | masks 4 | triangles 2 => proc 193.9 ms
# [18/312] frame_00017.png  read 50.1 | infer 69.9 | to_cpu 1.4 | post 375.6 | masks 4 | triangles 2 => proc 446.9 ms
# [19/312] frame_00018.png  read 42.0 | infer 112.9 | to_cpu 0.9 | post 171.7 | masks 4 | triangles 2 => proc 285.5 ms
# [20/312] frame_00019.png  read 42.0 | infer 76.1 | to_cpu 1.0 | post 156.7 | masks 3 | triangles 2 => proc 233.8 ms
# [21/312] frame_00020.png  read 37.6 | infer 31.3 | to_cpu 0.7 | post 150.1 | masks 3 | triangles 1 => proc 182.1 ms
# [22/312] frame_00021.png  read 40.8 | infer 80.3 | to_cpu 1.1 | post 130.9 | masks 4 | triangles 1 => proc 212.3 ms
# [23/312] frame_00022.png  read 40.9 | infer 78.8 | to_cpu 0.8 | post 111.2 | masks 4 | triangles 1 => proc 190.8 ms
# [24/312] frame_00023.png  read 38.5 | infer 35.0 | to_cpu 0.8 | post 124.5 | masks 4 | triangles 1 => proc 160.3 ms
# [25/312] frame_00024.png  read 41.2 | infer 35.0 | to_cpu 1.4 | post 102.0 | masks 4 | triangles 1 => proc 138.4 ms
# [26/312] frame_00025.png  read 39.3 | infer 79.4 | to_cpu 0.8 | post 100.5 | masks 4 | triangles 1 => proc 180.7 ms
# [27/312] frame_00026.png  read 37.3 | infer 82.0 | to_cpu 1.0 | post 90.6 | masks 5 | triangles 1 => proc 173.6 ms
# [28/312] frame_00027.png  read 90.3 | infer 67.9 | to_cpu 1.7 | post 244.0 | masks 3 | triangles 1 => proc 313.6 ms
# [29/312] frame_00028.png  read 41.9 | infer 102.5 | to_cpu 1.1 | post 65.4 | masks 5 | triangles 1 => proc 169.0 ms
# [30/312] frame_00029.png  read 41.7 | infer 385.2 | to_cpu 1.7 | post 47.9 | masks 6 | triangles 1 => proc 434.8 ms
# [31/312] frame_00030.png  read 48.3 | infer 95.1 | to_cpu 1.0 | post 72.9 | masks 6 | triangles 2 => proc 169.0 ms
# [32/312] frame_00031.png  read 39.0 | infer 39.8 | to_cpu 0.9 | post 80.7 | masks 6 | triangles 1 => proc 121.4 ms
# [33/312] frame_00032.png  read 41.0 | infer 38.0 | to_cpu 0.8 | post 140.8 | masks 5 | triangles 1 => proc 179.7 ms
# [34/312] frame_00033.png  read 37.6 | infer 36.3 | to_cpu 0.9 | post 111.2 | masks 3 | triangles 2 => proc 148.4 ms
# [35/312] frame_00034.png  read 40.8 | infer 42.9 | to_cpu 0.9 | post 118.6 | masks 4 | triangles 2 => proc 162.4 ms
# [36/312] frame_00035.png  read 38.4 | infer 74.1 | to_cpu 0.8 | post 124.0 | masks 4 | triangles 1 => proc 198.9 ms
# [37/312] frame_00036.png  read 39.8 | infer 39.5 | to_cpu 0.7 | post 174.8 | masks 3 | triangles 2 => proc 215.0 ms
# [38/312] frame_00037.png  read 67.9 | infer 45.3 | to_cpu 0.7 | post 139.9 | masks 3 | triangles 1 => proc 186.0 ms
# [39/312] frame_00038.png  read 38.2 | infer 33.5 | to_cpu 0.8 | post 118.6 | masks 4 | triangles 1 => proc 152.8 ms
# [40/312] frame_00039.png  read 38.0 | infer 44.3 | to_cpu 0.8 | post 118.8 | masks 4 | triangles 1 => proc 163.9 ms
# [41/312] frame_00040.png  read 38.7 | infer 38.6 | to_cpu 0.7 | post 111.3 | masks 3 | triangles 1 => proc 150.6 ms
# [42/312] frame_00041.png  read 39.2 | infer 78.6 | to_cpu 0.8 | post 98.9 | masks 3 | triangles 1 => proc 178.3 ms
# [43/312] frame_00042.png  read 37.1 | infer 38.8 | to_cpu 0.9 | post 133.3 | masks 5 | triangles 1 => proc 173.0 ms
# [44/312] frame_00043.png  read 41.5 | infer 35.5 | to_cpu 0.9 | post 128.1 | masks 5 | triangles 2 => proc 164.6 ms
# [45/312] frame_00044.png  read 37.0 | infer 34.7 | to_cpu 0.9 | post 121.6 | masks 4 | triangles 2 => proc 157.2 ms
# [46/312] frame_00045.png  read 37.6 | infer 75.8 | to_cpu 0.9 | post 156.0 | masks 3 | triangles 2 => proc 232.7 ms
# [47/312] frame_00046.png  read 38.6 | infer 38.0 | to_cpu 0.8 | post 154.0 | masks 3 | triangles 1 => proc 192.8 ms
# [48/312] frame_00047.png  read 43.9 | infer 39.7 | to_cpu 1.0 | post 136.0 | masks 3 | triangles 1 => proc 176.7 ms
# [49/312] frame_00048.png  read 40.4 | infer 36.0 | to_cpu 0.7 | post 152.6 | masks 3 | triangles 2 => proc 189.4 ms
# [50/312] frame_00049.png  read 36.6 | infer 149.9 | to_cpu 1.0 | post 157.8 | masks 2 | triangles 2 => proc 308.7 ms
# [51/312] frame_00050.png  read 40.6 | infer 36.5 | to_cpu 0.6 | post 164.8 | masks 2 | triangles 2 => proc 202.0 ms
# [52/312] frame_00051.png  read 37.3 | infer 72.7 | to_cpu 0.7 | post 153.4 | masks 2 | triangles 2 => proc 226.8 ms
# [53/312] frame_00052.png  read 38.9 | infer 74.5 | to_cpu 0.7 | post 151.1 | masks 2 | triangles 2 => proc 226.3 ms
# [54/312] frame_00053.png  read 37.7 | infer 39.2 | to_cpu 0.8 | post 117.2 | masks 2 | triangles 1 => proc 157.2 ms
# [55/312] frame_00054.png  read 40.3 | infer 34.4 | to_cpu 0.7 | post 125.1 | masks 4 | triangles 1 => proc 160.2 ms
# [56/312] frame_00055.png  read 38.1 | infer 48.7 | to_cpu 1.0 | post 126.1 | masks 4 | triangles 1 => proc 175.8 ms
# [57/312] frame_00056.png  read 43.2 | infer 40.2 | to_cpu 2.4 | post 124.4 | masks 4 | triangles 1 => proc 167.0 ms
# [58/312] frame_00057.png  read 37.8 | infer 33.7 | to_cpu 0.7 | post 121.9 | masks 4 | triangles 1 => proc 156.3 ms
# [59/312] frame_00058.png  read 39.2 | infer 42.3 | to_cpu 0.9 | post 138.7 | masks 5 | triangles 1 => proc 182.0 ms
# [60/312] frame_00059.png  read 40.3 | infer 40.0 | to_cpu 0.8 | post 136.7 | masks 4 | triangles 1 => proc 177.6 ms
# [61/312] frame_00060.png  read 39.5 | infer 38.4 | to_cpu 0.9 | post 113.4 | masks 5 | triangles 1 => proc 152.7 ms
# [62/312] frame_00061.png  read 39.0 | infer 35.1 | to_cpu 0.8 | post 111.9 | masks 4 | triangles 1 => proc 147.9 ms
# [63/312] frame_00062.png  read 40.4 | infer 391.6 | to_cpu 1.2 | post 209.8 | masks 6 | triangles 2 => proc 602.7 ms
# [64/312] frame_00063.png  read 41.5 | infer 71.2 | to_cpu 1.0 | post 166.1 | masks 4 | triangles 2 => proc 238.3 ms
# [65/312] frame_00064.png  read 39.3 | infer 40.4 | to_cpu 0.9 | post 172.9 | masks 5 | triangles 2 => proc 214.2 ms
# [66/312] frame_00065.png  read 37.5 | infer 79.8 | to_cpu 1.1 | post 130.4 | masks 6 | triangles 1 => proc 211.3 ms
# [67/312] frame_00066.png  read 42.0 | infer 42.4 | to_cpu 0.9 | post 144.0 | masks 5 | triangles 2 => proc 187.2 ms
# [68/312] frame_00067.png  read 42.7 | infer 51.5 | to_cpu 0.9 | post 199.9 | masks 5 | triangles 2 => proc 252.4 ms
# [69/312] frame_00068.png  read 40.2 | infer 132.6 | to_cpu 1.4 | post 159.1 | masks 4 | triangles 2 => proc 293.1 ms
# [70/312] frame_00069.png  read 39.9 | infer 41.8 | to_cpu 0.8 | post 156.7 | masks 4 | triangles 2 => proc 199.3 ms
# [71/312] frame_00070.png  read 38.9 | infer 74.5 | to_cpu 0.8 | post 155.6 | masks 5 | triangles 2 => proc 230.8 ms
# [72/312] frame_00071.png  read 39.2 | infer 39.1 | to_cpu 0.9 | post 155.4 | masks 5 | triangles 2 => proc 195.4 ms
# [73/312] frame_00072.png  read 36.7 | infer 36.1 | to_cpu 0.8 | post 145.5 | masks 4 | triangles 2 => proc 182.4 ms
# [74/312] frame_00073.png  read 39.8 | infer 34.4 | to_cpu 0.8 | post 141.6 | masks 4 | triangles 2 => proc 176.8 ms
# [75/312] frame_00074.png  read 36.3 | infer 41.2 | to_cpu 0.9 | post 140.4 | masks 3 | triangles 2 => proc 182.6 ms
# [76/312] frame_00075.png  read 41.4 | infer 36.0 | to_cpu 0.8 | post 130.1 | masks 4 | triangles 2 => proc 166.9 ms
# [77/312] frame_00076.png  read 40.7 | infer 74.5 | to_cpu 0.9 | post 128.9 | masks 5 | triangles 2 => proc 204.4 ms
# [78/312] frame_00077.png  read 40.9 | infer 40.4 | to_cpu 0.8 | post 162.7 | masks 4 | triangles 2 => proc 203.9 ms
# [79/312] frame_00078.png  read 38.0 | infer 35.8 | to_cpu 0.8 | post 89.5 | masks 4 | triangles 1 => proc 126.1 ms
# [80/312] frame_00079.png  read 42.9 | infer 40.6 | to_cpu 0.9 | post 120.2 | masks 4 | triangles 1 => proc 161.7 ms
# [81/312] frame_00080.png  read 38.3 | infer 46.8 | to_cpu 0.8 | post 128.0 | masks 4 | triangles 1 => proc 175.6 ms
# [82/312] frame_00081.png  read 37.7 | infer 36.5 | to_cpu 3.3 | post 149.6 | masks 5 | triangles 2 => proc 189.4 ms
# [83/312] frame_00082.png  read 36.7 | infer 35.4 | to_cpu 0.8 | post 149.7 | masks 3 | triangles 2 => proc 185.9 ms
# [84/312] frame_00083.png  read 41.5 | infer 36.0 | to_cpu 1.5 | post 173.4 | masks 4 | triangles 2 => proc 211.0 ms
# [85/312] frame_00084.png  read 36.9 | infer 34.5 | to_cpu 0.8 | post 154.2 | masks 3 | triangles 2 => proc 189.4 ms
# [86/312] frame_00085.png  read 40.5 | infer 76.0 | to_cpu 0.7 | post 152.2 | masks 3 | triangles 2 => proc 229.0 ms
# [87/312] frame_00086.png  read 36.4 | infer 40.3 | to_cpu 0.7 | post 152.6 | masks 2 | triangles 2 => proc 193.6 ms
# [88/312] frame_00087.png  read 38.6 | infer 80.0 | to_cpu 0.8 | post 172.9 | masks 3 | triangles 1 => proc 253.7 ms
# [89/312] frame_00088.png  read 55.3 | infer 35.2 | to_cpu 0.8 | post 126.3 | masks 4 | triangles 1 => proc 162.3 ms
# [90/312] frame_00089.png  read 37.8 | infer 36.5 | to_cpu 0.9 | post 149.0 | masks 5 | triangles 2 => proc 186.3 ms
# [91/312] frame_00090.png  read 40.0 | infer 42.0 | to_cpu 3.0 | post 156.8 | masks 3 | triangles 2 => proc 201.8 ms
# [92/312] frame_00091.png  read 38.7 | infer 43.1 | to_cpu 1.2 | post 155.3 | masks 3 | triangles 2 => proc 199.5 ms
# [93/312] frame_00092.png  read 40.1 | infer 36.8 | to_cpu 0.8 | post 156.3 | masks 3 | triangles 2 => proc 193.9 ms
# [94/312] frame_00093.png  read 42.2 | infer 36.3 | to_cpu 0.8 | post 156.8 | masks 3 | triangles 2 => proc 193.9 ms
# [95/312] frame_00094.png  read 38.8 | infer 35.9 | to_cpu 0.7 | post 152.0 | masks 2 | triangles 2 => proc 188.6 ms
# [96/312] frame_00095.png  read 37.1 | infer 33.8 | to_cpu 0.8 | post 144.1 | masks 3 | triangles 1 => proc 178.8 ms
# [97/312] frame_00096.png  read 40.2 | infer 42.6 | to_cpu 0.8 | post 126.8 | masks 4 | triangles 1 => proc 170.2 ms
# [98/312] frame_00097.png  read 37.7 | infer 36.5 | to_cpu 0.8 | post 122.8 | masks 4 | triangles 1 => proc 160.1 ms
# [99/312] frame_00098.png  read 41.5 | infer 41.4 | to_cpu 1.0 | post 134.7 | masks 4 | triangles 1 => proc 177.0 ms
# [100/312] frame_00099.png  read 39.9 | infer 45.4 | to_cpu 2.8 | post 119.6 | masks 4 | triangles 1 => proc 167.8 ms
# [101/312] frame_00100.png  read 40.2 | infer 36.2 | to_cpu 0.7 | post 121.7 | masks 3 | triangles 1 => proc 158.6 ms
# [102/312] frame_00101.png  read 38.5 | infer 42.8 | to_cpu 0.8 | post 148.2 | masks 5 | triangles 2 => proc 191.8 ms
# [103/312] frame_00102.png  read 39.8 | infer 42.8 | to_cpu 0.7 | post 181.4 | masks 3 | triangles 2 => proc 224.8 ms
# [104/312] frame_00103.png  read 37.4 | infer 38.7 | to_cpu 0.9 | post 152.3 | masks 4 | triangles 1 => proc 191.9 ms
# [105/312] frame_00104.png  read 38.6 | infer 43.7 | to_cpu 1.0 | post 146.3 | masks 4 | triangles 1 => proc 191.0 ms
# [106/312] frame_00105.png  read 36.8 | infer 37.0 | to_cpu 0.8 | post 154.4 | masks 4 | triangles 3 => proc 192.2 ms
# [107/312] frame_00106.png  read 40.0 | infer 44.7 | to_cpu 0.9 | post 185.0 | masks 5 | triangles 1 => proc 230.5 ms
# [108/312] frame_00107.png  read 39.0 | infer 40.0 | to_cpu 2.0 | post 133.3 | masks 5 | triangles 1 => proc 175.3 ms
# [109/312] frame_00108.png  read 38.3 | infer 39.9 | to_cpu 1.0 | post 167.6 | masks 5 | triangles 2 => proc 208.6 ms
# [110/312] frame_00109.png  read 37.5 | infer 34.6 | to_cpu 1.8 | post 156.3 | masks 5 | triangles 2 => proc 192.7 ms
# [111/312] frame_00110.png  read 40.9 | infer 41.7 | to_cpu 0.8 | post 140.0 | masks 4 | triangles 1 => proc 182.6 ms
# [112/312] frame_00111.png  read 38.1 | infer 37.5 | to_cpu 0.7 | post 145.4 | masks 4 | triangles 2 => proc 183.6 ms
# [113/312] frame_00112.png  read 39.4 | infer 42.7 | to_cpu 1.3 | post 142.3 | masks 4 | triangles 2 => proc 186.2 ms
# [114/312] frame_00113.png  read 37.4 | infer 37.1 | to_cpu 0.9 | post 128.7 | masks 5 | triangles 1 => proc 166.8 ms
# [115/312] frame_00114.png  read 40.2 | infer 373.9 | to_cpu 1.5 | post 135.1 | masks 6 | triangles 1 => proc 510.5 ms
# [116/312] frame_00115.png  read 56.1 | infer 81.0 | to_cpu 0.9 | post 120.7 | masks 6 | triangles 1 => proc 202.5 ms
# [117/312] frame_00116.png  read 40.4 | infer 81.2 | to_cpu 1.0 | post 121.5 | masks 6 | triangles 1 => proc 203.7 ms
# [118/312] frame_00117.png  read 40.7 | infer 45.2 | to_cpu 1.2 | post 129.5 | masks 4 | triangles 2 => proc 175.8 ms
# [119/312] frame_00118.png  read 42.1 | infer 41.0 | to_cpu 0.8 | post 120.9 | masks 5 | triangles 1 => proc 162.8 ms
# [120/312] frame_00119.png  read 37.6 | infer 59.2 | to_cpu 1.0 | post 164.4 | masks 6 | triangles 2 => proc 224.6 ms
# [121/312] frame_00120.png  read 44.7 | infer 75.7 | to_cpu 1.1 | post 194.6 | masks 6 | triangles 1 => proc 271.4 ms
# [122/312] frame_00121.png  read 37.3 | infer 88.0 | to_cpu 0.8 | post 154.7 | masks 6 | triangles 2 => proc 243.5 ms
# [123/312] frame_00122.png  read 42.0 | infer 199.1 | to_cpu 1.0 | post 145.0 | masks 7 | triangles 1 => proc 345.1 ms
# [124/312] frame_00123.png  read 40.5 | infer 454.8 | to_cpu 1.2 | post 138.8 | masks 10 | triangles 1 => proc 594.8 ms
# [125/312] frame_00124.png  read 52.9 | infer 168.6 | to_cpu 1.1 | post 140.4 | masks 9 | triangles 1 => proc 310.1 ms
# [126/312] frame_00125.png  read 40.4 | infer 37.2 | to_cpu 1.2 | post 139.3 | masks 9 | triangles 2 => proc 177.6 ms
# [127/312] frame_00126.png  read 60.0 | infer 161.7 | to_cpu 2.2 | post 162.8 | masks 5 | triangles 1 => proc 326.7 ms
# [128/312] frame_00127.png  read 70.5 | infer 100.3 | to_cpu 8.6 | post 195.9 | masks 5 | triangles 2 => proc 304.7 ms
# [129/312] frame_00128.png  read 36.2 | infer 44.3 | to_cpu 0.8 | post 161.6 | masks 3 | triangles 3 => proc 206.7 ms
# [130/312] frame_00129.png  read 47.0 | infer 41.8 | to_cpu 1.8 | post 173.4 | masks 3 | triangles 3 => proc 217.0 ms
# [131/312] frame_00130.png  read 36.1 | infer 40.9 | to_cpu 0.7 | post 157.6 | masks 3 | triangles 2 => proc 199.2 ms
# [132/312] frame_00131.png  read 39.7 | infer 42.7 | to_cpu 0.9 | post 160.0 | masks 4 | triangles 2 => proc 203.6 ms
# [133/312] frame_00132.png  read 34.3 | infer 45.1 | to_cpu 0.8 | post 150.9 | masks 3 | triangles 2 => proc 196.7 ms
# [134/312] frame_00133.png  read 34.7 | infer 35.3 | to_cpu 0.8 | post 139.2 | masks 3 | triangles 1 => proc 175.3 ms
# [135/312] frame_00134.png  read 30.7 | infer 49.4 | to_cpu 0.8 | post 114.3 | masks 3 | triangles 1 => proc 164.5 ms
# [136/312] frame_00135.png  read 30.9 | infer 65.9 | to_cpu 0.9 | post 93.0 | masks 2 | triangles 1 => proc 159.8 ms
# [137/312] frame_00136.png  read 34.1 | infer 36.1 | to_cpu 0.8 | post 88.0 | masks 2 | triangles 1 => proc 125.0 ms
# [138/312] frame_00137.png  read 31.6 | infer 33.6 | to_cpu 1.6 | post 108.8 | masks 2 | triangles 1 => proc 143.9 ms
# [139/312] frame_00138.png  read 53.0 | infer 48.0 | to_cpu 1.4 | post 259.2 | masks 3 | triangles 2 => proc 308.6 ms
# [140/312] frame_00139.png  read 38.2 | infer 85.7 | to_cpu 0.6 | post 158.6 | masks 2 | triangles 2 => proc 244.9 ms
# [141/312] frame_00140.png  read 39.2 | infer 41.1 | to_cpu 0.7 | post 160.2 | masks 3 | triangles 2 => proc 202.0 ms
# [142/312] frame_00141.png  read 36.8 | infer 47.7 | to_cpu 0.7 | post 153.5 | masks 3 | triangles 2 => proc 202.0 ms
# [143/312] frame_00142.png  read 39.8 | infer 40.7 | to_cpu 0.7 | post 157.9 | masks 3 | triangles 2 => proc 199.2 ms
# [144/312] frame_00143.png  read 36.2 | infer 36.4 | to_cpu 0.7 | post 149.6 | masks 3 | triangles 2 => proc 186.7 ms
# [145/312] frame_00144.png  read 40.5 | infer 37.3 | to_cpu 0.8 | post 156.3 | masks 3 | triangles 2 => proc 194.4 ms
# [146/312] frame_00145.png  read 41.2 | infer 36.9 | to_cpu 0.8 | post 114.4 | masks 4 | triangles 1 => proc 152.2 ms
# [147/312] frame_00146.png  read 38.6 | infer 50.1 | to_cpu 1.3 | post 108.3 | masks 4 | triangles 1 => proc 159.7 ms
# [148/312] frame_00147.png  read 40.3 | infer 42.7 | to_cpu 1.1 | post 119.7 | masks 4 | triangles 1 => proc 163.5 ms
# [149/312] frame_00148.png  read 37.6 | infer 41.1 | to_cpu 0.8 | post 111.1 | masks 4 | triangles 1 => proc 153.1 ms
# [150/312] frame_00149.png  read 41.5 | infer 348.9 | to_cpu 1.4 | post 138.1 | masks 6 | triangles 1 => proc 488.5 ms
# [151/312] frame_00150.png  read 39.8 | infer 61.8 | to_cpu 0.8 | post 129.9 | masks 7 | triangles 1 => proc 192.4 ms
# [152/312] frame_00151.png  read 37.4 | infer 54.2 | to_cpu 1.2 | post 129.1 | masks 7 | triangles 2 => proc 184.4 ms
# [153/312] frame_00152.png  read 47.8 | infer 68.8 | to_cpu 1.9 | post 194.5 | masks 5 | triangles 1 => proc 265.2 ms
# [154/312] frame_00153.png  read 47.3 | infer 54.0 | to_cpu 1.1 | post 181.5 | masks 5 | triangles 1 => proc 236.6 ms
# [155/312] frame_00154.png  read 46.6 | infer 232.5 | to_cpu 2.5 | post 223.2 | masks 6 | triangles 2 => proc 458.2 ms
# [156/312] frame_00155.png  read 44.3 | infer 82.8 | to_cpu 1.8 | post 225.2 | masks 6 | triangles 2 => proc 309.8 ms
# [157/312] frame_00156.png  read 40.6 | infer 64.7 | to_cpu 1.2 | post 174.3 | masks 5 | triangles 2 => proc 240.2 ms
# [158/312] frame_00157.png  read 40.1 | infer 52.4 | to_cpu 0.7 | post 141.2 | masks 3 | triangles 2 => proc 194.3 ms
# [159/312] frame_00158.png  read 37.0 | infer 33.3 | to_cpu 0.7 | post 136.8 | masks 5 | triangles 2 => proc 170.8 ms
# [160/312] frame_00159.png  read 40.6 | infer 45.9 | to_cpu 1.1 | post 162.6 | masks 5 | triangles 2 => proc 209.6 ms
# [161/312] frame_00160.png  read 66.5 | infer 45.1 | to_cpu 1.0 | post 155.9 | masks 5 | triangles 2 => proc 202.0 ms
# [162/312] frame_00161.png  read 38.8 | infer 40.4 | to_cpu 0.9 | post 116.9 | masks 4 | triangles 1 => proc 158.2 ms
# [163/312] frame_00162.png  read 36.5 | infer 395.5 | to_cpu 1.1 | post 209.9 | masks 6 | triangles 2 => proc 606.6 ms
# [164/312] frame_00163.png  read 46.0 | infer 48.4 | to_cpu 0.9 | post 172.1 | masks 4 | triangles 2 => proc 221.5 ms
# [165/312] frame_00164.png  read 37.8 | infer 38.2 | to_cpu 0.9 | post 161.8 | masks 5 | triangles 2 => proc 200.9 ms
# [166/312] frame_00165.png  read 39.2 | infer 50.7 | to_cpu 0.9 | post 158.2 | masks 4 | triangles 2 => proc 209.8 ms
# [167/312] frame_00166.png  read 38.0 | infer 34.5 | to_cpu 0.7 | post 158.2 | masks 4 | triangles 2 => proc 193.4 ms
# [168/312] frame_00167.png  read 40.4 | infer 36.8 | to_cpu 0.9 | post 156.7 | masks 5 | triangles 2 => proc 194.4 ms
# [169/312] frame_00168.png  read 38.5 | infer 49.9 | to_cpu 0.8 | post 154.8 | masks 4 | triangles 2 => proc 205.5 ms
# [170/312] frame_00169.png  read 132.1 | infer 40.3 | to_cpu 0.9 | post 207.5 | masks 4 | triangles 2 => proc 248.7 ms
# [171/312] frame_00170.png  read 38.9 | infer 52.8 | to_cpu 1.1 | post 162.3 | masks 3 | triangles 3 => proc 216.1 ms
# [172/312] frame_00171.png  read 38.2 | infer 53.7 | to_cpu 1.2 | post 303.7 | masks 4 | triangles 2 => proc 358.5 ms
# [173/312] frame_00172.png  read 43.1 | infer 516.4 | to_cpu 2.4 | post 186.5 | masks 6 | triangles 2 => proc 705.3 ms
# [174/312] frame_00173.png  read 43.4 | infer 132.3 | to_cpu 1.1 | post 187.6 | masks 6 | triangles 2 => proc 321.0 ms
# [175/312] frame_00174.png  read 39.1 | infer 49.7 | to_cpu 0.9 | post 155.5 | masks 5 | triangles 2 => proc 206.0 ms
# [176/312] frame_00175.png  read 41.4 | infer 38.8 | to_cpu 1.1 | post 163.9 | masks 5 | triangles 2 => proc 203.8 ms
# [177/312] frame_00176.png  read 40.6 | infer 44.4 | to_cpu 1.6 | post 152.8 | masks 4 | triangles 2 => proc 198.8 ms
# [178/312] frame_00177.png  read 40.4 | infer 38.1 | to_cpu 0.8 | post 45.8 | masks 4 | triangles 1 => proc 84.7 ms
# [179/312] frame_00178.png  read 38.5 | infer 127.1 | to_cpu 1.2 | post 0.0 | masks 6 | triangles 0 => proc 128.3 ms
# [180/312] frame_00179.png  read 42.7 | infer 47.1 | to_cpu 1.1 | post 0.0 | masks 5 | triangles 0 => proc 48.2 ms
# [181/312] frame_00180.png  read 39.6 | infer 96.1 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 97.1 ms
# [182/312] frame_00181.png  read 39.3 | infer 52.6 | to_cpu 1.2 | post 62.8 | masks 6 | triangles 1 => proc 116.6 ms
# [183/312] frame_00182.png  read 39.4 | infer 59.6 | to_cpu 1.0 | post 167.6 | masks 5 | triangles 2 => proc 228.3 ms
# [184/312] frame_00183.png  read 48.2 | infer 99.6 | to_cpu 1.0 | post 162.1 | masks 4 | triangles 3 => proc 262.7 ms
# [185/312] frame_00184.png  read 38.7 | infer 46.4 | to_cpu 0.8 | post 124.9 | masks 4 | triangles 1 => proc 172.0 ms
# [186/312] frame_00185.png  read 41.9 | infer 40.1 | to_cpu 1.0 | post 129.9 | masks 5 | triangles 1 => proc 171.1 ms
# [187/312] frame_00186.png  read 37.2 | infer 46.9 | to_cpu 1.0 | post 114.7 | masks 3 | triangles 1 => proc 162.6 ms
# [188/312] frame_00187.png  read 41.6 | infer 39.5 | to_cpu 1.7 | post 160.3 | masks 2 | triangles 2 => proc 201.5 ms
# [189/312] frame_00188.png  read 36.7 | infer 30.5 | to_cpu 0.7 | post 154.1 | masks 2 | triangles 2 => proc 185.3 ms
# [190/312] frame_00189.png  read 101.7 | infer 54.1 | to_cpu 0.8 | post 130.6 | masks 3 | triangles 1 => proc 185.5 ms
# [191/312] frame_00190.png  read 50.3 | infer 38.1 | to_cpu 0.9 | post 132.8 | masks 3 | triangles 1 => proc 171.7 ms
# [192/312] frame_00191.png  read 42.4 | infer 48.1 | to_cpu 1.0 | post 130.5 | masks 3 | triangles 1 => proc 179.6 ms
# [193/312] frame_00192.png  read 37.5 | infer 35.5 | to_cpu 0.7 | post 124.8 | masks 3 | triangles 1 => proc 161.1 ms
# [194/312] frame_00193.png  read 38.5 | infer 35.1 | to_cpu 0.7 | post 207.1 | masks 3 | triangles 1 => proc 242.9 ms
# [195/312] frame_00194.png  read 42.0 | infer 33.7 | to_cpu 0.8 | post 167.7 | masks 2 | triangles 2 => proc 202.2 ms
# [196/312] frame_00195.png  read 40.1 | infer 33.8 | to_cpu 0.7 | post 156.0 | masks 2 | triangles 2 => proc 190.5 ms
# [197/312] frame_00196.png  read 39.3 | infer 77.9 | to_cpu 1.4 | post 140.5 | masks 3 | triangles 1 => proc 219.8 ms
# [198/312] frame_00197.png  read 38.9 | infer 41.5 | to_cpu 0.8 | post 130.3 | masks 3 | triangles 1 => proc 172.5 ms
# [199/312] frame_00198.png  read 41.1 | infer 39.5 | to_cpu 0.7 | post 128.5 | masks 3 | triangles 1 => proc 168.7 ms
# [200/312] frame_00199.png  read 39.7 | infer 33.9 | to_cpu 0.8 | post 170.4 | masks 2 | triangles 2 => proc 205.1 ms
# [201/312] frame_00200.png  read 38.7 | infer 43.8 | to_cpu 0.7 | post 174.5 | masks 2 | triangles 2 => proc 218.9 ms
# [202/312] frame_00201.png  read 42.5 | infer 57.2 | to_cpu 0.8 | post 121.8 | masks 3 | triangles 1 => proc 179.9 ms
# [203/312] frame_00202.png  read 40.5 | infer 47.3 | to_cpu 0.7 | post 132.6 | masks 3 | triangles 1 => proc 180.6 ms
# [204/312] frame_00203.png  read 37.2 | infer 42.2 | to_cpu 1.7 | post 138.8 | masks 2 | triangles 2 => proc 182.7 ms
# [205/312] frame_00204.png  read 37.4 | infer 81.6 | to_cpu 0.6 | post 162.2 | masks 1 | triangles 2 => proc 244.4 ms
# [206/312] frame_00205.png  read 40.4 | infer 41.6 | to_cpu 0.8 | post 169.7 | masks 3 | triangles 2 => proc 212.1 ms
# [207/312] frame_00206.png  read 37.6 | infer 33.4 | to_cpu 0.8 | post 160.9 | masks 3 | triangles 2 => proc 195.2 ms
# [208/312] frame_00207.png  read 39.9 | infer 39.6 | to_cpu 0.9 | post 161.6 | masks 2 | triangles 3 => proc 202.1 ms
# [209/312] frame_00208.png  read 36.9 | infer 39.6 | to_cpu 0.7 | post 168.8 | masks 3 | triangles 3 => proc 209.1 ms
# [210/312] frame_00209.png  read 37.2 | infer 46.6 | to_cpu 0.9 | post 159.1 | masks 4 | triangles 3 => proc 206.7 ms
# [211/312] frame_00210.png  read 37.4 | infer 51.3 | to_cpu 0.8 | post 159.1 | masks 4 | triangles 3 => proc 211.3 ms
# [212/312] frame_00211.png  read 39.4 | infer 33.2 | to_cpu 1.0 | post 161.9 | masks 4 | triangles 2 => proc 196.0 ms
# [213/312] frame_00212.png  read 37.1 | infer 32.2 | to_cpu 0.7 | post 264.2 | masks 3 | triangles 3 => proc 297.1 ms
# [214/312] frame_00213.png  read 37.2 | infer 34.0 | to_cpu 0.8 | post 160.2 | masks 3 | triangles 3 => proc 195.0 ms
# [215/312] frame_00214.png  read 38.7 | infer 37.5 | to_cpu 0.8 | post 162.0 | masks 3 | triangles 3 => proc 200.3 ms
# [216/312] frame_00215.png  read 37.9 | infer 41.4 | to_cpu 2.1 | post 160.3 | masks 3 | triangles 2 => proc 203.8 ms
# [217/312] frame_00216.png  read 37.3 | infer 43.6 | to_cpu 0.9 | post 165.5 | masks 5 | triangles 2 => proc 210.0 ms
# [218/312] frame_00217.png  read 41.7 | infer 42.3 | to_cpu 1.4 | post 148.7 | masks 5 | triangles 2 => proc 192.5 ms
# [219/312] frame_00218.png  read 41.7 | infer 43.8 | to_cpu 0.8 | post 150.2 | masks 4 | triangles 2 => proc 194.8 ms
# [220/312] frame_00219.png  read 37.7 | infer 37.1 | to_cpu 0.8 | post 165.2 | masks 3 | triangles 2 => proc 203.1 ms
# [221/312] frame_00220.png  read 42.2 | infer 34.6 | to_cpu 0.8 | post 144.5 | masks 3 | triangles 1 => proc 179.9 ms
# [222/312] frame_00221.png  read 37.5 | infer 37.7 | to_cpu 1.0 | post 114.6 | masks 4 | triangles 1 => proc 153.4 ms
# [223/312] frame_00222.png  read 40.0 | infer 41.1 | to_cpu 1.0 | post 183.4 | masks 4 | triangles 1 => proc 225.5 ms
# [224/312] frame_00223.png  read 37.2 | infer 44.8 | to_cpu 1.3 | post 121.4 | masks 5 | triangles 1 => proc 167.5 ms
# [225/312] frame_00224.png  read 37.1 | infer 41.7 | to_cpu 1.2 | post 121.0 | masks 5 | triangles 1 => proc 163.9 ms
# [226/312] frame_00225.png  read 39.6 | infer 35.0 | to_cpu 0.8 | post 129.3 | masks 3 | triangles 1 => proc 165.1 ms
# [227/312] frame_00226.png  read 43.1 | infer 37.8 | to_cpu 0.7 | post 164.1 | masks 3 | triangles 2 => proc 202.5 ms
# [228/312] frame_00227.png  read 35.9 | infer 49.6 | to_cpu 0.7 | post 157.0 | masks 2 | triangles 2 => proc 207.3 ms
# [229/312] frame_00228.png  read 38.0 | infer 34.7 | to_cpu 0.7 | post 150.7 | masks 2 | triangles 2 => proc 186.1 ms
# [230/312] frame_00229.png  read 35.7 | infer 42.2 | to_cpu 0.9 | post 104.6 | masks 4 | triangles 1 => proc 147.8 ms
# [231/312] frame_00230.png  read 38.6 | infer 34.5 | to_cpu 0.9 | post 117.6 | masks 4 | triangles 1 => proc 153.0 ms
# [232/312] frame_00231.png  read 37.2 | infer 37.9 | to_cpu 0.9 | post 154.2 | masks 5 | triangles 2 => proc 193.0 ms
# [233/312] frame_00232.png  read 36.6 | infer 40.7 | to_cpu 0.8 | post 150.1 | masks 4 | triangles 2 => proc 191.6 ms
# [234/312] frame_00233.png  read 38.3 | infer 36.9 | to_cpu 0.9 | post 143.5 | masks 5 | triangles 2 => proc 181.4 ms
# [235/312] frame_00234.png  read 34.8 | infer 34.8 | to_cpu 0.7 | post 129.9 | masks 3 | triangles 2 => proc 165.4 ms
# [236/312] frame_00235.png  read 33.7 | infer 37.4 | to_cpu 0.7 | post 51.3 | masks 3 | triangles 0 => proc 89.4 ms
# [237/312] frame_00236.png  read 35.6 | infer 33.8 | to_cpu 0.8 | post 0.0 | masks 2 | triangles 0 => proc 34.5 ms
# [238/312] frame_00237.png  read 36.0 | infer 37.4 | to_cpu 0.8 | post 0.0 | masks 3 | triangles 0 => proc 38.2 ms
# [239/312] frame_00238.png  read 34.1 | infer 38.6 | to_cpu 0.7 | post 0.0 | masks 3 | triangles 0 => proc 39.3 ms
# [240/312] frame_00239.png  read 37.9 | infer 39.7 | to_cpu 0.9 | post 51.9 | masks 4 | triangles 1 => proc 92.5 ms
# [241/312] frame_00240.png  read 33.1 | infer 37.4 | to_cpu 0.7 | post 85.6 | masks 3 | triangles 1 => proc 123.8 ms
# [242/312] frame_00241.png  read 36.7 | infer 44.0 | to_cpu 0.7 | post 92.9 | masks 3 | triangles 1 => proc 137.7 ms
# [243/312] frame_00242.png  read 34.6 | infer 39.7 | to_cpu 0.7 | post 101.8 | masks 3 | triangles 1 => proc 142.1 ms
# [244/312] frame_00243.png  read 35.0 | infer 38.1 | to_cpu 0.7 | post 105.6 | masks 2 | triangles 1 => proc 144.5 ms
# [245/312] frame_00244.png  read 34.6 | infer 41.0 | to_cpu 0.8 | post 122.4 | masks 4 | triangles 3 => proc 164.2 ms
# [246/312] frame_00245.png  read 37.4 | infer 80.2 | to_cpu 0.6 | post 149.2 | masks 2 | triangles 2 => proc 230.0 ms
# [247/312] frame_00246.png  read 36.5 | infer 33.0 | to_cpu 0.7 | post 154.2 | masks 2 | triangles 2 => proc 187.9 ms
# [248/312] frame_00247.png  read 39.9 | infer 33.3 | to_cpu 2.6 | post 150.6 | masks 3 | triangles 2 => proc 186.5 ms
# [249/312] frame_00248.png  read 35.6 | infer 37.5 | to_cpu 0.7 | post 154.1 | masks 2 | triangles 2 => proc 192.3 ms
# [250/312] frame_00249.png  read 39.4 | infer 33.2 | to_cpu 0.7 | post 155.7 | masks 2 | triangles 2 => proc 189.5 ms
# [251/312] frame_00250.png  read 39.6 | infer 34.2 | to_cpu 0.7 | post 148.8 | masks 2 | triangles 2 => proc 183.7 ms
# [252/312] frame_00251.png  read 42.3 | infer 35.5 | to_cpu 0.7 | post 120.9 | masks 3 | triangles 1 => proc 157.2 ms
# [253/312] frame_00252.png  read 38.1 | infer 32.1 | to_cpu 0.8 | post 117.5 | masks 4 | triangles 1 => proc 150.4 ms
# [254/312] frame_00253.png  read 39.8 | infer 40.7 | to_cpu 0.8 | post 138.1 | masks 4 | triangles 1 => proc 179.6 ms
# [255/312] frame_00254.png  read 36.1 | infer 32.3 | to_cpu 0.7 | post 153.9 | masks 3 | triangles 2 => proc 186.9 ms
# [256/312] frame_00255.png  read 38.6 | infer 45.6 | to_cpu 1.2 | post 152.2 | masks 3 | triangles 2 => proc 198.9 ms
# [257/312] frame_00256.png  read 36.4 | infer 37.2 | to_cpu 0.9 | post 154.1 | masks 4 | triangles 2 => proc 192.2 ms
# [258/312] frame_00257.png  read 39.6 | infer 33.0 | to_cpu 0.8 | post 152.9 | masks 3 | triangles 2 => proc 186.6 ms
# [259/312] frame_00258.png  read 36.3 | infer 40.7 | to_cpu 0.9 | post 151.5 | masks 5 | triangles 2 => proc 193.1 ms
# [260/312] frame_00259.png  read 44.3 | infer 49.6 | to_cpu 0.9 | post 156.3 | masks 5 | triangles 2 => proc 206.8 ms
# [261/312] frame_00260.png  read 39.2 | infer 51.2 | to_cpu 1.7 | post 150.5 | masks 5 | triangles 2 => proc 203.4 ms
# [262/312] frame_00261.png  read 36.6 | infer 34.9 | to_cpu 0.8 | post 156.3 | masks 3 | triangles 2 => proc 192.0 ms
# [263/312] frame_00262.png  read 42.8 | infer 40.9 | to_cpu 0.9 | post 150.9 | masks 5 | triangles 2 => proc 192.7 ms
# [264/312] frame_00263.png  read 36.8 | infer 36.5 | to_cpu 0.8 | post 151.5 | masks 3 | triangles 2 => proc 188.8 ms
# [265/312] frame_00264.png  read 38.3 | infer 36.6 | to_cpu 0.7 | post 148.1 | masks 3 | triangles 2 => proc 185.4 ms
# [266/312] frame_00265.png  read 36.8 | infer 41.1 | to_cpu 0.8 | post 146.9 | masks 4 | triangles 2 => proc 188.9 ms
# [267/312] frame_00266.png  read 39.6 | infer 37.3 | to_cpu 0.7 | post 148.6 | masks 3 | triangles 2 => proc 186.6 ms
# [268/312] frame_00267.png  read 39.6 | infer 35.3 | to_cpu 0.8 | post 137.5 | masks 3 | triangles 2 => proc 173.6 ms
# [269/312] frame_00268.png  read 43.1 | infer 48.8 | to_cpu 0.9 | post 111.7 | masks 3 | triangles 1 => proc 161.4 ms
# [270/312] frame_00269.png  read 41.3 | infer 34.3 | to_cpu 0.8 | post 92.1 | masks 4 | triangles 1 => proc 127.1 ms
# [271/312] frame_00270.png  read 47.0 | infer 76.6 | to_cpu 0.8 | post 0.0 | masks 2 | triangles 0 => proc 77.4 ms
# [272/312] frame_00271.png  read 41.5 | infer 420.2 | to_cpu 1.0 | post 52.0 | masks 8 | triangles 1 => proc 473.2 ms
# [273/312] frame_00272.png  read 39.3 | infer 35.8 | to_cpu 0.8 | post 75.8 | masks 6 | triangles 2 => proc 112.4 ms
# [274/312] frame_00273.png  read 39.0 | infer 34.4 | to_cpu 1.2 | post 103.7 | masks 8 | triangles 2 => proc 139.3 ms
# [275/312] frame_00274.png  read 42.5 | infer 42.3 | to_cpu 1.0 | post 88.6 | masks 5 | triangles 2 => proc 132.0 ms
# [276/312] frame_00275.png  read 39.9 | infer 85.3 | to_cpu 1.4 | post 66.6 | masks 6 | triangles 1 => proc 153.3 ms
# [277/312] frame_00276.png  read 39.8 | infer 41.9 | to_cpu 1.0 | post 74.5 | masks 7 | triangles 2 => proc 117.5 ms
# [278/312] frame_00277.png  read 37.8 | infer 42.1 | to_cpu 1.2 | post 141.9 | masks 9 | triangles 2 => proc 185.2 ms
# [279/312] frame_00278.png  read 40.7 | infer 35.4 | to_cpu 1.0 | post 134.3 | masks 6 | triangles 2 => proc 170.7 ms
# [280/312] frame_00279.png  read 38.1 | infer 34.3 | to_cpu 0.9 | post 117.9 | masks 5 | triangles 2 => proc 153.1 ms
# [281/312] frame_00280.png  read 37.1 | infer 43.7 | to_cpu 0.9 | post 123.2 | masks 5 | triangles 1 => proc 167.8 ms
# [282/312] frame_00281.png  read 39.7 | infer 41.4 | to_cpu 0.8 | post 144.1 | masks 5 | triangles 2 => proc 186.3 ms
# [283/312] frame_00282.png  read 40.0 | infer 33.1 | to_cpu 0.8 | post 148.4 | masks 5 | triangles 2 => proc 182.3 ms
# [284/312] frame_00283.png  read 37.7 | infer 42.7 | to_cpu 0.8 | post 151.1 | masks 4 | triangles 2 => proc 194.6 ms
# [285/312] frame_00284.png  read 39.7 | infer 38.3 | to_cpu 0.8 | post 153.9 | masks 4 | triangles 2 => proc 193.1 ms
# [286/312] frame_00285.png  read 38.9 | infer 40.7 | to_cpu 0.8 | post 145.5 | masks 4 | triangles 2 => proc 187.0 ms
# [287/312] frame_00286.png  read 37.6 | infer 41.4 | to_cpu 1.0 | post 146.9 | masks 4 | triangles 2 => proc 189.3 ms
# [288/312] frame_00287.png  read 36.8 | infer 43.6 | to_cpu 0.7 | post 47.4 | masks 3 | triangles 1 => proc 91.7 ms
# [289/312] frame_00288.png  read 44.5 | infer 162.2 | to_cpu 1.0 | post 0.0 | masks 6 | triangles 0 => proc 163.2 ms
# [290/312] frame_00289.png  read 41.5 | infer 94.3 | to_cpu 1.2 | post 0.0 | masks 8 | triangles 0 => proc 95.4 ms
# [291/312] frame_00290.png  read 38.6 | infer 77.6 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 78.7 ms
# [292/312] frame_00291.png  read 40.6 | infer 82.3 | to_cpu 1.0 | post 0.0 | masks 7 | triangles 0 => proc 83.3 ms
# [293/312] frame_00292.png  read 45.9 | infer 45.4 | to_cpu 1.0 | post 0.0 | masks 7 | triangles 0 => proc 46.4 ms
# [294/312] frame_00293.png  read 37.8 | infer 40.4 | to_cpu 1.2 | post 0.0 | masks 7 | triangles 0 => proc 41.5 ms
# [295/312] frame_00294.png  read 44.7 | infer 53.3 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 54.4 ms
# [296/312] frame_00295.png  read 37.9 | infer 77.6 | to_cpu 0.9 | post 0.0 | masks 8 | triangles 0 => proc 78.5 ms
# [297/312] frame_00296.png  read 48.1 | infer 45.4 | to_cpu 1.2 | post 0.0 | masks 7 | triangles 0 => proc 46.6 ms
# [298/312] frame_00297.png  read 39.4 | infer 80.8 | to_cpu 1.1 | post 0.0 | masks 7 | triangles 0 => proc 81.9 ms
# [299/312] frame_00298.png  read 40.1 | infer 48.8 | to_cpu 1.1 | post 0.0 | masks 6 | triangles 0 => proc 49.9 ms
# [300/312] frame_00299.png  read 43.0 | infer 83.3 | to_cpu 1.1 | post 0.0 | masks 7 | triangles 0 => proc 84.4 ms
# [301/312] frame_00300.png  read 40.5 | infer 44.3 | to_cpu 1.3 | post 0.0 | masks 6 | triangles 0 => proc 45.6 ms
# [302/312] frame_00301.png  read 47.1 | infer 47.4 | to_cpu 0.9 | post 0.0 | masks 6 | triangles 0 => proc 48.3 ms
# [303/312] frame_00302.png  read 37.0 | infer 41.7 | to_cpu 2.2 | post 0.0 | masks 7 | triangles 0 => proc 43.9 ms
# [304/312] frame_00303.png  read 57.1 | infer 87.6 | to_cpu 1.4 | post 0.0 | masks 8 | triangles 0 => proc 89.0 ms
# [305/312] frame_00304.png  read 56.0 | infer 36.9 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 38.0 ms
# [306/312] frame_00305.png  read 37.6 | infer 35.5 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 36.6 ms
# [307/312] frame_00306.png  read 37.5 | infer 80.9 | to_cpu 1.2 | post 0.0 | masks 7 | triangles 0 => proc 82.0 ms
# [308/312] frame_00307.png  read 18.6 | infer 24.0 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 24.0 ms
# [309/312] frame_00308.png  read 17.5 | infer 37.6 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 37.6 ms
# [310/312] frame_00309.png  read 18.5 | infer 21.8 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 21.8 ms
# [311/312] frame_00310.png  read 17.1 | infer 21.4 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 21.4 ms
# [312/312] frame_00311.png  read 17.2 | infer 22.5 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 22.5 ms

# %%
#Speed optimised version of code above. Optimal function as of 10-08-2025 -> 12:31am

# %%
#!/usr/bin/env python3
# Ultra-fast overlays + lane-aware curved sampling (optimized postproc)

import os, glob, time, math
import cv2, torch, numpy as np
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from ultralytics import YOLO

# =======================
# Config
# =======================
home       = os.path.expanduser("~")
weights    = f"{home}/models/jakes-loped/jakes-finder-mk1/1/weights.pt"
frames_dir = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "frames"

# SAVE HERE
out_dir    = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "out_overlays6"
out_dir.mkdir(parents=True, exist_ok=True)

RAIL_ID    = 9
IMG_SIZE   = 512
CONF, IOU  = 0.30, 0.45
MAX_DET    = 30

# Color/region filter
TARGET_COLORS_RGB  = [(119,104,67), (81,42,45)]
TOLERANCE          = 20.0
MIN_REGION_SIZE    = 30
MIN_REGION_HEIGHT  = 150

# Heat/triangle
HEAT_BLUR_KSIZE     = 51
RED_SCORE_THRESH    = 220
EXCLUDE_TOP_FRAC    = 0.40
EXCLUDE_BOTTOM_FRAC = 0.15
MIN_DARK_RED_AREA   = 1200
MIN_DARK_FRACTION   = 0.15
TRI_SIZE_PX         = 18

# Sampling ray length
SAMPLE_UP_PX        = 180

# ===== Bend degrees (tune here) =====
BEND_LEFT_STATE_RIGHT_DEG  = -20.0  # N1
BEND_MID_STATE_RIGHT_DEG   = -20.0  # N2
BEND_MID_STATE_LEFT_DEG    = +20.0  # N3
BEND_RIGHT_STATE_LEFT_DEG  = +20.0  # N4

# Colours (BGR)
COLOR_GREEN  = (0, 255, 0)
COLOR_PINK   = (203, 192, 255)
COLOR_YELLOW = (0, 255, 255)
COLOR_RED    = (0, 0, 255)
COLOR_WHITE  = (255, 255, 255)
COLOR_CYAN   = (255, 255, 0)
COLOR_BLACK  = (0, 0, 0)

# Runtime
THREADS_IO          = max(2, (os.cpu_count() or 4) // 2)
SHOW_FIRST_N        = None
RENDER_FIRST_N      = 300

# =======================
# Jake lane points
# =======================
LANE_LEFT   = (300, 1340)
LANE_MID    = (490, 1340)
LANE_RIGHT  = (680, 1340)
JAKE_POINT  = LANE_RIGHT  # pick: LANE_LEFT / LANE_MID / LANE_RIGHT

LANE_TARGET_DEG = {"left": -10.7, "mid": +1.5, "right": +15.0}

def lane_name_from_point(p):
    if p == LANE_LEFT:  return "left"
    if p == LANE_MID:   return "mid"
    if p == LANE_RIGHT: return "right"
    return "mid"

# =======================
# System/Backends
# =======================
cv2.setUseOptimized(True)
try: cv2.setNumThreads(max(1, (os.cpu_count() or 1) - 1))
except Exception: pass

if torch.cuda.is_available():
    device, half = 0, True
    torch.backends.cudnn.benchmark = True
    try: torch.set_float32_matmul_precision('high')
    except Exception: pass
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device, half = "mps", False
else:
    device, half = "cpu", False

# =======================
# Model
# =======================
model = YOLO(weights)
try: model.fuse()
except Exception: pass

_dummy = np.zeros((IMG_SIZE, IMG_SIZE, 3), np.uint8)
_ = model.predict(_dummy, task="segment", imgsz=IMG_SIZE, device=device,
                  conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET)

# =======================
# Precomputed
# =======================
TARGETS_BGR_F32 = np.array([(r,g,b)[::-1] for (r,g,b) in TARGET_COLORS_RGB], dtype=np.float32)
TOL2            = TOLERANCE * TOLERANCE
SAFE_GREEN      = {9, 10}
WARN_YELLOW     = {2,3,4,5,8}

CLASS_COLOURS = {
    0:(255,255,0),1:(192,192,192),2:(0,128,255),3:(0,255,0),
    4:(255,0,255),5:(0,255,255),6:(255,128,0),7:(128,0,255),
    8:(0,0,128),9:(0,0,255),10:(128,128,0),11:(255,255,102)
}
LABELS = {
    0:"BOOTS",1:"GREYTRAIN",2:"HIGHBARRIER1",3:"JUMP",4:"LOWBARRIER1",
    5:"LOWBARRIER2",6:"ORANGETRAIN",7:"PILLAR",8:"RAMP",9:"RAILS",
    10:"SIDEWALK",11:"YELLOWTRAIN"
}

# ====== tiny helpers ======
def _clampi(v, lo, hi):
    return lo if v < lo else (hi if v > hi else v)

def load_image_with_time(path: str):
    t0 = time.perf_counter()
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    return img, (time.perf_counter() - t0) * 1000.0

def chunked(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

# =======================
# Fast rails green finder
# =======================
def highlight_rails_mask_only_fast(img_bgr, rail_mask):
    # Expect rail_mask as bool (H,W)
    H, W = rail_mask.shape
    if not rail_mask.any():
        return np.zeros((H, W), dtype=bool)

    # Fast bbox via boundingRect on a uint8 view
    rail_u8 = rail_mask.view(dtype=np.uint8) * 255
    x, y, w, h = cv2.boundingRect(rail_u8)
    img_roi  = img_bgr[y:y+h, x:x+w]
    mask_roi = rail_u8[y:y+h, x:x+w]  # uint8 0/255

    img_f = img_roi.astype(np.float32, copy=False)
    # dist^2 to each target color (BGR)
    diff  = img_f[:, :, None, :] - TARGETS_BGR_F32[None, None, :, :]
    dist2 = (diff * diff).sum(-1)
    colour_hit = (dist2 <= TOL2).any(-1)

    # inside rail AND close to target colors
    combined = np.logical_and(colour_hit, mask_roi.astype(bool))

    # blobs filter by area & height (use CC with stats inside ROI only)
    comp = combined.astype(np.uint8)
    n, lbls, stats, _ = cv2.connectedComponentsWithStats(comp, 8)
    if n <= 1:
        return np.zeros((H, W), dtype=bool)

    good = np.zeros_like(combined)
    # stats: [label, x, y, w, h, area] -> OpenCV layout
    areas = stats[1:, cv2.CC_STAT_AREA]
    hs    = stats[1:, cv2.CC_STAT_HEIGHT]
    keep  = np.where((areas >= MIN_REGION_SIZE) & (hs >= MIN_REGION_HEIGHT))[0] + 1
    for k in keep:
        good[lbls == k] = True

    full = np.zeros((H, W), dtype=bool)
    full[y:y+h, x:x+w] = good
    return full

def red_vs_green_score(red_mask, green_mask):
    # both masks already bool in frame space
    k = (HEAT_BLUR_KSIZE, HEAT_BLUR_KSIZE)
    r = cv2.blur(red_mask.astype(np.float32, copy=False), k)
    g = cv2.blur(green_mask.astype(np.float32, copy=False), k)
    diff = r - g
    amax = float(np.max(np.abs(diff))) + 1e-6
    norm = (diff / (2.0 * amax) + 0.5)
    return np.clip(norm * 255.0, 0, 255.0).astype(np.uint8, copy=False)

def purple_triangles(score, H):
    top_ex = int(H * EXCLUDE_TOP_FRAC)
    bot_ex = int(H * EXCLUDE_BOTTOM_FRAC)
    dark = (score >= RED_SCORE_THRESH).astype(np.uint8, copy=False)
    if top_ex: dark[:top_ex, :] = 0
    if bot_ex: dark[-bot_ex:, :] = 0

    dark = cv2.morphologyEx(
        dark, cv2.MORPH_OPEN,
        cv2.getStructuringElement(cv2.MORPH_RECT, (5, 9)), iterations=1
    )
    total_dark = int(dark.sum())
    if total_dark == 0:
        return [], None

    frac_thresh = int(np.ceil(MIN_DARK_FRACTION * total_dark))
    n_lbl, lbls, stats, _ = cv2.connectedComponentsWithStats(dark, 8)
    if n_lbl <= 1:
        return [], None

    tris = []
    for lbl in range(1, n_lbl):
        area = stats[lbl, cv2.CC_STAT_AREA]
        if area >= MIN_DARK_RED_AREA and area >= frac_thresh:
            ys, xs = np.where(lbls == lbl)
            if ys.size == 0: continue
            y_top = ys.min()
            x_mid = int(xs[ys == y_top].mean())
            tris.append((x_mid, int(y_top)))

    if not tris:
        return [], None
    best = min(tris, key=lambda xy: xy[1])
    return tris, best

# ===== Bearing-based Jake triangle selection =====
def signed_degrees_from_vertical(dx, dy):
    if dx == 0 and dy == 0: return 0.0
    return -math.degrees(math.atan2(dx, -dy))

def select_triangle_by_bearing(tri_positions, jx, jy, target_deg, min_dy=6):
    best_i, best_deg, best_err = -1, None, None
    for i, (xt, yt) in enumerate(tri_positions):
        dy = yt - jy
        if dy >= -min_dy:  # must be above Jake
            continue
        deg = signed_degrees_from_vertical(xt - jx, dy)
        err = abs(deg - target_deg)
        if (best_err is None) or (err < best_err):
            best_i, best_deg, best_err = i, deg, err
    return best_i, best_deg, best_err

# ===== Lane-aware curved sampling (precompute sin/cos) =====
def _precompute_trig():
    # unique angle set includes 0°, N1, N2, N3, N4 (duplicates folded by set)
    angles = sorted(set([0.0,
        BEND_LEFT_STATE_RIGHT_DEG,
        BEND_MID_STATE_RIGHT_DEG,
        BEND_MID_STATE_LEFT_DEG,
        BEND_RIGHT_STATE_LEFT_DEG
    ]))
    table = {}
    for a in angles:
        r = math.radians(a)
        table[a] = (math.sin(r), -math.cos(r))  # (dx, dy) for unit ray (up = -y)
    return table
TRIG_TABLE = _precompute_trig()

def pick_bend_angle(jake_point, xt, x_ref, idx, best_idx):
    if idx == best_idx:
        return 0.0
    if jake_point == LANE_LEFT:
        return BEND_LEFT_STATE_RIGHT_DEG if xt > x_ref else 0.0
    if jake_point == LANE_RIGHT:
        return BEND_RIGHT_STATE_LEFT_DEG if xt < x_ref else 0.0
    # mid lane: right of JakeTri bends left (N2), left bends right (N3)
    if xt > x_ref: return BEND_MID_STATE_RIGHT_DEG
    if xt < x_ref: return BEND_MID_STATE_LEFT_DEG
    return 0.0

def classify_triangles_at_sample_curved(
    tri_positions, masks_np, classes_np, H, W,
    jake_point, x_ref, best_idx, sample_px=SAMPLE_UP_PX
):
    if masks_np is None or classes_np is None or len(tri_positions) == 0:
        return [], []

    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (W - 1))
    sy = (mh - 1) / max(1, (H - 1))

    colours, rays = [], []
    # fast refs
    SAFE, WARN = SAFE_GREEN, WARN_YELLOW
    for idx, (x, y) in enumerate(tri_positions):
        theta = pick_bend_angle(jake_point, x, x_ref, idx, best_idx)
        dx1, dy1 = TRIG_TABLE[theta]  # unit direction
        xs = int(round(x + dx1 * sample_px))
        ys = int(round(y + dy1 * sample_px))
        xs = _clampi(xs, 0, W-1); ys = _clampi(ys, 0, H-1)

        mx = int(round(xs * sx)); my = int(round(ys * sy))
        mx = _clampi(mx, 0, mw-1); my = _clampi(my, 0, mh-1)

        cls_here = None
        for m, c in zip(masks_np, classes_np):
            if m[my, mx] > 0.5:
                cls_here = int(c); break

        if (cls_here is None) or (cls_here in SAFE):
            colours.append(COLOR_GREEN)
        elif cls_here == 0:
            colours.append(COLOR_PINK)
        elif cls_here in WARN:
            colours.append(COLOR_YELLOW)
        else:
            colours.append(COLOR_RED)

        rays.append(((int(x), int(y)), (xs, ys), float(theta)))

    return colours, rays

# =======================
# Frame post-processing
# =======================
def process_frame_post(frame_bgr, yolo_res):
    H, W = frame_bgr.shape[:2]
    if yolo_res.masks is None:
        return None, 0, 0, 0.0, 0.0, None, None, None, None, [], [], [], None, None, None

    t0 = time.perf_counter()
    masks_np = yolo_res.masks.data.detach().cpu().numpy()  # [n,h,w]
    if hasattr(yolo_res.masks, "cls") and yolo_res.masks.cls is not None:
        classes_np = yolo_res.masks.cls.detach().cpu().numpy().astype(int)
    else:
        classes_np = yolo_res.boxes.cls.detach().cpu().numpy().astype(int)
    to_cpu_ms = (time.perf_counter() - t0) * 1000.0
    mask_count = int(masks_np.shape[0])
    if mask_count == 0 or classes_np.size == 0:
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    rail_sel = (classes_np == RAIL_ID)
    if not np.any(rail_sel):
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    t1 = time.perf_counter()
    rail_masks = masks_np[rail_sel].astype(bool, copy=False)
    union = np.any(rail_masks, axis=0).astype(np.uint8, copy=False)
    rail_mask = cv2.resize(union, (W, H), interpolation=cv2.INTER_NEAREST).astype(bool, copy=False)

    green = highlight_rails_mask_only_fast(frame_bgr, rail_mask)
    red   = np.logical_and(rail_mask, np.logical_not(green))
    score = red_vs_green_score(red, green)
    tri_positions, tri_best = purple_triangles(score, H)

    # Jake triangle by bearing
    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    xj, yj = JAKE_POINT
    best_idx, best_deg, _ = select_triangle_by_bearing(tri_positions, xj, yj, target_deg, min_dy=6)

    # x_ref for bending
    if lane_name == "mid" and (best_idx is not None) and (0 <= best_idx < len(tri_positions)):
        x_ref = tri_positions[best_idx][0]
    else:
        x_ref = xj

    tri_colours, tri_rays = classify_triangles_at_sample_curved(
        tri_positions, masks_np, classes_np, H, W, JAKE_POINT, x_ref, best_idx, SAMPLE_UP_PX
    )
    post_ms = (time.perf_counter() - t1) * 1000.0

    return tri_best, len(tri_positions), mask_count, to_cpu_ms, post_ms, masks_np, classes_np, rail_mask, green, tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref

# =======================
# Viz helpers
# =======================
def _colour_for_point(x, y, masks_np, classes_np, H, W):
    if masks_np is None or classes_np is None or masks_np.size == 0: return COLOR_GREEN
    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (W - 1)); sy = (mh - 1) / max(1, (H - 1))
    mx = _clampi(int(round(x * sx)), 0, mw-1)
    my = _clampi(int(round(y * sy)), 0, mh-1)
    cls_here = None
    for m, c in zip(masks_np, classes_np):
        if m[my, mx] > 0.5: cls_here = int(c); break
    if (cls_here is None) or (cls_here in SAFE_GREEN): return COLOR_GREEN
    if cls_here == 0: return COLOR_PINK
    if cls_here in WARN_YELLOW: return COLOR_YELLOW
    return COLOR_RED

def draw_triangle(img, x, y, size=TRI_SIZE_PX, colour=COLOR_RED):
    h = int(size * 1.2)
    pts = np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)
    cv2.fillConvexPoly(img, pts, colour)
    cv2.polylines(img, [pts.reshape(-1,1,2)], True, COLOR_BLACK, 1, cv2.LINE_AA)

def triangle_pts(x, y, size=TRI_SIZE_PX):
    h = int(size * 1.2)
    return np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)

def render_overlays(frame_bgr, masks_np, classes_np, rail_mask, green_mask,
                    tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref):
    out = frame_bgr.copy()
    H, W = out.shape[:2]
    alpha = 0.45

    if masks_np is not None and classes_np is not None and masks_np.size:
        for m, c in zip(masks_np, classes_np):
            m_full = m
            if m.shape != (H, W):
                m_full = cv2.resize(m.astype(np.uint8), (W, H), interpolation=cv2.INTER_NEAREST).astype(bool)
            color = CLASS_COLOURS.get(int(c), (255,255,255))
            out[m_full] = (np.array(color, dtype=np.uint8) * alpha + out[m_full] * (1 - alpha)).astype(np.uint8)
            ys, xs = np.where(m_full)
            if xs.size:
                xc, yc = int(xs.mean()), int(ys.mean())
                label = LABELS.get(int(c), f"C{int(c)}")
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, COLOR_BLACK, 2, cv2.LINE_AA)
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1, cv2.LINE_AA)

    if rail_mask is not None:
        tint = out.copy()
        tint[rail_mask] = (0, 0, 255)
        out = cv2.addWeighted(tint, 0.30, out, 0.70, 0)
    if green_mask is not None:
        out[green_mask] = (0, 255, 0)

    # tiny scout lines
    if tri_positions:
        for (x, y) in tri_positions:
            y_end = max(0, y - SAMPLE_UP_PX)
            for yy in range(y, y_end - 1, -1):
                out[yy, x] = _colour_for_point(x, yy, masks_np, classes_np, H, W)

    # starburst to Jake
    xj, yj = JAKE_POINT
    for idx, (xt, yt) in enumerate(tri_positions):
        xt = _clampi(int(xt), 0, W-1); yt = _clampi(int(yt), 0, H-1)
        deg_signed = signed_degrees_from_vertical(xt - xj, yt - yj)
        cv2.line(out, (xj, yj), (xt, yt),
                 COLOR_CYAN if idx == best_idx else COLOR_WHITE, 2, cv2.LINE_AA)
        mx = (xj + xt) // 2; my = (yj + yt) // 2
        txt = f"{deg_signed:.1f}°"
        cv2.putText(out, txt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, txt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    # curved sampling rays
    for (p0, p1, theta) in tri_rays:
        cv2.line(out, p0, p1, (255,255,255), 2, cv2.LINE_AA)
        mx = (p0[0] + p1[0]) // 2; my = (p0[1] + p1[1]) // 2
        ttxt = f"{theta:+.1f}°"
        cv2.putText(out, ttxt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, ttxt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    for (x, y), col in zip(tri_positions, tri_colours):
        draw_triangle(out, int(x), int(y), colour=col)

    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    if best_idx is not None and 0 <= best_idx < len(tri_positions):
        xt, yt = tri_positions[best_idx]
        pts = triangle_pts(int(xt), int(yt), size=TRI_SIZE_PX)
        cv2.polylines(out, [pts.reshape(-1,1,2)], True, COLOR_CYAN, 3, cv2.LINE_AA)
        tag = f"JAKE_TRI ({lane_name}: target {target_deg:.1f}°)"
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)
    return out

# =======================
# Run
# =======================
def run_pipeline_with_prints_and_overlays():
    paths = (
        glob.glob(str(frames_dir/"frame_*.jpg")) +
        glob.glob(str(frames_dir/"frame_*.png")) +
        glob.glob(str(frames_dir/"*.jpg")) +
        glob.glob(str(frames_dir/"*.png"))
    )
    paths = sorted(set(paths))
    if not paths:
        raise FileNotFoundError(f"No images in: {frames_dir}")
    if SHOW_FIRST_N is not None:
        paths = paths[:SHOW_FIRST_N]

    N = len(paths)

    def load_batch(batch_paths):
        imgs, read_ms = [None]*len(batch_paths), [0.0]*len(batch_paths)
        with ThreadPoolExecutor(max_workers=THREADS_IO) as ex:
            fut2i = {ex.submit(load_image_with_time, p): i for i, p in enumerate(batch_paths)}
            for fut in as_completed(fut2i):
                i = fut2i[fut]
                im, r = fut.result()
                imgs[i] = im; read_ms[i] = r
        ok = [(p, im, rm) for p, im, rm in zip(batch_paths, imgs, read_ms) if im is not None]
        if not ok: return [], [], []
        b_paths, b_imgs, b_read = zip(*ok)
        return list(b_paths), list(b_imgs), list(b_read)

    idx_global = 0
    for batch_paths in chunked(paths, 1):
        batch_paths, imgs_bgr, read_ms_list = load_batch(batch_paths)
        if not imgs_bgr:
            idx_global += len(batch_paths); continue

        t0_inf = time.perf_counter()
        res_list = model.predict(
            imgs_bgr, task="segment", imgsz=IMG_SIZE, device=device,
            conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET, batch=1
        )
        try:
            if device == 0 and torch.cuda.is_available(): torch.cuda.synchronize()
            elif device == "mps" and getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
                torch.mps.synchronize()
        except Exception: pass
        infer_ms_share = (time.perf_counter() - t0_inf) * 1000.0

        for j, (img, yres, read_ms) in enumerate(zip(imgs_bgr, res_list, read_ms_list)):
            (tri_best_xy, tri_count, mask_count, to_cpu_ms, post_ms,
             masks_np, classes_np, rail_mask, green_mask, tri_positions, tri_colours,
             tri_rays, best_idx, best_deg, x_ref) = process_frame_post(img, yres)

            proc_ms = infer_ms_share + to_cpu_ms + post_ms
            fname = os.path.basename(batch_paths[j])
            frame_idx = idx_global + j + 1

            print(f"[{frame_idx}/{N}] {fname}  "
                  f"read {read_ms:.1f} | infer {infer_ms_share:.1f} | "
                  f"to_cpu {to_cpu_ms:.1f} | post {post_ms:.1f} | "
                  f"masks {mask_count} | triangles {tri_count} "
                  f"=> proc {proc_ms:.1f} ms")

            if frame_idx <= RENDER_FIRST_N:
                overlay = render_overlays(img, masks_np, classes_np, rail_mask, green_mask,
                                          tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref)
                out_path = out_dir / f"overlay_{frame_idx:04d}_{fname}"
                cv2.imwrite(str(out_path), overlay)

        idx_global += 1

# =======================
# Entry
# =======================
if __name__ == "__main__":
    run_pipeline_with_prints_and_overlays()
# Out:
# YOLO11n-seg summary (fused): 113 layers, 2,836,908 parameters, 0 gradients, 10.2 GFLOPs
# [1/312] frame_00000.png  read 42.6 | infer 111.3 | to_cpu 1.2 | post 0.0 | masks 1 | triangles 0 => proc 112.6 ms
# [2/312] frame_00001.png  read 43.0 | infer 50.9 | to_cpu 0.9 | post 109.6 | masks 3 | triangles 1 => proc 161.4 ms
# [3/312] frame_00002.png  read 42.9 | infer 56.0 | to_cpu 0.8 | post 148.7 | masks 3 | triangles 3 => proc 205.5 ms
# [4/312] frame_00003.png  read 50.3 | infer 66.2 | to_cpu 1.2 | post 133.2 | masks 3 | triangles 2 => proc 200.5 ms
# [5/312] frame_00004.png  read 47.3 | infer 47.0 | to_cpu 0.8 | post 187.5 | masks 4 | triangles 1 => proc 235.3 ms
# [6/312] frame_00005.png  read 68.6 | infer 232.2 | to_cpu 2.4 | post 343.4 | masks 5 | triangles 1 => proc 578.0 ms
# [7/312] frame_00006.png  read 84.1 | infer 100.3 | to_cpu 1.3 | post 339.9 | masks 5 | triangles 2 => proc 441.6 ms
# [8/312] frame_00007.png  read 47.2 | infer 54.5 | to_cpu 0.9 | post 198.5 | masks 4 | triangles 2 => proc 253.9 ms
# [9/312] frame_00008.png  read 41.0 | infer 43.2 | to_cpu 0.8 | post 148.5 | masks 5 | triangles 2 => proc 192.5 ms
# [10/312] frame_00009.png  read 83.0 | infer 114.6 | to_cpu 2.2 | post 395.1 | masks 4 | triangles 2 => proc 511.9 ms
# [11/312] frame_00010.png  read 78.8 | infer 75.5 | to_cpu 1.3 | post 306.8 | masks 4 | triangles 2 => proc 383.6 ms
# [12/312] frame_00011.png  read 58.6 | infer 59.4 | to_cpu 0.8 | post 214.3 | masks 3 | triangles 3 => proc 274.5 ms
# [13/312] frame_00012.png  read 47.5 | infer 60.6 | to_cpu 0.8 | post 228.0 | masks 3 | triangles 3 => proc 289.4 ms
# [14/312] frame_00013.png  read 41.5 | infer 62.6 | to_cpu 1.0 | post 270.3 | masks 3 | triangles 3 => proc 333.8 ms
# [15/312] frame_00014.png  read 73.6 | infer 73.5 | to_cpu 1.1 | post 388.2 | masks 4 | triangles 2 => proc 462.8 ms
# [16/312] frame_00015.png  read 47.4 | infer 51.1 | to_cpu 1.0 | post 199.4 | masks 5 | triangles 2 => proc 251.6 ms
# [17/312] frame_00016.png  read 42.9 | infer 38.5 | to_cpu 0.8 | post 152.8 | masks 4 | triangles 2 => proc 192.1 ms
# [18/312] frame_00017.png  read 51.3 | infer 47.5 | to_cpu 1.0 | post 182.0 | masks 4 | triangles 2 => proc 230.4 ms
# [19/312] frame_00018.png  read 84.1 | infer 105.0 | to_cpu 1.1 | post 298.0 | masks 4 | triangles 2 => proc 404.1 ms
# [20/312] frame_00019.png  read 57.5 | infer 62.6 | to_cpu 1.0 | post 196.3 | masks 3 | triangles 2 => proc 260.0 ms
# [21/312] frame_00020.png  read 46.8 | infer 38.7 | to_cpu 0.7 | post 141.1 | masks 3 | triangles 1 => proc 180.6 ms
# [22/312] frame_00021.png  read 37.9 | infer 41.0 | to_cpu 0.8 | post 121.4 | masks 4 | triangles 1 => proc 163.2 ms
# [23/312] frame_00022.png  read 40.9 | infer 43.5 | to_cpu 0.9 | post 119.9 | masks 4 | triangles 1 => proc 164.2 ms
# [24/312] frame_00023.png  read 53.1 | infer 53.7 | to_cpu 1.3 | post 135.7 | masks 4 | triangles 1 => proc 190.7 ms
# [25/312] frame_00024.png  read 48.7 | infer 65.1 | to_cpu 0.9 | post 131.9 | masks 4 | triangles 1 => proc 197.9 ms
# [26/312] frame_00025.png  read 52.8 | infer 50.8 | to_cpu 1.0 | post 131.2 | masks 4 | triangles 1 => proc 183.0 ms
# [27/312] frame_00026.png  read 68.3 | infer 79.7 | to_cpu 1.3 | post 126.4 | masks 5 | triangles 1 => proc 207.4 ms
# [28/312] frame_00027.png  read 52.3 | infer 51.6 | to_cpu 0.9 | post 86.8 | masks 3 | triangles 1 => proc 139.4 ms
# [29/312] frame_00028.png  read 48.3 | infer 61.9 | to_cpu 1.7 | post 52.5 | masks 5 | triangles 1 => proc 116.1 ms
# [30/312] frame_00029.png  read 36.9 | infer 723.7 | to_cpu 1.9 | post 64.7 | masks 6 | triangles 1 => proc 790.2 ms
# [31/312] frame_00030.png  read 54.2 | infer 84.5 | to_cpu 1.1 | post 180.2 | masks 6 | triangles 2 => proc 265.8 ms
# [32/312] frame_00031.png  read 46.0 | infer 54.6 | to_cpu 0.9 | post 110.9 | masks 6 | triangles 1 => proc 166.4 ms
# [33/312] frame_00032.png  read 47.7 | infer 42.9 | to_cpu 1.0 | post 162.6 | masks 5 | triangles 1 => proc 206.4 ms
# [34/312] frame_00033.png  read 57.2 | infer 44.2 | to_cpu 0.7 | post 138.8 | masks 3 | triangles 2 => proc 183.7 ms
# [35/312] frame_00034.png  read 40.7 | infer 52.9 | to_cpu 0.8 | post 133.7 | masks 4 | triangles 2 => proc 187.4 ms
# [36/312] frame_00035.png  read 37.8 | infer 49.2 | to_cpu 2.3 | post 120.7 | masks 4 | triangles 1 => proc 172.2 ms
# [37/312] frame_00036.png  read 39.7 | infer 38.3 | to_cpu 0.8 | post 144.3 | masks 3 | triangles 2 => proc 183.3 ms
# [38/312] frame_00037.png  read 39.7 | infer 45.8 | to_cpu 0.8 | post 133.6 | masks 3 | triangles 1 => proc 180.1 ms
# [39/312] frame_00038.png  read 39.3 | infer 33.1 | to_cpu 1.8 | post 115.9 | masks 4 | triangles 1 => proc 150.9 ms
# [40/312] frame_00039.png  read 37.0 | infer 47.5 | to_cpu 2.1 | post 130.1 | masks 4 | triangles 1 => proc 179.7 ms
# [41/312] frame_00040.png  read 45.0 | infer 41.4 | to_cpu 0.7 | post 142.2 | masks 3 | triangles 1 => proc 184.2 ms
# [42/312] frame_00041.png  read 46.7 | infer 49.3 | to_cpu 0.8 | post 108.5 | masks 3 | triangles 1 => proc 158.5 ms
# [43/312] frame_00042.png  read 43.0 | infer 36.0 | to_cpu 1.9 | post 119.0 | masks 5 | triangles 1 => proc 156.8 ms
# [44/312] frame_00043.png  read 39.2 | infer 44.4 | to_cpu 1.1 | post 125.5 | masks 5 | triangles 2 => proc 171.0 ms
# [45/312] frame_00044.png  read 39.4 | infer 36.7 | to_cpu 0.8 | post 119.6 | masks 4 | triangles 2 => proc 157.1 ms
# [46/312] frame_00045.png  read 37.4 | infer 38.4 | to_cpu 0.6 | post 151.6 | masks 3 | triangles 2 => proc 190.5 ms
# [47/312] frame_00046.png  read 39.5 | infer 36.0 | to_cpu 0.7 | post 142.6 | masks 3 | triangles 1 => proc 179.4 ms
# [48/312] frame_00047.png  read 36.4 | infer 34.8 | to_cpu 1.8 | post 118.5 | masks 3 | triangles 1 => proc 155.1 ms
# [49/312] frame_00048.png  read 40.4 | infer 37.1 | to_cpu 0.8 | post 153.0 | masks 3 | triangles 2 => proc 190.9 ms
# [50/312] frame_00049.png  read 37.1 | infer 46.9 | to_cpu 0.8 | post 149.3 | masks 2 | triangles 2 => proc 197.0 ms
# [51/312] frame_00050.png  read 37.1 | infer 37.5 | to_cpu 0.7 | post 155.3 | masks 2 | triangles 2 => proc 193.4 ms
# [52/312] frame_00051.png  read 40.8 | infer 39.2 | to_cpu 0.7 | post 151.6 | masks 2 | triangles 2 => proc 191.5 ms
# [53/312] frame_00052.png  read 37.3 | infer 41.8 | to_cpu 0.7 | post 145.1 | masks 2 | triangles 2 => proc 187.6 ms
# [54/312] frame_00053.png  read 39.4 | infer 39.6 | to_cpu 0.7 | post 123.7 | masks 2 | triangles 1 => proc 164.0 ms
# [55/312] frame_00054.png  read 36.7 | infer 35.5 | to_cpu 2.8 | post 118.6 | masks 4 | triangles 1 => proc 156.9 ms
# [56/312] frame_00055.png  read 40.1 | infer 40.2 | to_cpu 0.7 | post 117.8 | masks 4 | triangles 1 => proc 158.7 ms
# [57/312] frame_00056.png  read 36.1 | infer 40.8 | to_cpu 2.9 | post 121.0 | masks 4 | triangles 1 => proc 164.6 ms
# [58/312] frame_00057.png  read 40.2 | infer 34.5 | to_cpu 0.8 | post 115.6 | masks 4 | triangles 1 => proc 150.9 ms
# [59/312] frame_00058.png  read 37.0 | infer 40.7 | to_cpu 0.9 | post 113.3 | masks 5 | triangles 1 => proc 154.8 ms
# [60/312] frame_00059.png  read 42.0 | infer 40.3 | to_cpu 0.9 | post 115.6 | masks 4 | triangles 1 => proc 156.7 ms
# [61/312] frame_00060.png  read 36.6 | infer 35.2 | to_cpu 1.1 | post 109.1 | masks 5 | triangles 1 => proc 145.4 ms
# [62/312] frame_00061.png  read 40.8 | infer 34.6 | to_cpu 1.0 | post 108.7 | masks 4 | triangles 1 => proc 144.3 ms
# [63/312] frame_00062.png  read 36.8 | infer 380.6 | to_cpu 0.9 | post 155.3 | masks 6 | triangles 2 => proc 536.9 ms
# [64/312] frame_00063.png  read 39.0 | infer 37.2 | to_cpu 0.8 | post 158.8 | masks 4 | triangles 2 => proc 196.8 ms
# [65/312] frame_00064.png  read 39.7 | infer 40.3 | to_cpu 0.8 | post 148.9 | masks 5 | triangles 2 => proc 189.9 ms
# [66/312] frame_00065.png  read 39.9 | infer 63.4 | to_cpu 1.2 | post 118.1 | masks 6 | triangles 1 => proc 182.7 ms
# [67/312] frame_00066.png  read 42.7 | infer 48.9 | to_cpu 2.3 | post 147.2 | masks 5 | triangles 2 => proc 198.4 ms
# [68/312] frame_00067.png  read 36.5 | infer 44.5 | to_cpu 0.8 | post 157.1 | masks 5 | triangles 2 => proc 202.4 ms
# [69/312] frame_00068.png  read 40.2 | infer 45.7 | to_cpu 0.7 | post 150.0 | masks 4 | triangles 2 => proc 196.3 ms
# [70/312] frame_00069.png  read 36.9 | infer 40.4 | to_cpu 0.8 | post 146.7 | masks 4 | triangles 2 => proc 188.0 ms
# [71/312] frame_00070.png  read 40.1 | infer 56.4 | to_cpu 0.9 | post 144.8 | masks 5 | triangles 2 => proc 202.1 ms
# [72/312] frame_00071.png  read 36.3 | infer 33.1 | to_cpu 0.9 | post 147.3 | masks 5 | triangles 2 => proc 181.4 ms
# [73/312] frame_00072.png  read 38.7 | infer 38.8 | to_cpu 0.7 | post 138.8 | masks 4 | triangles 2 => proc 178.3 ms
# [74/312] frame_00073.png  read 39.2 | infer 35.8 | to_cpu 0.8 | post 133.7 | masks 4 | triangles 2 => proc 170.3 ms
# [75/312] frame_00074.png  read 39.5 | infer 42.0 | to_cpu 0.8 | post 131.0 | masks 3 | triangles 2 => proc 173.9 ms
# [76/312] frame_00075.png  read 38.6 | infer 35.5 | to_cpu 0.8 | post 124.1 | masks 4 | triangles 2 => proc 160.5 ms
# [77/312] frame_00076.png  read 39.6 | infer 38.2 | to_cpu 0.8 | post 123.1 | masks 5 | triangles 2 => proc 162.1 ms
# [78/312] frame_00077.png  read 38.5 | infer 42.5 | to_cpu 0.8 | post 140.1 | masks 4 | triangles 2 => proc 183.3 ms
# [79/312] frame_00078.png  read 39.8 | infer 33.8 | to_cpu 0.7 | post 87.0 | masks 4 | triangles 1 => proc 121.5 ms
# [80/312] frame_00079.png  read 37.2 | infer 39.4 | to_cpu 2.2 | post 112.3 | masks 4 | triangles 1 => proc 153.9 ms
# [81/312] frame_00080.png  read 38.9 | infer 42.5 | to_cpu 1.5 | post 116.4 | masks 4 | triangles 1 => proc 160.4 ms
# [82/312] frame_00081.png  read 37.8 | infer 39.5 | to_cpu 0.8 | post 142.8 | masks 5 | triangles 2 => proc 183.0 ms
# [83/312] frame_00082.png  read 38.5 | infer 34.4 | to_cpu 0.7 | post 145.6 | masks 3 | triangles 2 => proc 180.7 ms
# [84/312] frame_00083.png  read 39.2 | infer 37.0 | to_cpu 0.8 | post 155.7 | masks 4 | triangles 2 => proc 193.5 ms
# [85/312] frame_00084.png  read 38.7 | infer 37.1 | to_cpu 1.3 | post 147.6 | masks 3 | triangles 2 => proc 186.0 ms
# [86/312] frame_00085.png  read 47.7 | infer 46.6 | to_cpu 0.8 | post 146.2 | masks 3 | triangles 2 => proc 193.6 ms
# [87/312] frame_00086.png  read 37.6 | infer 43.4 | to_cpu 1.1 | post 148.0 | masks 2 | triangles 2 => proc 192.5 ms
# [88/312] frame_00087.png  read 40.5 | infer 44.0 | to_cpu 0.7 | post 149.5 | masks 3 | triangles 1 => proc 194.2 ms
# [89/312] frame_00088.png  read 37.4 | infer 37.2 | to_cpu 1.0 | post 126.8 | masks 4 | triangles 1 => proc 165.0 ms
# [90/312] frame_00089.png  read 40.7 | infer 35.3 | to_cpu 0.9 | post 137.9 | masks 5 | triangles 2 => proc 174.0 ms
# [91/312] frame_00090.png  read 38.0 | infer 44.6 | to_cpu 0.8 | post 148.9 | masks 3 | triangles 2 => proc 194.2 ms
# [92/312] frame_00091.png  read 40.1 | infer 39.9 | to_cpu 1.0 | post 149.1 | masks 3 | triangles 2 => proc 189.9 ms
# [93/312] frame_00092.png  read 36.4 | infer 37.1 | to_cpu 0.8 | post 147.0 | masks 3 | triangles 2 => proc 184.8 ms
# [94/312] frame_00093.png  read 39.9 | infer 37.2 | to_cpu 14.9 | post 160.2 | masks 3 | triangles 2 => proc 212.3 ms
# [95/312] frame_00094.png  read 36.5 | infer 38.5 | to_cpu 0.8 | post 149.9 | masks 2 | triangles 2 => proc 189.2 ms
# [96/312] frame_00095.png  read 36.1 | infer 35.4 | to_cpu 0.7 | post 141.0 | masks 3 | triangles 1 => proc 177.0 ms
# [97/312] frame_00096.png  read 39.0 | infer 37.8 | to_cpu 0.8 | post 119.0 | masks 4 | triangles 1 => proc 157.6 ms
# [98/312] frame_00097.png  read 37.5 | infer 34.6 | to_cpu 0.8 | post 122.6 | masks 4 | triangles 1 => proc 158.0 ms
# [99/312] frame_00098.png  read 41.2 | infer 39.3 | to_cpu 0.8 | post 115.0 | masks 4 | triangles 1 => proc 155.1 ms
# [100/312] frame_00099.png  read 37.3 | infer 42.4 | to_cpu 0.8 | post 117.3 | masks 4 | triangles 1 => proc 160.5 ms
# [101/312] frame_00100.png  read 40.0 | infer 37.2 | to_cpu 0.9 | post 111.6 | masks 3 | triangles 1 => proc 149.7 ms
# [102/312] frame_00101.png  read 37.1 | infer 41.8 | to_cpu 1.0 | post 139.8 | masks 5 | triangles 2 => proc 182.6 ms
# [103/312] frame_00102.png  read 39.4 | infer 46.9 | to_cpu 0.7 | post 163.7 | masks 3 | triangles 2 => proc 211.2 ms
# [104/312] frame_00103.png  read 37.6 | infer 43.7 | to_cpu 0.9 | post 161.3 | masks 4 | triangles 1 => proc 205.9 ms
# [105/312] frame_00104.png  read 40.3 | infer 35.1 | to_cpu 0.7 | post 142.5 | masks 4 | triangles 1 => proc 178.3 ms
# [106/312] frame_00105.png  read 36.6 | infer 36.0 | to_cpu 0.8 | post 148.8 | masks 4 | triangles 3 => proc 185.6 ms
# [107/312] frame_00106.png  read 45.4 | infer 42.5 | to_cpu 0.9 | post 146.4 | masks 5 | triangles 1 => proc 189.8 ms
# [108/312] frame_00107.png  read 38.1 | infer 37.6 | to_cpu 0.8 | post 130.0 | masks 5 | triangles 1 => proc 168.4 ms
# [109/312] frame_00108.png  read 39.5 | infer 34.6 | to_cpu 0.7 | post 140.4 | masks 5 | triangles 2 => proc 175.7 ms
# [110/312] frame_00109.png  read 37.7 | infer 35.3 | to_cpu 0.9 | post 138.1 | masks 5 | triangles 2 => proc 174.3 ms
# [111/312] frame_00110.png  read 40.2 | infer 37.6 | to_cpu 0.8 | post 130.0 | masks 4 | triangles 1 => proc 168.5 ms
# [112/312] frame_00111.png  read 36.9 | infer 31.7 | to_cpu 0.7 | post 137.9 | masks 4 | triangles 2 => proc 170.3 ms
# [113/312] frame_00112.png  read 40.4 | infer 36.7 | to_cpu 0.8 | post 133.3 | masks 4 | triangles 2 => proc 170.8 ms
# [114/312] frame_00113.png  read 36.5 | infer 39.3 | to_cpu 0.8 | post 122.6 | masks 5 | triangles 1 => proc 162.7 ms
# [115/312] frame_00114.png  read 40.3 | infer 317.8 | to_cpu 1.2 | post 117.6 | masks 6 | triangles 1 => proc 436.5 ms
# [116/312] frame_00115.png  read 42.5 | infer 42.5 | to_cpu 0.9 | post 113.1 | masks 6 | triangles 1 => proc 156.5 ms
# [117/312] frame_00116.png  read 39.3 | infer 41.5 | to_cpu 0.8 | post 114.0 | masks 6 | triangles 1 => proc 156.3 ms
# [118/312] frame_00117.png  read 37.5 | infer 42.5 | to_cpu 0.8 | post 116.7 | masks 4 | triangles 2 => proc 160.0 ms
# [119/312] frame_00118.png  read 40.5 | infer 45.0 | to_cpu 1.4 | post 109.6 | masks 5 | triangles 1 => proc 156.0 ms
# [120/312] frame_00119.png  read 41.2 | infer 51.4 | to_cpu 1.9 | post 129.0 | masks 6 | triangles 2 => proc 182.4 ms
# [121/312] frame_00120.png  read 37.3 | infer 32.5 | to_cpu 0.9 | post 140.0 | masks 6 | triangles 1 => proc 173.4 ms
# [122/312] frame_00121.png  read 39.4 | infer 41.1 | to_cpu 0.8 | post 136.3 | masks 6 | triangles 2 => proc 178.2 ms
# [123/312] frame_00122.png  read 37.2 | infer 50.0 | to_cpu 1.6 | post 128.7 | masks 7 | triangles 1 => proc 180.4 ms
# [124/312] frame_00123.png  read 41.1 | infer 42.8 | to_cpu 1.1 | post 131.1 | masks 10 | triangles 1 => proc 174.9 ms
# [125/312] frame_00124.png  read 39.0 | infer 44.6 | to_cpu 0.9 | post 129.9 | masks 9 | triangles 1 => proc 175.5 ms
# [126/312] frame_00125.png  read 37.6 | infer 35.4 | to_cpu 1.9 | post 134.8 | masks 9 | triangles 2 => proc 172.1 ms
# [127/312] frame_00126.png  read 40.1 | infer 43.7 | to_cpu 0.8 | post 128.9 | masks 5 | triangles 1 => proc 173.4 ms
# [128/312] frame_00127.png  read 36.8 | infer 39.9 | to_cpu 0.9 | post 146.6 | masks 5 | triangles 2 => proc 187.4 ms
# [129/312] frame_00128.png  read 41.2 | infer 37.3 | to_cpu 0.7 | post 169.1 | masks 3 | triangles 3 => proc 207.1 ms
# [130/312] frame_00129.png  read 38.1 | infer 40.5 | to_cpu 1.2 | post 152.8 | masks 3 | triangles 3 => proc 194.6 ms
# [131/312] frame_00130.png  read 36.6 | infer 34.4 | to_cpu 3.8 | post 146.7 | masks 3 | triangles 2 => proc 184.9 ms
# [132/312] frame_00131.png  read 35.2 | infer 42.9 | to_cpu 0.7 | post 151.6 | masks 4 | triangles 2 => proc 195.3 ms
# [133/312] frame_00132.png  read 36.5 | infer 39.3 | to_cpu 0.7 | post 146.8 | masks 3 | triangles 2 => proc 186.9 ms
# [134/312] frame_00133.png  read 32.9 | infer 35.4 | to_cpu 0.9 | post 132.4 | masks 3 | triangles 1 => proc 168.7 ms
# [135/312] frame_00134.png  read 33.0 | infer 43.1 | to_cpu 0.7 | post 93.5 | masks 3 | triangles 1 => proc 137.3 ms
# [136/312] frame_00135.png  read 31.2 | infer 42.8 | to_cpu 0.6 | post 84.9 | masks 2 | triangles 1 => proc 128.4 ms
# [137/312] frame_00136.png  read 33.9 | infer 33.8 | to_cpu 0.7 | post 83.8 | masks 2 | triangles 1 => proc 118.2 ms
# [138/312] frame_00137.png  read 30.9 | infer 35.4 | to_cpu 0.6 | post 86.9 | masks 2 | triangles 1 => proc 122.8 ms
# [139/312] frame_00138.png  read 37.2 | infer 37.1 | to_cpu 1.5 | post 128.8 | masks 3 | triangles 2 => proc 167.4 ms
# [140/312] frame_00139.png  read 36.2 | infer 44.0 | to_cpu 0.7 | post 144.7 | masks 2 | triangles 2 => proc 189.4 ms
# [141/312] frame_00140.png  read 39.1 | infer 39.4 | to_cpu 0.8 | post 150.9 | masks 3 | triangles 2 => proc 191.0 ms
# [142/312] frame_00141.png  read 36.2 | infer 44.8 | to_cpu 0.7 | post 148.6 | masks 3 | triangles 2 => proc 194.1 ms
# [143/312] frame_00142.png  read 38.7 | infer 55.1 | to_cpu 0.7 | post 145.2 | masks 3 | triangles 2 => proc 201.0 ms
# [144/312] frame_00143.png  read 42.8 | infer 36.2 | to_cpu 0.8 | post 141.6 | masks 3 | triangles 2 => proc 178.6 ms
# [145/312] frame_00144.png  read 37.3 | infer 32.1 | to_cpu 0.9 | post 144.1 | masks 3 | triangles 2 => proc 177.1 ms
# [146/312] frame_00145.png  read 40.2 | infer 33.9 | to_cpu 0.7 | post 103.6 | masks 4 | triangles 1 => proc 138.1 ms
# [147/312] frame_00146.png  read 37.3 | infer 39.5 | to_cpu 0.8 | post 102.1 | masks 4 | triangles 1 => proc 142.3 ms
# [148/312] frame_00147.png  read 39.1 | infer 38.7 | to_cpu 0.8 | post 103.6 | masks 4 | triangles 1 => proc 143.0 ms
# [149/312] frame_00148.png  read 40.4 | infer 40.6 | to_cpu 0.8 | post 101.4 | masks 4 | triangles 1 => proc 142.8 ms
# [150/312] frame_00149.png  read 37.6 | infer 166.3 | to_cpu 1.4 | post 121.7 | masks 6 | triangles 1 => proc 289.4 ms
# [151/312] frame_00150.png  read 40.6 | infer 57.2 | to_cpu 0.9 | post 113.7 | masks 7 | triangles 1 => proc 171.8 ms
# [152/312] frame_00151.png  read 39.7 | infer 42.5 | to_cpu 0.9 | post 127.6 | masks 7 | triangles 2 => proc 171.1 ms
# [153/312] frame_00152.png  read 40.5 | infer 44.6 | to_cpu 1.0 | post 99.9 | masks 5 | triangles 1 => proc 145.4 ms
# [154/312] frame_00153.png  read 41.0 | infer 42.3 | to_cpu 0.7 | post 122.1 | masks 5 | triangles 1 => proc 165.1 ms
# [155/312] frame_00154.png  read 37.2 | infer 70.7 | to_cpu 1.1 | post 142.3 | masks 6 | triangles 2 => proc 214.0 ms
# [156/312] frame_00155.png  read 41.0 | infer 68.5 | to_cpu 0.8 | post 148.0 | masks 6 | triangles 2 => proc 217.3 ms
# [157/312] frame_00156.png  read 39.1 | infer 42.9 | to_cpu 0.8 | post 140.3 | masks 5 | triangles 2 => proc 184.0 ms
# [158/312] frame_00157.png  read 42.6 | infer 44.9 | to_cpu 0.7 | post 132.2 | masks 3 | triangles 2 => proc 177.9 ms
# [159/312] frame_00158.png  read 38.4 | infer 33.3 | to_cpu 3.3 | post 127.1 | masks 5 | triangles 2 => proc 163.6 ms
# [160/312] frame_00159.png  read 37.4 | infer 41.4 | to_cpu 2.8 | post 129.9 | masks 5 | triangles 2 => proc 174.1 ms
# [161/312] frame_00160.png  read 39.9 | infer 43.7 | to_cpu 0.8 | post 136.8 | masks 5 | triangles 2 => proc 181.3 ms
# [162/312] frame_00161.png  read 35.9 | infer 48.3 | to_cpu 1.2 | post 104.2 | masks 4 | triangles 1 => proc 153.7 ms
# [163/312] frame_00162.png  read 39.2 | infer 65.3 | to_cpu 1.2 | post 163.3 | masks 6 | triangles 2 => proc 229.8 ms
# [164/312] frame_00163.png  read 37.1 | infer 49.8 | to_cpu 0.9 | post 161.0 | masks 4 | triangles 2 => proc 211.7 ms
# [165/312] frame_00164.png  read 38.7 | infer 36.3 | to_cpu 0.8 | post 157.9 | masks 5 | triangles 2 => proc 195.0 ms
# [166/312] frame_00165.png  read 37.2 | infer 48.2 | to_cpu 1.1 | post 157.6 | masks 4 | triangles 2 => proc 206.9 ms
# [167/312] frame_00166.png  read 40.7 | infer 38.6 | to_cpu 0.7 | post 149.0 | masks 4 | triangles 2 => proc 188.2 ms
# [168/312] frame_00167.png  read 38.8 | infer 39.0 | to_cpu 1.0 | post 186.2 | masks 5 | triangles 2 => proc 226.2 ms
# [169/312] frame_00168.png  read 42.6 | infer 42.0 | to_cpu 0.9 | post 146.3 | masks 4 | triangles 2 => proc 189.3 ms
# [170/312] frame_00169.png  read 48.8 | infer 49.7 | to_cpu 1.1 | post 178.4 | masks 4 | triangles 2 => proc 229.2 ms
# [171/312] frame_00170.png  read 37.0 | infer 33.2 | to_cpu 0.8 | post 153.9 | masks 3 | triangles 3 => proc 187.9 ms
# [172/312] frame_00171.png  read 42.8 | infer 41.2 | to_cpu 0.7 | post 177.4 | masks 4 | triangles 2 => proc 219.3 ms
# [173/312] frame_00172.png  read 41.1 | infer 325.7 | to_cpu 1.8 | post 164.9 | masks 6 | triangles 2 => proc 492.5 ms
# [174/312] frame_00173.png  read 45.7 | infer 74.5 | to_cpu 0.9 | post 158.3 | masks 6 | triangles 2 => proc 233.7 ms
# [175/312] frame_00174.png  read 39.0 | infer 46.5 | to_cpu 0.9 | post 145.5 | masks 5 | triangles 2 => proc 192.9 ms
# [176/312] frame_00175.png  read 44.0 | infer 34.1 | to_cpu 0.8 | post 145.0 | masks 5 | triangles 2 => proc 179.8 ms
# [177/312] frame_00176.png  read 38.6 | infer 41.9 | to_cpu 0.7 | post 132.5 | masks 4 | triangles 2 => proc 175.2 ms
# [178/312] frame_00177.png  read 38.6 | infer 33.5 | to_cpu 0.7 | post 41.8 | masks 4 | triangles 1 => proc 76.0 ms
# [179/312] frame_00178.png  read 36.1 | infer 67.4 | to_cpu 1.1 | post 0.0 | masks 6 | triangles 0 => proc 68.5 ms
# [180/312] frame_00179.png  read 35.3 | infer 34.6 | to_cpu 0.8 | post 0.0 | masks 5 | triangles 0 => proc 35.4 ms
# [181/312] frame_00180.png  read 37.6 | infer 42.6 | to_cpu 1.1 | post 0.0 | masks 7 | triangles 0 => proc 43.8 ms
# [182/312] frame_00181.png  read 36.9 | infer 41.0 | to_cpu 0.9 | post 43.2 | masks 6 | triangles 1 => proc 85.0 ms
# [183/312] frame_00182.png  read 36.6 | infer 54.8 | to_cpu 0.9 | post 94.6 | masks 5 | triangles 2 => proc 150.3 ms
# [184/312] frame_00183.png  read 38.2 | infer 41.5 | to_cpu 0.8 | post 149.9 | masks 4 | triangles 3 => proc 192.2 ms
# [185/312] frame_00184.png  read 40.6 | infer 43.4 | to_cpu 0.8 | post 118.1 | masks 4 | triangles 1 => proc 162.3 ms
# [186/312] frame_00185.png  read 37.6 | infer 34.4 | to_cpu 0.9 | post 123.4 | masks 5 | triangles 1 => proc 158.6 ms
# [187/312] frame_00186.png  read 39.1 | infer 45.7 | to_cpu 0.7 | post 109.7 | masks 3 | triangles 1 => proc 156.1 ms
# [188/312] frame_00187.png  read 39.6 | infer 41.2 | to_cpu 0.7 | post 156.3 | masks 2 | triangles 2 => proc 198.2 ms
# [189/312] frame_00188.png  read 40.0 | infer 39.8 | to_cpu 0.7 | post 147.5 | masks 2 | triangles 2 => proc 188.0 ms
# [190/312] frame_00189.png  read 37.3 | infer 42.7 | to_cpu 0.8 | post 118.7 | masks 3 | triangles 1 => proc 162.2 ms
# [191/312] frame_00190.png  read 39.9 | infer 32.1 | to_cpu 0.8 | post 114.6 | masks 3 | triangles 1 => proc 147.4 ms
# [192/312] frame_00191.png  read 37.7 | infer 34.0 | to_cpu 0.8 | post 115.7 | masks 3 | triangles 1 => proc 150.6 ms
# [193/312] frame_00192.png  read 43.1 | infer 35.3 | to_cpu 0.7 | post 118.7 | masks 3 | triangles 1 => proc 154.7 ms
# [194/312] frame_00193.png  read 36.6 | infer 33.3 | to_cpu 0.6 | post 116.4 | masks 3 | triangles 1 => proc 150.4 ms
# [195/312] frame_00194.png  read 40.3 | infer 30.6 | to_cpu 0.6 | post 154.7 | masks 2 | triangles 2 => proc 185.9 ms
# [196/312] frame_00195.png  read 37.3 | infer 31.8 | to_cpu 0.7 | post 146.3 | masks 2 | triangles 2 => proc 178.7 ms
# [197/312] frame_00196.png  read 38.7 | infer 32.3 | to_cpu 1.4 | post 117.6 | masks 3 | triangles 1 => proc 151.3 ms
# [198/312] frame_00197.png  read 36.9 | infer 37.3 | to_cpu 0.7 | post 116.5 | masks 3 | triangles 1 => proc 154.5 ms
# [199/312] frame_00198.png  read 40.0 | infer 38.8 | to_cpu 0.9 | post 119.5 | masks 3 | triangles 1 => proc 159.2 ms
# [200/312] frame_00199.png  read 36.9 | infer 34.1 | to_cpu 0.6 | post 149.2 | masks 2 | triangles 2 => proc 184.0 ms
# [201/312] frame_00200.png  read 38.0 | infer 48.4 | to_cpu 1.0 | post 150.4 | masks 2 | triangles 2 => proc 199.9 ms
# [202/312] frame_00201.png  read 37.9 | infer 41.6 | to_cpu 0.8 | post 116.6 | masks 3 | triangles 1 => proc 159.0 ms
# [203/312] frame_00202.png  read 41.1 | infer 44.9 | to_cpu 1.0 | post 111.6 | masks 3 | triangles 1 => proc 157.4 ms
# [204/312] frame_00203.png  read 37.6 | infer 34.8 | to_cpu 0.6 | post 134.6 | masks 2 | triangles 2 => proc 170.0 ms
# [205/312] frame_00204.png  read 39.2 | infer 48.8 | to_cpu 0.6 | post 159.9 | masks 1 | triangles 2 => proc 209.3 ms
# [206/312] frame_00205.png  read 37.6 | infer 48.6 | to_cpu 0.7 | post 161.0 | masks 3 | triangles 2 => proc 210.3 ms
# [207/312] frame_00206.png  read 38.9 | infer 34.7 | to_cpu 0.7 | post 149.8 | masks 3 | triangles 2 => proc 185.3 ms
# [208/312] frame_00207.png  read 36.8 | infer 31.5 | to_cpu 2.7 | post 153.7 | masks 2 | triangles 3 => proc 187.8 ms
# [209/312] frame_00208.png  read 40.2 | infer 43.4 | to_cpu 2.1 | post 153.3 | masks 3 | triangles 3 => proc 198.8 ms
# [210/312] frame_00209.png  read 36.9 | infer 43.1 | to_cpu 0.9 | post 147.5 | masks 4 | triangles 3 => proc 191.5 ms
# [211/312] frame_00210.png  read 39.0 | infer 36.7 | to_cpu 0.8 | post 149.1 | masks 4 | triangles 3 => proc 186.6 ms
# [212/312] frame_00211.png  read 36.5 | infer 34.9 | to_cpu 0.8 | post 148.5 | masks 4 | triangles 2 => proc 184.2 ms
# [213/312] frame_00212.png  read 35.8 | infer 32.0 | to_cpu 1.3 | post 156.2 | masks 3 | triangles 3 => proc 189.5 ms
# [214/312] frame_00213.png  read 39.1 | infer 33.6 | to_cpu 1.8 | post 152.1 | masks 3 | triangles 3 => proc 187.5 ms
# [215/312] frame_00214.png  read 37.1 | infer 37.2 | to_cpu 0.7 | post 149.5 | masks 3 | triangles 3 => proc 187.4 ms
# [216/312] frame_00215.png  read 39.3 | infer 32.0 | to_cpu 0.8 | post 142.8 | masks 3 | triangles 2 => proc 175.6 ms
# [217/312] frame_00216.png  read 37.3 | infer 40.3 | to_cpu 0.8 | post 146.1 | masks 5 | triangles 2 => proc 187.1 ms
# [218/312] frame_00217.png  read 38.6 | infer 39.1 | to_cpu 0.7 | post 144.0 | masks 5 | triangles 2 => proc 183.9 ms
# [219/312] frame_00218.png  read 37.6 | infer 38.9 | to_cpu 0.7 | post 139.8 | masks 4 | triangles 2 => proc 179.5 ms
# [220/312] frame_00219.png  read 58.1 | infer 34.8 | to_cpu 0.7 | post 140.6 | masks 3 | triangles 2 => proc 176.1 ms
# [221/312] frame_00220.png  read 47.1 | infer 36.8 | to_cpu 0.7 | post 128.2 | masks 3 | triangles 1 => proc 165.6 ms
# [222/312] frame_00221.png  read 38.6 | infer 35.0 | to_cpu 0.8 | post 105.8 | masks 4 | triangles 1 => proc 141.6 ms
# [223/312] frame_00222.png  read 39.9 | infer 38.9 | to_cpu 0.8 | post 93.4 | masks 4 | triangles 1 => proc 133.0 ms
# [224/312] frame_00223.png  read 37.2 | infer 37.3 | to_cpu 0.8 | post 113.7 | masks 5 | triangles 1 => proc 151.8 ms
# [225/312] frame_00224.png  read 49.5 | infer 54.7 | to_cpu 1.2 | post 120.0 | masks 5 | triangles 1 => proc 175.8 ms
# [226/312] frame_00225.png  read 36.7 | infer 32.8 | to_cpu 0.6 | post 127.9 | masks 3 | triangles 1 => proc 161.4 ms
# [227/312] frame_00226.png  read 37.0 | infer 35.5 | to_cpu 0.7 | post 155.5 | masks 3 | triangles 2 => proc 191.7 ms
# [228/312] frame_00227.png  read 39.6 | infer 40.0 | to_cpu 0.6 | post 145.9 | masks 2 | triangles 2 => proc 186.4 ms
# [229/312] frame_00228.png  read 34.7 | infer 34.7 | to_cpu 0.7 | post 143.5 | masks 2 | triangles 2 => proc 178.9 ms
# [230/312] frame_00229.png  read 38.4 | infer 41.5 | to_cpu 0.8 | post 100.4 | masks 4 | triangles 1 => proc 142.7 ms
# [231/312] frame_00230.png  read 37.4 | infer 34.0 | to_cpu 0.8 | post 116.0 | masks 4 | triangles 1 => proc 150.8 ms
# [232/312] frame_00231.png  read 38.4 | infer 36.0 | to_cpu 0.7 | post 144.4 | masks 5 | triangles 2 => proc 181.1 ms
# [233/312] frame_00232.png  read 34.8 | infer 42.2 | to_cpu 0.9 | post 143.2 | masks 4 | triangles 2 => proc 186.4 ms
# [234/312] frame_00233.png  read 34.0 | infer 38.7 | to_cpu 0.8 | post 138.0 | masks 5 | triangles 2 => proc 177.5 ms
# [235/312] frame_00234.png  read 34.2 | infer 34.3 | to_cpu 0.7 | post 123.4 | masks 3 | triangles 2 => proc 158.4 ms
# [236/312] frame_00235.png  read 36.2 | infer 40.0 | to_cpu 0.7 | post 46.3 | masks 3 | triangles 0 => proc 87.0 ms
# [237/312] frame_00236.png  read 36.7 | infer 47.4 | to_cpu 0.8 | post 0.0 | masks 2 | triangles 0 => proc 48.2 ms
# [238/312] frame_00237.png  read 38.9 | infer 50.0 | to_cpu 0.8 | post 0.0 | masks 3 | triangles 0 => proc 50.9 ms
# [239/312] frame_00238.png  read 34.8 | infer 41.0 | to_cpu 1.1 | post 0.0 | masks 3 | triangles 0 => proc 42.1 ms
# [240/312] frame_00239.png  read 38.0 | infer 40.6 | to_cpu 0.8 | post 51.8 | masks 4 | triangles 1 => proc 93.2 ms
# [241/312] frame_00240.png  read 33.3 | infer 43.2 | to_cpu 0.7 | post 79.2 | masks 3 | triangles 1 => proc 123.1 ms
# [242/312] frame_00241.png  read 36.2 | infer 41.7 | to_cpu 0.8 | post 88.0 | masks 3 | triangles 1 => proc 130.4 ms
# [243/312] frame_00242.png  read 34.5 | infer 40.0 | to_cpu 0.8 | post 94.8 | masks 3 | triangles 1 => proc 135.6 ms
# [244/312] frame_00243.png  read 36.4 | infer 39.8 | to_cpu 0.6 | post 103.7 | masks 2 | triangles 1 => proc 144.2 ms
# [245/312] frame_00244.png  read 34.5 | infer 40.0 | to_cpu 1.8 | post 117.6 | masks 4 | triangles 3 => proc 159.4 ms
# [246/312] frame_00245.png  read 37.8 | infer 41.6 | to_cpu 0.7 | post 148.6 | masks 2 | triangles 2 => proc 190.9 ms
# [247/312] frame_00246.png  read 38.7 | infer 37.3 | to_cpu 0.7 | post 142.8 | masks 2 | triangles 2 => proc 180.8 ms
# [248/312] frame_00247.png  read 38.3 | infer 33.4 | to_cpu 0.7 | post 154.5 | masks 3 | triangles 2 => proc 188.6 ms
# [249/312] frame_00248.png  read 38.4 | infer 39.3 | to_cpu 0.7 | post 143.8 | masks 2 | triangles 2 => proc 183.8 ms
# [250/312] frame_00249.png  read 39.3 | infer 33.0 | to_cpu 0.7 | post 146.0 | masks 2 | triangles 2 => proc 179.7 ms
# [251/312] frame_00250.png  read 36.2 | infer 36.7 | to_cpu 0.7 | post 146.0 | masks 2 | triangles 2 => proc 183.5 ms
# [252/312] frame_00251.png  read 38.7 | infer 33.8 | to_cpu 0.6 | post 115.2 | masks 3 | triangles 1 => proc 149.7 ms
# [253/312] frame_00252.png  read 36.5 | infer 31.7 | to_cpu 0.8 | post 109.8 | masks 4 | triangles 1 => proc 142.3 ms
# [254/312] frame_00253.png  read 52.5 | infer 42.3 | to_cpu 0.8 | post 147.5 | masks 4 | triangles 1 => proc 190.6 ms
# [255/312] frame_00254.png  read 36.4 | infer 34.3 | to_cpu 0.8 | post 149.6 | masks 3 | triangles 2 => proc 184.7 ms
# [256/312] frame_00255.png  read 38.8 | infer 41.1 | to_cpu 0.7 | post 147.2 | masks 3 | triangles 2 => proc 189.0 ms
# [257/312] frame_00256.png  read 37.6 | infer 38.1 | to_cpu 1.8 | post 146.3 | masks 4 | triangles 2 => proc 186.2 ms
# [258/312] frame_00257.png  read 39.2 | infer 33.0 | to_cpu 0.7 | post 169.2 | masks 3 | triangles 2 => proc 202.9 ms
# [259/312] frame_00258.png  read 36.2 | infer 40.9 | to_cpu 0.8 | post 145.5 | masks 5 | triangles 2 => proc 187.2 ms
# [260/312] frame_00259.png  read 38.9 | infer 40.3 | to_cpu 1.3 | post 146.8 | masks 5 | triangles 2 => proc 188.4 ms
# [261/312] frame_00260.png  read 39.6 | infer 41.8 | to_cpu 0.8 | post 147.4 | masks 5 | triangles 2 => proc 190.0 ms
# [262/312] frame_00261.png  read 39.8 | infer 36.0 | to_cpu 0.8 | post 147.5 | masks 3 | triangles 2 => proc 184.4 ms
# [263/312] frame_00262.png  read 36.6 | infer 39.1 | to_cpu 0.9 | post 146.7 | masks 5 | triangles 2 => proc 186.7 ms
# [264/312] frame_00263.png  read 39.5 | infer 43.5 | to_cpu 0.9 | post 144.9 | masks 3 | triangles 2 => proc 189.3 ms
# [265/312] frame_00264.png  read 38.4 | infer 44.7 | to_cpu 0.8 | post 137.7 | masks 3 | triangles 2 => proc 183.1 ms
# [266/312] frame_00265.png  read 36.1 | infer 41.5 | to_cpu 0.8 | post 139.5 | masks 4 | triangles 2 => proc 181.8 ms
# [267/312] frame_00266.png  read 41.0 | infer 34.8 | to_cpu 0.6 | post 132.7 | masks 3 | triangles 2 => proc 168.1 ms
# [268/312] frame_00267.png  read 37.7 | infer 39.9 | to_cpu 0.7 | post 130.2 | masks 3 | triangles 2 => proc 170.9 ms
# [269/312] frame_00268.png  read 39.6 | infer 38.3 | to_cpu 0.8 | post 99.2 | masks 3 | triangles 1 => proc 138.3 ms
# [270/312] frame_00269.png  read 38.0 | infer 36.1 | to_cpu 0.7 | post 81.1 | masks 4 | triangles 1 => proc 118.0 ms
# [271/312] frame_00270.png  read 40.5 | infer 44.0 | to_cpu 0.6 | post 0.0 | masks 2 | triangles 0 => proc 44.6 ms
# [272/312] frame_00271.png  read 43.8 | infer 336.3 | to_cpu 1.4 | post 35.9 | masks 8 | triangles 1 => proc 373.5 ms
# [273/312] frame_00272.png  read 37.4 | infer 48.8 | to_cpu 1.0 | post 69.8 | masks 6 | triangles 2 => proc 119.6 ms
# [274/312] frame_00273.png  read 40.2 | infer 39.6 | to_cpu 1.1 | post 74.9 | masks 8 | triangles 2 => proc 115.6 ms
# [275/312] frame_00274.png  read 37.7 | infer 49.8 | to_cpu 0.9 | post 92.8 | masks 5 | triangles 2 => proc 143.5 ms
# [276/312] frame_00275.png  read 41.3 | infer 41.5 | to_cpu 0.8 | post 58.5 | masks 6 | triangles 1 => proc 100.8 ms
# [277/312] frame_00276.png  read 39.3 | infer 55.7 | to_cpu 2.9 | post 69.0 | masks 7 | triangles 2 => proc 127.6 ms
# [278/312] frame_00277.png  read 39.6 | infer 60.0 | to_cpu 1.2 | post 164.2 | masks 9 | triangles 2 => proc 225.5 ms
# [279/312] frame_00278.png  read 37.7 | infer 33.9 | to_cpu 0.9 | post 123.3 | masks 6 | triangles 2 => proc 158.1 ms
# [280/312] frame_00279.png  read 41.6 | infer 35.0 | to_cpu 1.1 | post 110.4 | masks 5 | triangles 2 => proc 146.5 ms
# [281/312] frame_00280.png  read 40.5 | infer 41.6 | to_cpu 0.9 | post 108.9 | masks 5 | triangles 1 => proc 151.3 ms
# [282/312] frame_00281.png  read 38.5 | infer 41.6 | to_cpu 1.5 | post 130.3 | masks 5 | triangles 2 => proc 173.4 ms
# [283/312] frame_00282.png  read 39.1 | infer 33.5 | to_cpu 0.8 | post 149.7 | masks 5 | triangles 2 => proc 184.1 ms
# [284/312] frame_00283.png  read 37.0 | infer 44.6 | to_cpu 0.7 | post 153.4 | masks 4 | triangles 2 => proc 198.7 ms
# [285/312] frame_00284.png  read 40.1 | infer 37.0 | to_cpu 0.8 | post 146.0 | masks 4 | triangles 2 => proc 183.8 ms
# [286/312] frame_00285.png  read 36.3 | infer 31.1 | to_cpu 0.7 | post 138.7 | masks 4 | triangles 2 => proc 170.6 ms
# [287/312] frame_00286.png  read 40.0 | infer 32.5 | to_cpu 0.8 | post 133.4 | masks 4 | triangles 2 => proc 166.7 ms
# [288/312] frame_00287.png  read 36.3 | infer 48.9 | to_cpu 1.2 | post 41.3 | masks 3 | triangles 1 => proc 91.5 ms
# [289/312] frame_00288.png  read 39.3 | infer 102.2 | to_cpu 1.3 | post 0.0 | masks 6 | triangles 0 => proc 103.6 ms
# [290/312] frame_00289.png  read 39.2 | infer 39.2 | to_cpu 2.0 | post 0.0 | masks 8 | triangles 0 => proc 41.3 ms
# [291/312] frame_00290.png  read 38.2 | infer 47.7 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 48.8 ms
# [292/312] frame_00291.png  read 39.9 | infer 44.7 | to_cpu 3.4 | post 0.0 | masks 7 | triangles 0 => proc 48.1 ms
# [293/312] frame_00292.png  read 40.7 | infer 34.8 | to_cpu 1.1 | post 0.0 | masks 7 | triangles 0 => proc 35.9 ms
# [294/312] frame_00293.png  read 40.4 | infer 39.1 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 40.0 ms
# [295/312] frame_00294.png  read 41.1 | infer 50.7 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 51.8 ms
# [296/312] frame_00295.png  read 40.7 | infer 52.4 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 53.4 ms
# [297/312] frame_00296.png  read 43.4 | infer 42.3 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 43.2 ms
# [298/312] frame_00297.png  read 43.6 | infer 40.0 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 40.9 ms
# [299/312] frame_00298.png  read 37.4 | infer 39.8 | to_cpu 2.0 | post 0.0 | masks 6 | triangles 0 => proc 41.8 ms
# [300/312] frame_00299.png  read 42.6 | infer 39.6 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 40.5 ms
# [301/312] frame_00300.png  read 40.8 | infer 44.5 | to_cpu 0.9 | post 0.0 | masks 6 | triangles 0 => proc 45.4 ms
# [302/312] frame_00301.png  read 37.1 | infer 54.9 | to_cpu 1.0 | post 0.0 | masks 6 | triangles 0 => proc 55.9 ms
# [303/312] frame_00302.png  read 37.7 | infer 35.5 | to_cpu 1.0 | post 0.0 | masks 7 | triangles 0 => proc 36.6 ms
# [304/312] frame_00303.png  read 39.2 | infer 51.3 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 52.3 ms
# [305/312] frame_00304.png  read 36.6 | infer 36.0 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 37.0 ms
# [306/312] frame_00305.png  read 37.8 | infer 33.5 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 34.6 ms
# [307/312] frame_00306.png  read 36.7 | infer 44.7 | to_cpu 2.1 | post 0.0 | masks 7 | triangles 0 => proc 46.9 ms
# [308/312] frame_00307.png  read 19.5 | infer 23.5 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 23.5 ms
# [309/312] frame_00308.png  read 17.8 | infer 22.4 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 22.4 ms
# [310/312] frame_00309.png  read 17.6 | infer 20.0 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 20.0 ms
# [311/312] frame_00310.png  read 17.0 | infer 19.8 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 19.8 ms
# [312/312] frame_00311.png  read 17.0 | infer 19.6 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 19.6 ms

# %%
#Upgraded order logic and mask scanning

# %%
#!/usr/bin/env python3
# Ultra-fast overlays + lane-aware curved sampling (optimized postproc)
# Now: walk the bent probe ray in 15px steps (first-hit wins: RED→YELLOW→BOOTS→else GREEN)

import os, glob, time, math
import cv2, torch, numpy as np
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from ultralytics import YOLO

# =======================
# Config
# =======================
home       = os.path.expanduser("~")
weights    = f"{home}/models/jakes-loped/jakes-finder-mk1/1/weights.pt"
frames_dir = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "frames"

# SAVE HERE
out_dir    = Path(home) / "Documents" / "GitHub" / "Ai-plays-SubwaySurfers" / "out_overlays7"
out_dir.mkdir(parents=True, exist_ok=True)

RAIL_ID    = 9
IMG_SIZE   = 512
CONF, IOU  = 0.30, 0.45
MAX_DET    = 30

# Color/region filter
TARGET_COLORS_RGB  = [(119,104,67), (81,42,45)]
TOLERANCE          = 20.0
MIN_REGION_SIZE    = 30
MIN_REGION_HEIGHT  = 150

# Heat/triangle
HEAT_BLUR_KSIZE     = 51
RED_SCORE_THRESH    = 220
EXCLUDE_TOP_FRAC    = 0.40
EXCLUDE_BOTTOM_FRAC = 0.15
MIN_DARK_RED_AREA   = 1200
MIN_DARK_FRACTION   = 0.15
TRI_SIZE_PX         = 18

# Sampling ray length
SAMPLE_UP_PX        = 180
RAY_STEP_PX         = 20   # << walk the ray every 15 px

# ===== Bend degrees (tune here) =====
BEND_LEFT_STATE_RIGHT_DEG  = -20.0  # N1
BEND_MID_STATE_RIGHT_DEG   = -20.0  # N2
BEND_MID_STATE_LEFT_DEG    = +20.0  # N3
BEND_RIGHT_STATE_LEFT_DEG  = +20.0  # N4

# Colours (BGR)
COLOR_GREEN  = (0, 255, 0)
COLOR_PINK   = (203, 192, 255)
COLOR_YELLOW = (0, 255, 255)
COLOR_RED    = (0, 0, 255)
COLOR_WHITE  = (255, 255, 255)
COLOR_CYAN   = (255, 255, 0)
COLOR_BLACK  = (0, 0, 0)

# Runtime
THREADS_IO          = max(2, (os.cpu_count() or 4) // 2)
SHOW_FIRST_N        = None
RENDER_FIRST_N      = 300

# =======================
# Jake lane points
# =======================
LANE_LEFT   = (300, 1340)
LANE_MID    = (490, 1340)
LANE_RIGHT  = (680, 1340)
JAKE_POINT  = LANE_LEFT  # pick: LANE_LEFT / LANE_MID / LANE_RIGHT

LANE_TARGET_DEG = {"left": -10.7, "mid": +1.5, "right": +15.0}

def lane_name_from_point(p):
    if p == LANE_LEFT:  return "left"
    if p == LANE_MID:   return "mid"
    if p == LANE_RIGHT: return "right"
    return "mid"

# =======================
# System/Backends
# =======================
cv2.setUseOptimized(True)
try: cv2.setNumThreads(max(1, (os.cpu_count() or 1) - 1))
except Exception: pass

if torch.cuda.is_available():
    device, half = 0, True
    torch.backends.cudnn.benchmark = True
    try: torch.set_float32_matmul_precision('high')
    except Exception: pass
elif getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
    device, half = "mps", False
else:
    device, half = "cpu", False

# =======================
# Model
# =======================
model = YOLO(weights)
try: model.fuse()
except Exception: pass

_dummy = np.zeros((IMG_SIZE, IMG_SIZE, 3), np.uint8)
_ = model.predict(_dummy, task="segment", imgsz=IMG_SIZE, device=device,
                  conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET)

# =======================
# Precomputed
# =======================
TARGETS_BGR_F32 = np.array([(r,g,b)[::-1] for (r,g,b) in TARGET_COLORS_RGB], dtype=np.float32)
TOL2            = TOLERANCE * TOLERANCE

# Class buckets for probe classification
DANGER_RED   = {1, 6, 7, 11}
WARN_YELLOW  = {2, 3, 4, 5, 8}
BOOTS_PINK   = {0}

CLASS_COLOURS = {
    0:(255,255,0),1:(192,192,192),2:(0,128,255),3:(0,255,0),
    4:(255,0,255),5:(0,255,255),6:(255,128,0),7:(128,0,255),
    8:(0,0,128),9:(0,0,255),10:(128,128,0),11:(255,255,102)
}
LABELS = {
    0:"BOOTS",1:"GREYTRAIN",2:"HIGHBARRIER1",3:"JUMP",4:"LOWBARRIER1",
    5:"LOWBARRIER2",6:"ORANGETRAIN",7:"PILLAR",8:"RAMP",9:"RAILS",
    10:"SIDEWALK",11:"YELLOWTRAIN"
}

# ====== tiny helpers ======
def _clampi(v, lo, hi):
    return lo if v < lo else (hi if v > hi else v)

def load_image_with_time(path: str):
    t0 = time.perf_counter()
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    return img, (time.perf_counter() - t0) * 1000.0

def chunked(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i+n]

# =======================
# Fast rails green finder
# =======================
def highlight_rails_mask_only_fast(img_bgr, rail_mask):
    H, W = rail_mask.shape
    if not rail_mask.any():
        return np.zeros((H, W), dtype=bool)

    rail_u8 = rail_mask.view(dtype=np.uint8) * 255
    x, y, w, h = cv2.boundingRect(rail_u8)
    img_roi  = img_bgr[y:y+h, x:x+w]
    mask_roi = rail_u8[y:y+h, x:x+w]

    img_f = img_roi.astype(np.float32, copy=False)
    diff  = img_f[:, :, None, :] - TARGETS_BGR_F32[None, None, :, :]
    dist2 = (diff * diff).sum(-1)
    colour_hit = (dist2 <= TOL2).any(-1)

    combined = np.logical_and(colour_hit, mask_roi.astype(bool))

    comp = combined.astype(np.uint8)
    n, lbls, stats, _ = cv2.connectedComponentsWithStats(comp, 8)
    if n <= 1: return np.zeros((H, W), dtype=bool)

    good = np.zeros_like(combined)
    areas = stats[1:, cv2.CC_STAT_AREA]
    hs    = stats[1:, cv2.CC_STAT_HEIGHT]
    keep  = np.where((areas >= MIN_REGION_SIZE) & (hs >= MIN_REGION_HEIGHT))[0] + 1
    for k in keep: good[lbls == k] = True

    full = np.zeros((H, W), dtype=bool)
    full[y:y+h, x:x+w] = good
    return full

def red_vs_green_score(red_mask, green_mask):
    k = (HEAT_BLUR_KSIZE, HEAT_BLUR_KSIZE)
    r = cv2.blur(red_mask.astype(np.float32, copy=False), k)
    g = cv2.blur(green_mask.astype(np.float32, copy=False), k)
    diff = r - g
    amax = float(np.max(np.abs(diff))) + 1e-6
    norm = (diff / (2.0 * amax) + 0.5)
    return np.clip(norm * 255.0, 0, 255.0).astype(np.uint8, copy=False)

def purple_triangles(score, H):
    top_ex = int(H * EXCLUDE_TOP_FRAC)
    bot_ex = int(H * EXCLUDE_BOTTOM_FRAC)
    dark = (score >= RED_SCORE_THRESH).astype(np.uint8, copy=False)
    if top_ex: dark[:top_ex, :] = 0
    if bot_ex: dark[-bot_ex:, :] = 0

    dark = cv2.morphologyEx(
        dark, cv2.MORPH_OPEN,
        cv2.getStructuringElement(cv2.MORPH_RECT, (5, 9)), iterations=1
    )
    total_dark = int(dark.sum())
    if total_dark == 0: return [], None

    frac_thresh = int(np.ceil(MIN_DARK_FRACTION * total_dark))
    n_lbl, lbls, stats, _ = cv2.connectedComponentsWithStats(dark, 8)
    if n_lbl <= 1: return [], None

    tris = []
    for lbl in range(1, n_lbl):
        area = stats[lbl, cv2.CC_STAT_AREA]
        if area >= MIN_DARK_RED_AREA and area >= frac_thresh:
            ys, xs = np.where(lbls == lbl)
            if ys.size == 0: continue
            y_top = ys.min()
            x_mid = int(xs[ys == y_top].mean())
            tris.append((x_mid, int(y_top)))

    if not tris: return [], None
    best = min(tris, key=lambda xy: xy[1])
    return tris, best

# ===== Bearing-based Jake triangle selection =====
def signed_degrees_from_vertical(dx, dy):
    if dx == 0 and dy == 0: return 0.0
    return -math.degrees(math.atan2(dx, -dy))

def select_triangle_by_bearing(tri_positions, jx, jy, target_deg, min_dy=6):
    best_i, best_deg, best_err = -1, None, None
    for i, (xt, yt) in enumerate(tri_positions):
        dy = yt - jy
        if dy >= -min_dy:  # must be above Jake
            continue
        deg = signed_degrees_from_vertical(xt - jx, dy)
        err = abs(deg - target_deg)
        if (best_err is None) or (err < best_err):
            best_i, best_deg, best_err = i, deg, err
    return best_i, best_deg, best_err

# ===== Lane-aware curved sampling (precompute sin/cos) =====
def _precompute_trig():
    angles = sorted(set([0.0,
        BEND_LEFT_STATE_RIGHT_DEG,
        BEND_MID_STATE_RIGHT_DEG,
        BEND_MID_STATE_LEFT_DEG,
        BEND_RIGHT_STATE_LEFT_DEG
    ]))
    table = {}
    for a in angles:
        r = math.radians(a)
        table[a] = (math.sin(r), -math.cos(r))  # (dx, dy) for unit ray (up = -y)
    return table
TRIG_TABLE = _precompute_trig()

def pick_bend_angle(jake_point, xt, x_ref, idx, best_idx):
    if idx == best_idx:
        return 0.0
    if jake_point == LANE_LEFT:
        return BEND_LEFT_STATE_RIGHT_DEG if xt > x_ref else 0.0
    if jake_point == LANE_RIGHT:
        return BEND_RIGHT_STATE_LEFT_DEG if xt < x_ref else 0.0
    if xt > x_ref: return BEND_MID_STATE_RIGHT_DEG
    if xt < x_ref: return BEND_MID_STATE_LEFT_DEG
    return 0.0

# --------- NEW: walk-the-ray classifier (15px steps, first-hit wins) ----------
def classify_triangles_at_sample_curved(
    tri_positions, masks_np, classes_np, H, W,
    jake_point, x_ref, best_idx, sample_px=SAMPLE_UP_PX, step_px=RAY_STEP_PX
):
    if masks_np is None or classes_np is None or len(tri_positions) == 0:
        return [], []

    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (W - 1))
    sy = (mh - 1) / max(1, (H - 1))

    # Build index lists once per frame for speed
    red_idx    = [i for i, c in enumerate(classes_np) if int(c) in DANGER_RED]
    yellow_idx = [i for i, c in enumerate(classes_np) if int(c) in WARN_YELLOW]
    boots_idx  = [i for i, c in enumerate(classes_np) if int(c) in BOOTS_PINK]

    colours, rays = [], []
    max_k = max(1, sample_px // max(1, step_px))

    for idx, (x0, y0) in enumerate(tri_positions):
        theta = pick_bend_angle(jake_point, x0, x_ref, idx, best_idx)
        dx1, dy1 = TRIG_TABLE[theta]

        # Default = GREEN unless we hit something
        hit_colour = COLOR_GREEN

        # march along the ray (tip -> outward), first-hit wins
        found = False
        for k in range(1, max_k + 1):
            t  = k * step_px
            xs = _clampi(int(round(x0 + dx1 * t)), 0, W-1)
            ys = _clampi(int(round(y0 + dy1 * t)), 0, H-1)
            mx = _clampi(int(round(xs * sx)), 0, mw-1)
            my = _clampi(int(round(ys * sy)), 0, mh-1)

            # RED first
            for i in red_idx:
                if masks_np[i][my, mx] > 0.5:
                    hit_colour = COLOR_RED; found = True
                    break
            if found: break
            # then YELLOW
            for i in yellow_idx:
                if masks_np[i][my, mx] > 0.5:
                    hit_colour = COLOR_YELLOW; found = True
                    break
            if found: break
            # then BOOTS (pink)
            for i in boots_idx:
                if masks_np[i][my, mx] > 0.5:
                    hit_colour = COLOR_PINK; found = True
                    break
            if found: break
            # otherwise keep walking; stays GREEN

        # end point for viz = full length along bend
        x1 = _clampi(int(round(x0 + dx1 * sample_px)), 0, W-1)
        y1 = _clampi(int(round(y0 + dy1 * sample_px)), 0, H-1)

        colours.append(hit_colour)
        rays.append(((int(x0), int(y0)), (x1, y1), float(theta)))

    return colours, rays
# ------------------------------------------------------------------------------

# =======================
# Frame post-processing
# =======================
def process_frame_post(frame_bgr, yolo_res):
    H, W = frame_bgr.shape[:2]
    if yolo_res.masks is None:
        return None, 0, 0, 0.0, 0.0, None, None, None, None, [], [], [], None, None, None

    t0 = time.perf_counter()
    masks_np = yolo_res.masks.data.detach().cpu().numpy()  # [n,h,w]
    if hasattr(yolo_res.masks, "cls") and yolo_res.masks.cls is not None:
        classes_np = yolo_res.masks.cls.detach().cpu().numpy().astype(int)
    else:
        classes_np = yolo_res.boxes.cls.detach().cpu().numpy().astype(int)
    to_cpu_ms = (time.perf_counter() - t0) * 1000.0
    mask_count = int(masks_np.shape[0])
    if mask_count == 0 or classes_np.size == 0:
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    rail_sel = (classes_np == RAIL_ID)
    if not np.any(rail_sel):
        return None, 0, mask_count, to_cpu_ms, 0.0, masks_np, classes_np, None, None, [], [], [], None, None, None

    t1 = time.perf_counter()
    rail_masks = masks_np[rail_sel].astype(bool, copy=False)
    union = np.any(rail_masks, axis=0).astype(np.uint8, copy=False)
    rail_mask = cv2.resize(union, (W, H), interpolation=cv2.INTER_NEAREST).astype(bool, copy=False)

    green = highlight_rails_mask_only_fast(frame_bgr, rail_mask)
    red   = np.logical_and(rail_mask, np.logical_not(green))
    score = red_vs_green_score(red, green)
    tri_positions, tri_best = purple_triangles(score, H)

    # Jake triangle by bearing
    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    xj, yj = JAKE_POINT
    best_idx, best_deg, _ = select_triangle_by_bearing(tri_positions, xj, yj, target_deg, min_dy=6)

    # x_ref for bending
    if lane_name == "mid" and (best_idx is not None) and (0 <= best_idx < len(tri_positions)):
        x_ref = tri_positions[best_idx][0]
    else:
        x_ref = xj

    tri_colours, tri_rays = classify_triangles_at_sample_curved(
        tri_positions, masks_np, classes_np, H, W, JAKE_POINT, x_ref, best_idx,
        SAMPLE_UP_PX, RAY_STEP_PX
    )
    post_ms = (time.perf_counter() - t1) * 1000.0

    return tri_best, len(tri_positions), mask_count, to_cpu_ms, post_ms, masks_np, classes_np, rail_mask, green, tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref

# =======================
# Viz helpers
# =======================
def _colour_for_point(x, y, masks_np, classes_np, H, W):
    if masks_np is None or classes_np is None or masks_np.size == 0: return COLOR_GREEN
    mh, mw = masks_np.shape[1], masks_np.shape[2]
    sx = (mw - 1) / max(1, (W - 1)); sy = (mh - 1) / max(1, (H - 1))
    mx = _clampi(int(round(x * sx)), 0, mw-1)
    my = _clampi(int(round(y * sy)), 0, mh-1)
    cls_here = None
    for m, c in zip(masks_np, classes_np):
        if m[my, mx] > 0.5: cls_here = int(c); break
    if cls_here in DANGER_RED:   return COLOR_RED
    if cls_here in WARN_YELLOW:  return COLOR_YELLOW
    if cls_here in BOOTS_PINK:   return COLOR_PINK
    return COLOR_GREEN

def draw_triangle(img, x, y, size=TRI_SIZE_PX, colour=COLOR_RED):
    h = int(size * 1.2)
    pts = np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)
    cv2.fillConvexPoly(img, pts, colour)
    cv2.polylines(img, [pts.reshape(-1,1,2)], True, COLOR_BLACK, 1, cv2.LINE_AA)

def triangle_pts(x, y, size=TRI_SIZE_PX):
    h = int(size * 1.2)
    return np.array([[x, y], [x-size, y+h], [x+size, y+h]], np.int32)

def render_overlays(frame_bgr, masks_np, classes_np, rail_mask, green_mask,
                    tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref):
    out = frame_bgr.copy()
    H, W = out.shape[:2]
    alpha = 0.45

    if masks_np is not None and classes_np is not None and masks_np.size:
        for m, c in zip(masks_np, classes_np):
            m_full = m
            if m.shape != (H, W):
                m_full = cv2.resize(m.astype(np.uint8), (W, H), interpolation=cv2.INTER_NEAREST).astype(bool)
            color = CLASS_COLOURS.get(int(c), (255,255,255))
            out[m_full] = (np.array(color, dtype=np.uint8) * alpha + out[m_full] * (1 - alpha)).astype(np.uint8)
            ys, xs = np.where(m_full)
            if xs.size:
                xc, yc = int(xs.mean()), int(ys.mean())
                label = LABELS.get(int(c), f"C{int(c)}")
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, COLOR_BLACK, 2, cv2.LINE_AA)
                cv2.putText(out, label, (max(5, xc-40), max(20, yc)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 1, cv2.LINE_AA)

    if rail_mask is not None:
        tint = out.copy()
        tint[rail_mask] = (0, 0, 255)
        out = cv2.addWeighted(tint, 0.30, out, 0.70, 0)
    if green_mask is not None:
        out[green_mask] = (0, 255, 0)

    # tiny scout lines (viz only)
    if tri_positions:
        for (x, y) in tri_positions:
            y_end = max(0, y - SAMPLE_UP_PX)
            for yy in range(y, y_end - 1, -1):
                out[yy, x] = _colour_for_point(x, yy, masks_np, classes_np, H, W)

    # starburst to Jake
    xj, yj = JAKE_POINT
    for idx, (xt, yt) in enumerate(tri_positions):
        xt = _clampi(int(xt), 0, W-1); yt = _clampi(int(yt), 0, H-1)
        deg_signed = signed_degrees_from_vertical(xt - xj, yt - yj)
        cv2.line(out, (xj, yj), (xt, yt),
                 COLOR_CYAN if idx == best_idx else COLOR_WHITE, 2, cv2.LINE_AA)
        mx = (xj + xt) // 2; my = (yj + yt) // 2
        txt = f"{deg_signed:.1f}°"
        cv2.putText(out, txt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, txt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    # curved sampling rays (viz)
    for (p0, p1, theta) in tri_rays:
        cv2.line(out, p0, p1, (255,255,255), 2, cv2.LINE_AA)
        mx = (p0[0] + p1[0]) // 2; my = (p0[1] + p1[1]) // 2
        ttxt = f"{theta:+.1f}°"
        cv2.putText(out, ttxt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, ttxt, (mx, my), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)

    for (x, y), col in zip(tri_positions, tri_colours):
        draw_triangle(out, int(x), int(y), colour=col)

    lane_name = lane_name_from_point(JAKE_POINT)
    target_deg = LANE_TARGET_DEG[lane_name]
    if best_idx is not None and 0 <= best_idx < len(tri_positions):
        xt, yt = tri_positions[best_idx]
        pts = triangle_pts(int(xt), int(yt), size=TRI_SIZE_PX)
        cv2.polylines(out, [pts.reshape(-1,1,2)], True, COLOR_CYAN, 3, cv2.LINE_AA)
        tag = f"JAKE_TRI ({lane_name}: target {target_deg:.1f}°)"
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, COLOR_BLACK, 2, cv2.LINE_AA)
        cv2.putText(out, tag, (max(5, int(xt)-70), max(20, int(yt)-16)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.55, (255,255,255), 1, cv2.LINE_AA)
    return out

# =======================
# Run
# =======================
def run_pipeline_with_prints_and_overlays():
    paths = (
        glob.glob(str(frames_dir/"frame_*.jpg")) +
        glob.glob(str(frames_dir/"frame_*.png")) +
        glob.glob(str(frames_dir/"*.jpg")) +
        glob.glob(str(frames_dir/"*.png"))
    )
    paths = sorted(set(paths))
    if not paths:
        raise FileNotFoundError(f"No images in: {frames_dir}")
    if SHOW_FIRST_N is not None:
        paths = paths[:SHOW_FIRST_N]

    N = len(paths)

    def load_batch(batch_paths):
        imgs, read_ms = [None]*len(batch_paths), [0.0]*len(batch_paths)
        with ThreadPoolExecutor(max_workers=THREADS_IO) as ex:
            fut2i = {ex.submit(load_image_with_time, p): i for i, p in enumerate(batch_paths)}
            for fut in as_completed(fut2i):
                i = fut2i[fut]
                im, r = fut.result()
                imgs[i] = im; read_ms[i] = r
        ok = [(p, im, rm) for p, im, rm in zip(batch_paths, imgs, read_ms) if im is not None]
        if not ok: return [], [], []
        b_paths, b_imgs, b_read = zip(*ok)
        return list(b_paths), list(b_imgs), list(b_read)

    idx_global = 0
    for batch_paths in chunked(paths, 1):
        batch_paths, imgs_bgr, read_ms_list = load_batch(batch_paths)
        if not imgs_bgr:
            idx_global += len(batch_paths); continue

        t0_inf = time.perf_counter()
        res_list = model.predict(
            imgs_bgr, task="segment", imgsz=IMG_SIZE, device=device,
            conf=CONF, iou=IOU, verbose=False, half=half, max_det=MAX_DET, batch=1
        )
        try:
            if device == 0 and torch.cuda.is_available(): torch.cuda.synchronize()
            elif device == "mps" and getattr(torch.backends, "mps", None) and torch.backends.mps.is_available():
                torch.mps.synchronize()
        except Exception: pass
        infer_ms_share = (time.perf_counter() - t0_inf) * 1000.0

        for j, (img, yres, read_ms) in enumerate(zip(imgs_bgr, res_list, read_ms_list)):
            (tri_best_xy, tri_count, mask_count, to_cpu_ms, post_ms,
             masks_np, classes_np, rail_mask, green_mask, tri_positions, tri_colours,
             tri_rays, best_idx, best_deg, x_ref) = process_frame_post(img, yres)

            proc_ms = infer_ms_share + to_cpu_ms + post_ms
            fname = os.path.basename(batch_paths[j])
            frame_idx = idx_global + j + 1

            print(f"[{frame_idx}/{N}] {fname}  "
                  f"read {read_ms:.1f} | infer {infer_ms_share:.1f} | "
                  f"to_cpu {to_cpu_ms:.1f} | post {post_ms:.1f} | "
                  f"masks {mask_count} | triangles {tri_count} "
                  f"=> proc {proc_ms:.1f} ms")

            if frame_idx <= RENDER_FIRST_N:
                overlay = render_overlays(img, masks_np, classes_np, rail_mask, green_mask,
                                          tri_positions, tri_colours, tri_rays, best_idx, best_deg, x_ref)
                out_path = out_dir / f"overlay_{frame_idx:04d}_{fname}"
                cv2.imwrite(str(out_path), overlay)

        idx_global += 1

# =======================
# Entry
# =======================
if __name__ == "__main__":
    run_pipeline_with_prints_and_overlays()
# Out:
# YOLO11n-seg summary (fused): 113 layers, 2,836,908 parameters, 0 gradients, 10.2 GFLOPs
# [1/312] frame_00000.png  read 29.0 | infer 94.1 | to_cpu 0.6 | post 0.0 | masks 1 | triangles 0 => proc 94.7 ms
# [2/312] frame_00001.png  read 29.3 | infer 38.1 | to_cpu 0.7 | post 65.8 | masks 3 | triangles 1 => proc 104.6 ms
# [3/312] frame_00002.png  read 29.5 | infer 33.2 | to_cpu 0.6 | post 76.3 | masks 3 | triangles 3 => proc 110.1 ms
# [4/312] frame_00003.png  read 34.3 | infer 36.2 | to_cpu 0.7 | post 87.4 | masks 3 | triangles 2 => proc 124.3 ms
# [5/312] frame_00004.png  read 32.4 | infer 38.5 | to_cpu 0.7 | post 119.3 | masks 4 | triangles 1 => proc 158.5 ms
# [6/312] frame_00005.png  read 32.5 | infer 38.4 | to_cpu 0.8 | post 117.9 | masks 5 | triangles 1 => proc 157.1 ms
# [7/312] frame_00006.png  read 30.0 | infer 115.0 | to_cpu 5.4 | post 130.7 | masks 5 | triangles 2 => proc 251.1 ms
# [8/312] frame_00007.png  read 29.3 | infer 34.6 | to_cpu 0.7 | post 125.4 | masks 4 | triangles 2 => proc 160.7 ms
# [9/312] frame_00008.png  read 28.6 | infer 35.5 | to_cpu 0.7 | post 123.5 | masks 5 | triangles 2 => proc 159.8 ms
# [10/312] frame_00009.png  read 29.5 | infer 35.1 | to_cpu 0.8 | post 118.4 | masks 4 | triangles 2 => proc 154.2 ms
# [11/312] frame_00010.png  read 29.9 | infer 32.5 | to_cpu 0.7 | post 128.0 | masks 4 | triangles 2 => proc 161.3 ms
# [12/312] frame_00011.png  read 139.1 | infer 114.6 | to_cpu 0.9 | post 156.2 | masks 3 | triangles 3 => proc 271.7 ms
# [13/312] frame_00012.png  read 31.6 | infer 39.9 | to_cpu 0.7 | post 128.9 | masks 3 | triangles 3 => proc 169.6 ms
# [14/312] frame_00013.png  read 30.7 | infer 36.3 | to_cpu 0.7 | post 145.0 | masks 3 | triangles 3 => proc 182.0 ms
# [15/312] frame_00014.png  read 31.8 | infer 37.7 | to_cpu 0.8 | post 137.3 | masks 4 | triangles 2 => proc 175.8 ms
# [16/312] frame_00015.png  read 32.1 | infer 35.3 | to_cpu 0.7 | post 136.3 | masks 5 | triangles 2 => proc 172.3 ms
# [17/312] frame_00016.png  read 40.4 | infer 32.4 | to_cpu 0.7 | post 115.1 | masks 4 | triangles 2 => proc 148.1 ms
# [18/312] frame_00017.png  read 30.0 | infer 33.2 | to_cpu 0.6 | post 124.5 | masks 4 | triangles 2 => proc 158.3 ms
# [19/312] frame_00018.png  read 29.7 | infer 38.5 | to_cpu 0.7 | post 121.1 | masks 4 | triangles 2 => proc 160.3 ms
# [20/312] frame_00019.png  read 29.7 | infer 37.1 | to_cpu 0.6 | post 124.5 | masks 3 | triangles 2 => proc 162.2 ms
# [21/312] frame_00020.png  read 31.8 | infer 31.3 | to_cpu 0.7 | post 107.2 | masks 3 | triangles 1 => proc 139.1 ms
# [22/312] frame_00021.png  read 29.0 | infer 48.9 | to_cpu 0.8 | post 93.0 | masks 4 | triangles 1 => proc 142.7 ms
# [23/312] frame_00022.png  read 31.8 | infer 67.6 | to_cpu 0.8 | post 94.7 | masks 4 | triangles 1 => proc 163.1 ms
# [24/312] frame_00023.png  read 28.7 | infer 31.8 | to_cpu 0.7 | post 83.6 | masks 4 | triangles 1 => proc 116.2 ms
# [25/312] frame_00024.png  read 31.8 | infer 31.5 | to_cpu 0.7 | post 80.3 | masks 4 | triangles 1 => proc 112.4 ms
# [26/312] frame_00025.png  read 29.0 | infer 36.5 | to_cpu 0.7 | post 72.2 | masks 4 | triangles 1 => proc 109.5 ms
# [27/312] frame_00026.png  read 32.4 | infer 35.7 | to_cpu 0.7 | post 64.6 | masks 5 | triangles 1 => proc 101.0 ms
# [28/312] frame_00027.png  read 28.2 | infer 31.0 | to_cpu 0.7 | post 48.5 | masks 3 | triangles 1 => proc 80.2 ms
# [29/312] frame_00028.png  read 32.2 | infer 30.7 | to_cpu 1.2 | post 31.6 | masks 5 | triangles 1 => proc 63.5 ms
# [30/312] frame_00029.png  read 31.8 | infer 37.9 | to_cpu 0.9 | post 29.4 | masks 6 | triangles 1 => proc 68.2 ms
# [31/312] frame_00030.png  read 31.8 | infer 37.6 | to_cpu 0.9 | post 53.9 | masks 6 | triangles 2 => proc 92.4 ms
# [32/312] frame_00031.png  read 35.2 | infer 36.7 | to_cpu 0.9 | post 59.7 | masks 6 | triangles 1 => proc 97.4 ms
# [33/312] frame_00032.png  read 29.8 | infer 29.3 | to_cpu 0.8 | post 106.1 | masks 5 | triangles 1 => proc 136.2 ms
# [34/312] frame_00033.png  read 29.6 | infer 29.8 | to_cpu 0.7 | post 82.6 | masks 3 | triangles 2 => proc 113.0 ms
# [35/312] frame_00034.png  read 31.3 | infer 35.6 | to_cpu 1.0 | post 93.2 | masks 4 | triangles 2 => proc 129.8 ms
# [36/312] frame_00035.png  read 32.3 | infer 35.6 | to_cpu 0.8 | post 94.8 | masks 4 | triangles 1 => proc 131.2 ms
# [37/312] frame_00036.png  read 28.1 | infer 30.5 | to_cpu 0.7 | post 110.8 | masks 3 | triangles 2 => proc 142.0 ms
# [38/312] frame_00037.png  read 29.1 | infer 36.6 | to_cpu 0.9 | post 105.6 | masks 3 | triangles 1 => proc 143.1 ms
# [39/312] frame_00038.png  read 28.1 | infer 27.6 | to_cpu 0.8 | post 96.0 | masks 4 | triangles 1 => proc 124.3 ms
# [40/312] frame_00039.png  read 32.3 | infer 37.1 | to_cpu 0.7 | post 86.4 | masks 4 | triangles 1 => proc 124.2 ms
# [41/312] frame_00040.png  read 29.2 | infer 43.4 | to_cpu 0.8 | post 88.2 | masks 3 | triangles 1 => proc 132.3 ms
# [42/312] frame_00041.png  read 37.6 | infer 40.6 | to_cpu 0.7 | post 73.8 | masks 3 | triangles 1 => proc 115.2 ms
# [43/312] frame_00042.png  read 31.3 | infer 32.6 | to_cpu 1.0 | post 105.3 | masks 5 | triangles 1 => proc 138.9 ms
# [44/312] frame_00043.png  read 28.8 | infer 30.0 | to_cpu 0.8 | post 118.5 | masks 5 | triangles 2 => proc 149.3 ms
# [45/312] frame_00044.png  read 31.0 | infer 32.4 | to_cpu 0.9 | post 90.2 | masks 4 | triangles 2 => proc 123.4 ms
# [46/312] frame_00045.png  read 28.2 | infer 37.5 | to_cpu 0.7 | post 114.5 | masks 3 | triangles 2 => proc 152.7 ms
# [47/312] frame_00046.png  read 29.8 | infer 30.8 | to_cpu 1.2 | post 110.5 | masks 3 | triangles 1 => proc 142.5 ms
# [48/312] frame_00047.png  read 28.1 | infer 30.9 | to_cpu 0.7 | post 100.1 | masks 3 | triangles 1 => proc 131.8 ms
# [49/312] frame_00048.png  read 31.4 | infer 30.0 | to_cpu 1.6 | post 125.4 | masks 3 | triangles 2 => proc 156.9 ms
# [50/312] frame_00049.png  read 28.8 | infer 44.0 | to_cpu 1.0 | post 119.1 | masks 2 | triangles 2 => proc 164.0 ms
# [51/312] frame_00050.png  read 32.1 | infer 34.7 | to_cpu 0.7 | post 130.3 | masks 2 | triangles 2 => proc 165.6 ms
# [52/312] frame_00051.png  read 28.9 | infer 41.6 | to_cpu 0.8 | post 119.2 | masks 2 | triangles 2 => proc 161.6 ms
# [53/312] frame_00052.png  read 30.0 | infer 31.4 | to_cpu 0.6 | post 113.2 | masks 2 | triangles 2 => proc 145.2 ms
# [54/312] frame_00053.png  read 29.0 | infer 29.5 | to_cpu 0.6 | post 95.1 | masks 2 | triangles 1 => proc 125.2 ms
# [55/312] frame_00054.png  read 29.1 | infer 26.4 | to_cpu 0.8 | post 97.3 | masks 4 | triangles 1 => proc 124.5 ms
# [56/312] frame_00055.png  read 31.4 | infer 35.5 | to_cpu 0.8 | post 92.1 | masks 4 | triangles 1 => proc 128.4 ms
# [57/312] frame_00056.png  read 31.2 | infer 34.2 | to_cpu 0.8 | post 91.7 | masks 4 | triangles 1 => proc 126.8 ms
# [58/312] frame_00057.png  read 32.0 | infer 33.4 | to_cpu 0.8 | post 90.1 | masks 4 | triangles 1 => proc 124.2 ms
# [59/312] frame_00058.png  read 28.0 | infer 40.0 | to_cpu 0.7 | post 90.4 | masks 5 | triangles 1 => proc 131.1 ms
# [60/312] frame_00059.png  read 32.4 | infer 33.3 | to_cpu 0.6 | post 86.9 | masks 4 | triangles 1 => proc 120.8 ms
# [61/312] frame_00060.png  read 28.8 | infer 31.2 | to_cpu 0.8 | post 86.7 | masks 5 | triangles 1 => proc 118.7 ms
# [62/312] frame_00061.png  read 31.5 | infer 32.7 | to_cpu 0.7 | post 83.0 | masks 4 | triangles 1 => proc 116.5 ms
# [63/312] frame_00062.png  read 31.1 | infer 36.9 | to_cpu 0.9 | post 107.2 | masks 6 | triangles 2 => proc 145.0 ms
# [64/312] frame_00063.png  read 30.4 | infer 26.7 | to_cpu 0.8 | post 116.6 | masks 4 | triangles 2 => proc 144.0 ms
# [65/312] frame_00064.png  read 29.5 | infer 34.8 | to_cpu 0.8 | post 112.8 | masks 5 | triangles 2 => proc 148.4 ms
# [66/312] frame_00065.png  read 29.2 | infer 43.5 | to_cpu 1.1 | post 91.7 | masks 6 | triangles 1 => proc 136.3 ms
# [67/312] frame_00066.png  read 32.8 | infer 31.1 | to_cpu 5.8 | post 108.1 | masks 5 | triangles 2 => proc 145.1 ms
# [68/312] frame_00067.png  read 28.3 | infer 37.9 | to_cpu 0.7 | post 116.8 | masks 5 | triangles 2 => proc 155.5 ms
# [69/312] frame_00068.png  read 30.1 | infer 34.8 | to_cpu 0.7 | post 113.2 | masks 4 | triangles 2 => proc 148.7 ms
# [70/312] frame_00069.png  read 29.1 | infer 36.3 | to_cpu 0.7 | post 123.2 | masks 4 | triangles 2 => proc 160.2 ms
# [71/312] frame_00070.png  read 31.1 | infer 33.2 | to_cpu 0.9 | post 114.9 | masks 5 | triangles 2 => proc 148.9 ms
# [72/312] frame_00071.png  read 28.3 | infer 31.9 | to_cpu 0.8 | post 113.9 | masks 5 | triangles 2 => proc 146.6 ms
# [73/312] frame_00072.png  read 29.8 | infer 29.2 | to_cpu 0.8 | post 108.9 | masks 4 | triangles 2 => proc 138.9 ms
# [74/312] frame_00073.png  read 32.3 | infer 28.7 | to_cpu 0.9 | post 106.6 | masks 4 | triangles 2 => proc 136.1 ms
# [75/312] frame_00074.png  read 30.9 | infer 34.9 | to_cpu 0.8 | post 103.3 | masks 3 | triangles 2 => proc 139.0 ms
# [76/312] frame_00075.png  read 29.7 | infer 31.4 | to_cpu 0.9 | post 99.5 | masks 4 | triangles 2 => proc 131.8 ms
# [77/312] frame_00076.png  read 33.0 | infer 34.4 | to_cpu 0.9 | post 102.5 | masks 5 | triangles 2 => proc 137.8 ms
# [78/312] frame_00077.png  read 28.6 | infer 34.6 | to_cpu 0.8 | post 109.4 | masks 4 | triangles 2 => proc 144.9 ms
# [79/312] frame_00078.png  read 31.8 | infer 30.6 | to_cpu 0.7 | post 65.9 | masks 4 | triangles 1 => proc 97.1 ms
# [80/312] frame_00079.png  read 29.6 | infer 38.3 | to_cpu 0.8 | post 90.2 | masks 4 | triangles 1 => proc 129.2 ms
# [81/312] frame_00080.png  read 32.1 | infer 41.6 | to_cpu 0.6 | post 94.8 | masks 4 | triangles 1 => proc 137.1 ms
# [82/312] frame_00081.png  read 28.7 | infer 32.8 | to_cpu 0.8 | post 113.6 | masks 5 | triangles 2 => proc 147.2 ms
# [83/312] frame_00082.png  read 31.3 | infer 32.9 | to_cpu 0.8 | post 114.1 | masks 3 | triangles 2 => proc 147.9 ms
# [84/312] frame_00083.png  read 28.5 | infer 29.9 | to_cpu 0.9 | post 116.7 | masks 4 | triangles 2 => proc 147.6 ms
# [85/312] frame_00084.png  read 31.5 | infer 29.1 | to_cpu 0.8 | post 114.6 | masks 3 | triangles 2 => proc 144.5 ms
# [86/312] frame_00085.png  read 30.9 | infer 44.9 | to_cpu 0.8 | post 114.1 | masks 3 | triangles 2 => proc 159.8 ms
# [87/312] frame_00086.png  read 29.2 | infer 42.2 | to_cpu 0.6 | post 115.2 | masks 2 | triangles 2 => proc 158.0 ms
# [88/312] frame_00087.png  read 30.4 | infer 34.1 | to_cpu 0.9 | post 123.0 | masks 3 | triangles 1 => proc 157.9 ms
# [89/312] frame_00088.png  read 29.1 | infer 30.7 | to_cpu 0.8 | post 98.6 | masks 4 | triangles 1 => proc 130.1 ms
# [90/312] frame_00089.png  read 32.0 | infer 41.4 | to_cpu 0.9 | post 111.3 | masks 5 | triangles 2 => proc 153.6 ms
# [91/312] frame_00090.png  read 28.7 | infer 49.1 | to_cpu 0.6 | post 117.9 | masks 3 | triangles 2 => proc 167.6 ms
# [92/312] frame_00091.png  read 31.8 | infer 35.5 | to_cpu 0.7 | post 126.8 | masks 3 | triangles 2 => proc 163.0 ms
# [93/312] frame_00092.png  read 28.4 | infer 27.5 | to_cpu 0.7 | post 114.5 | masks 3 | triangles 2 => proc 142.7 ms
# [94/312] frame_00093.png  read 28.1 | infer 29.9 | to_cpu 0.6 | post 115.5 | masks 3 | triangles 2 => proc 146.0 ms
# [95/312] frame_00094.png  read 27.5 | infer 30.7 | to_cpu 0.7 | post 126.1 | masks 2 | triangles 2 => proc 157.4 ms
# [96/312] frame_00095.png  read 29.5 | infer 28.5 | to_cpu 0.6 | post 109.9 | masks 3 | triangles 1 => proc 139.0 ms
# [97/312] frame_00096.png  read 29.0 | infer 33.1 | to_cpu 0.7 | post 92.4 | masks 4 | triangles 1 => proc 126.2 ms
# [98/312] frame_00097.png  read 31.6 | infer 32.2 | to_cpu 0.7 | post 90.3 | masks 4 | triangles 1 => proc 123.3 ms
# [99/312] frame_00098.png  read 29.4 | infer 37.8 | to_cpu 0.8 | post 91.4 | masks 4 | triangles 1 => proc 129.9 ms
# [100/312] frame_00099.png  read 32.6 | infer 34.2 | to_cpu 0.7 | post 89.0 | masks 4 | triangles 1 => proc 123.8 ms
# [101/312] frame_00100.png  read 29.3 | infer 28.2 | to_cpu 0.7 | post 90.7 | masks 3 | triangles 1 => proc 119.6 ms
# [102/312] frame_00101.png  read 31.2 | infer 29.6 | to_cpu 0.7 | post 205.3 | masks 5 | triangles 2 => proc 235.6 ms
# [103/312] frame_00102.png  read 30.6 | infer 37.4 | to_cpu 0.7 | post 127.3 | masks 3 | triangles 2 => proc 165.4 ms
# [104/312] frame_00103.png  read 33.5 | infer 32.4 | to_cpu 0.9 | post 166.2 | masks 4 | triangles 1 => proc 199.5 ms
# [105/312] frame_00104.png  read 30.1 | infer 39.8 | to_cpu 0.7 | post 119.8 | masks 4 | triangles 1 => proc 160.3 ms
# [106/312] frame_00105.png  read 27.8 | infer 30.9 | to_cpu 0.7 | post 116.0 | masks 4 | triangles 3 => proc 147.6 ms
# [107/312] frame_00106.png  read 30.5 | infer 35.2 | to_cpu 1.5 | post 105.7 | masks 5 | triangles 1 => proc 142.4 ms
# [108/312] frame_00107.png  read 29.5 | infer 33.5 | to_cpu 0.9 | post 103.1 | masks 5 | triangles 1 => proc 137.5 ms
# [109/312] frame_00108.png  read 32.7 | infer 42.1 | to_cpu 0.8 | post 112.6 | masks 5 | triangles 2 => proc 155.5 ms
# [110/312] frame_00109.png  read 29.4 | infer 34.0 | to_cpu 1.1 | post 125.3 | masks 5 | triangles 2 => proc 160.4 ms
# [111/312] frame_00110.png  read 29.4 | infer 34.9 | to_cpu 0.7 | post 124.2 | masks 4 | triangles 1 => proc 159.9 ms
# [112/312] frame_00111.png  read 31.7 | infer 31.2 | to_cpu 1.0 | post 111.6 | masks 4 | triangles 2 => proc 143.8 ms
# [113/312] frame_00112.png  read 28.4 | infer 40.3 | to_cpu 1.0 | post 107.3 | masks 4 | triangles 2 => proc 148.6 ms
# [114/312] frame_00113.png  read 33.4 | infer 35.0 | to_cpu 0.9 | post 94.1 | masks 5 | triangles 1 => proc 129.9 ms
# [115/312] frame_00114.png  read 29.3 | infer 35.8 | to_cpu 0.8 | post 91.0 | masks 6 | triangles 1 => proc 127.6 ms
# [116/312] frame_00115.png  read 35.1 | infer 37.8 | to_cpu 1.1 | post 87.4 | masks 6 | triangles 1 => proc 126.4 ms
# [117/312] frame_00116.png  read 29.4 | infer 31.2 | to_cpu 0.8 | post 89.3 | masks 6 | triangles 1 => proc 121.3 ms
# [118/312] frame_00117.png  read 32.2 | infer 30.9 | to_cpu 0.6 | post 100.6 | masks 4 | triangles 2 => proc 132.1 ms
# [119/312] frame_00118.png  read 28.6 | infer 33.8 | to_cpu 0.8 | post 84.7 | masks 5 | triangles 1 => proc 119.3 ms
# [120/312] frame_00119.png  read 32.6 | infer 28.9 | to_cpu 0.9 | post 102.9 | masks 6 | triangles 2 => proc 132.7 ms
# [121/312] frame_00120.png  read 28.6 | infer 34.8 | to_cpu 0.9 | post 111.0 | masks 6 | triangles 1 => proc 146.8 ms
# [122/312] frame_00121.png  read 32.4 | infer 39.4 | to_cpu 1.6 | post 109.8 | masks 6 | triangles 2 => proc 150.8 ms
# [123/312] frame_00122.png  read 30.1 | infer 37.1 | to_cpu 0.9 | post 106.8 | masks 7 | triangles 1 => proc 144.8 ms
# [124/312] frame_00123.png  read 30.7 | infer 44.7 | to_cpu 1.4 | post 106.0 | masks 10 | triangles 1 => proc 152.1 ms
# [125/312] frame_00124.png  read 29.2 | infer 44.3 | to_cpu 2.3 | post 106.1 | masks 9 | triangles 1 => proc 152.6 ms
# [126/312] frame_00125.png  read 32.0 | infer 30.0 | to_cpu 1.1 | post 107.3 | masks 9 | triangles 2 => proc 138.5 ms
# [127/312] frame_00126.png  read 30.0 | infer 33.1 | to_cpu 0.8 | post 101.4 | masks 5 | triangles 1 => proc 135.3 ms
# [128/312] frame_00127.png  read 30.3 | infer 37.5 | to_cpu 0.8 | post 121.3 | masks 5 | triangles 2 => proc 159.6 ms
# [129/312] frame_00128.png  read 31.0 | infer 32.0 | to_cpu 0.7 | post 122.2 | masks 3 | triangles 3 => proc 154.9 ms
# [130/312] frame_00129.png  read 29.2 | infer 36.9 | to_cpu 0.8 | post 119.4 | masks 3 | triangles 3 => proc 157.2 ms
# [131/312] frame_00130.png  read 28.9 | infer 30.2 | to_cpu 0.7 | post 120.2 | masks 3 | triangles 2 => proc 151.1 ms
# [132/312] frame_00131.png  read 26.9 | infer 34.2 | to_cpu 0.7 | post 136.6 | masks 4 | triangles 2 => proc 171.5 ms
# [133/312] frame_00132.png  read 28.8 | infer 40.2 | to_cpu 2.3 | post 117.1 | masks 3 | triangles 2 => proc 159.6 ms
# [134/312] frame_00133.png  read 24.9 | infer 28.8 | to_cpu 0.9 | post 107.7 | masks 3 | triangles 1 => proc 137.4 ms
# [135/312] frame_00134.png  read 25.4 | infer 33.5 | to_cpu 0.6 | post 80.6 | masks 3 | triangles 1 => proc 114.7 ms
# [136/312] frame_00135.png  read 23.5 | infer 36.2 | to_cpu 1.1 | post 69.0 | masks 2 | triangles 1 => proc 106.3 ms
# [137/312] frame_00136.png  read 25.1 | infer 26.4 | to_cpu 0.7 | post 67.6 | masks 2 | triangles 1 => proc 94.7 ms
# [138/312] frame_00137.png  read 24.5 | infer 31.3 | to_cpu 0.7 | post 70.1 | masks 2 | triangles 1 => proc 102.1 ms
# [139/312] frame_00138.png  read 27.3 | infer 29.0 | to_cpu 0.7 | post 100.0 | masks 3 | triangles 2 => proc 129.7 ms
# [140/312] frame_00139.png  read 32.5 | infer 33.7 | to_cpu 0.6 | post 118.2 | masks 2 | triangles 2 => proc 152.5 ms
# [141/312] frame_00140.png  read 27.8 | infer 33.4 | to_cpu 0.6 | post 116.4 | masks 3 | triangles 2 => proc 150.4 ms
# [142/312] frame_00141.png  read 29.6 | infer 35.8 | to_cpu 0.8 | post 114.0 | masks 3 | triangles 2 => proc 150.6 ms
# [143/312] frame_00142.png  read 28.3 | infer 34.9 | to_cpu 0.9 | post 116.3 | masks 3 | triangles 2 => proc 152.1 ms
# [144/312] frame_00143.png  read 31.2 | infer 46.8 | to_cpu 0.7 | post 164.8 | masks 3 | triangles 2 => proc 212.4 ms
# [145/312] frame_00144.png  read 28.0 | infer 32.3 | to_cpu 1.0 | post 113.0 | masks 3 | triangles 2 => proc 146.3 ms
# [146/312] frame_00145.png  read 30.5 | infer 29.7 | to_cpu 0.8 | post 92.6 | masks 4 | triangles 1 => proc 123.1 ms
# [147/312] frame_00146.png  read 28.6 | infer 33.8 | to_cpu 0.7 | post 94.2 | masks 4 | triangles 1 => proc 128.7 ms
# [148/312] frame_00147.png  read 33.2 | infer 37.3 | to_cpu 0.7 | post 82.3 | masks 4 | triangles 1 => proc 120.3 ms
# [149/312] frame_00148.png  read 29.4 | infer 40.9 | to_cpu 0.9 | post 81.3 | masks 4 | triangles 1 => proc 123.0 ms
# [150/312] frame_00149.png  read 35.3 | infer 39.6 | to_cpu 0.7 | post 94.2 | masks 6 | triangles 1 => proc 134.4 ms
# [151/312] frame_00150.png  read 29.1 | infer 42.1 | to_cpu 2.2 | post 91.0 | masks 7 | triangles 1 => proc 135.3 ms
# [152/312] frame_00151.png  read 32.9 | infer 36.4 | to_cpu 1.1 | post 98.9 | masks 7 | triangles 2 => proc 136.4 ms
# [153/312] frame_00152.png  read 30.3 | infer 36.9 | to_cpu 0.8 | post 102.4 | masks 5 | triangles 1 => proc 140.1 ms
# [154/312] frame_00153.png  read 31.0 | infer 27.4 | to_cpu 0.8 | post 87.3 | masks 5 | triangles 1 => proc 115.5 ms
# [155/312] frame_00154.png  read 28.7 | infer 36.8 | to_cpu 0.7 | post 121.6 | masks 6 | triangles 2 => proc 159.2 ms
# [156/312] frame_00155.png  read 34.4 | infer 35.3 | to_cpu 0.9 | post 109.4 | masks 6 | triangles 2 => proc 145.6 ms
# [157/312] frame_00156.png  read 28.8 | infer 34.4 | to_cpu 0.8 | post 115.6 | masks 5 | triangles 2 => proc 150.8 ms
# [158/312] frame_00157.png  read 31.3 | infer 32.5 | to_cpu 0.6 | post 107.4 | masks 3 | triangles 2 => proc 140.5 ms
# [159/312] frame_00158.png  read 28.7 | infer 26.3 | to_cpu 0.8 | post 108.9 | masks 5 | triangles 2 => proc 136.0 ms
# [160/312] frame_00159.png  read 31.3 | infer 52.1 | to_cpu 0.8 | post 96.6 | masks 5 | triangles 2 => proc 149.5 ms
# [161/312] frame_00160.png  read 28.8 | infer 33.7 | to_cpu 1.4 | post 120.4 | masks 5 | triangles 2 => proc 155.4 ms
# [162/312] frame_00161.png  read 33.0 | infer 33.5 | to_cpu 0.8 | post 88.0 | masks 4 | triangles 1 => proc 122.4 ms
# [163/312] frame_00162.png  read 28.9 | infer 35.9 | to_cpu 1.3 | post 143.1 | masks 6 | triangles 2 => proc 180.3 ms
# [164/312] frame_00163.png  read 31.1 | infer 37.9 | to_cpu 8.0 | post 176.4 | masks 4 | triangles 2 => proc 222.4 ms
# [165/312] frame_00164.png  read 29.9 | infer 31.9 | to_cpu 0.7 | post 123.3 | masks 5 | triangles 2 => proc 155.9 ms
# [166/312] frame_00165.png  read 30.4 | infer 33.7 | to_cpu 0.6 | post 134.6 | masks 4 | triangles 2 => proc 168.9 ms
# [167/312] frame_00166.png  read 28.6 | infer 27.0 | to_cpu 0.8 | post 114.4 | masks 4 | triangles 2 => proc 142.2 ms
# [168/312] frame_00167.png  read 30.5 | infer 30.9 | to_cpu 0.8 | post 115.4 | masks 5 | triangles 2 => proc 147.1 ms
# [169/312] frame_00168.png  read 30.5 | infer 33.2 | to_cpu 0.7 | post 125.8 | masks 4 | triangles 2 => proc 159.7 ms
# [170/312] frame_00169.png  read 30.7 | infer 31.6 | to_cpu 0.7 | post 121.6 | masks 4 | triangles 2 => proc 154.0 ms
# [171/312] frame_00170.png  read 30.4 | infer 33.1 | to_cpu 0.6 | post 121.0 | masks 3 | triangles 3 => proc 154.7 ms
# [172/312] frame_00171.png  read 29.2 | infer 36.3 | to_cpu 0.8 | post 117.4 | masks 4 | triangles 2 => proc 154.4 ms
# [173/312] frame_00172.png  read 31.3 | infer 39.0 | to_cpu 0.9 | post 115.8 | masks 6 | triangles 2 => proc 155.7 ms
# [174/312] frame_00173.png  read 29.2 | infer 34.0 | to_cpu 0.9 | post 120.6 | masks 6 | triangles 2 => proc 155.6 ms
# [175/312] frame_00174.png  read 29.3 | infer 34.4 | to_cpu 0.8 | post 110.5 | masks 5 | triangles 2 => proc 145.7 ms
# [176/312] frame_00175.png  read 31.1 | infer 33.6 | to_cpu 0.8 | post 110.2 | masks 5 | triangles 2 => proc 144.5 ms
# [177/312] frame_00176.png  read 28.7 | infer 33.2 | to_cpu 0.7 | post 102.2 | masks 4 | triangles 2 => proc 136.2 ms
# [178/312] frame_00177.png  read 32.5 | infer 31.6 | to_cpu 0.7 | post 31.2 | masks 4 | triangles 1 => proc 63.6 ms
# [179/312] frame_00178.png  read 28.1 | infer 31.6 | to_cpu 0.9 | post 0.0 | masks 6 | triangles 0 => proc 32.5 ms
# [180/312] frame_00179.png  read 27.6 | infer 29.0 | to_cpu 1.0 | post 0.0 | masks 5 | triangles 0 => proc 30.0 ms
# [181/312] frame_00180.png  read 26.8 | infer 48.6 | to_cpu 2.6 | post 0.0 | masks 7 | triangles 0 => proc 51.3 ms
# [182/312] frame_00181.png  read 30.3 | infer 33.8 | to_cpu 0.8 | post 34.8 | masks 6 | triangles 1 => proc 69.4 ms
# [183/312] frame_00182.png  read 27.4 | infer 47.9 | to_cpu 0.8 | post 77.8 | masks 5 | triangles 2 => proc 126.5 ms
# [184/312] frame_00183.png  read 30.1 | infer 36.0 | to_cpu 0.9 | post 93.4 | masks 4 | triangles 3 => proc 130.3 ms
# [185/312] frame_00184.png  read 29.2 | infer 36.7 | to_cpu 0.8 | post 95.1 | masks 4 | triangles 1 => proc 132.6 ms
# [186/312] frame_00185.png  read 32.2 | infer 30.6 | to_cpu 0.8 | post 96.6 | masks 5 | triangles 1 => proc 128.1 ms
# [187/312] frame_00186.png  read 30.3 | infer 35.7 | to_cpu 1.9 | post 94.0 | masks 3 | triangles 1 => proc 131.6 ms
# [188/312] frame_00187.png  read 31.1 | infer 36.3 | to_cpu 0.7 | post 129.1 | masks 2 | triangles 2 => proc 166.0 ms
# [189/312] frame_00188.png  read 29.7 | infer 29.2 | to_cpu 0.6 | post 124.5 | masks 2 | triangles 2 => proc 154.3 ms
# [190/312] frame_00189.png  read 28.8 | infer 33.5 | to_cpu 0.6 | post 93.0 | masks 3 | triangles 1 => proc 127.1 ms
# [191/312] frame_00190.png  read 33.2 | infer 37.7 | to_cpu 1.0 | post 96.5 | masks 3 | triangles 1 => proc 135.3 ms
# [192/312] frame_00191.png  read 29.3 | infer 32.2 | to_cpu 0.8 | post 90.1 | masks 3 | triangles 1 => proc 123.2 ms
# [193/312] frame_00192.png  read 32.0 | infer 32.4 | to_cpu 0.7 | post 94.7 | masks 3 | triangles 1 => proc 127.9 ms
# [194/312] frame_00193.png  read 30.5 | infer 30.3 | to_cpu 0.6 | post 99.4 | masks 3 | triangles 1 => proc 130.3 ms
# [195/312] frame_00194.png  read 29.1 | infer 31.4 | to_cpu 0.7 | post 116.9 | masks 2 | triangles 2 => proc 149.1 ms
# [196/312] frame_00195.png  read 30.5 | infer 26.6 | to_cpu 0.6 | post 115.5 | masks 2 | triangles 2 => proc 142.7 ms
# [197/312] frame_00196.png  read 29.8 | infer 28.2 | to_cpu 0.6 | post 98.7 | masks 3 | triangles 1 => proc 127.5 ms
# [198/312] frame_00197.png  read 28.4 | infer 40.7 | to_cpu 1.0 | post 91.2 | masks 3 | triangles 1 => proc 132.8 ms
# [199/312] frame_00198.png  read 37.2 | infer 30.2 | to_cpu 0.8 | post 90.5 | masks 3 | triangles 1 => proc 121.5 ms
# [200/312] frame_00199.png  read 28.6 | infer 27.8 | to_cpu 0.6 | post 119.4 | masks 2 | triangles 2 => proc 147.8 ms
# [201/312] frame_00200.png  read 30.6 | infer 33.4 | to_cpu 0.6 | post 120.0 | masks 2 | triangles 2 => proc 154.1 ms
# [202/312] frame_00201.png  read 29.7 | infer 35.5 | to_cpu 0.7 | post 92.2 | masks 3 | triangles 1 => proc 128.4 ms
# [203/312] frame_00202.png  read 32.3 | infer 35.1 | to_cpu 1.0 | post 89.4 | masks 3 | triangles 1 => proc 125.5 ms
# [204/312] frame_00203.png  read 29.3 | infer 31.7 | to_cpu 1.0 | post 110.7 | masks 2 | triangles 2 => proc 143.4 ms
# [205/312] frame_00204.png  read 31.1 | infer 33.9 | to_cpu 0.5 | post 133.8 | masks 1 | triangles 2 => proc 168.2 ms
# [206/312] frame_00205.png  read 28.7 | infer 40.2 | to_cpu 0.7 | post 129.6 | masks 3 | triangles 2 => proc 170.5 ms
# [207/312] frame_00206.png  read 30.7 | infer 31.3 | to_cpu 0.8 | post 117.4 | masks 3 | triangles 2 => proc 149.5 ms
# [208/312] frame_00207.png  read 30.1 | infer 31.6 | to_cpu 0.6 | post 128.6 | masks 2 | triangles 3 => proc 160.8 ms
# [209/312] frame_00208.png  read 29.0 | infer 32.4 | to_cpu 0.7 | post 122.3 | masks 3 | triangles 3 => proc 155.4 ms
# [210/312] frame_00209.png  read 30.5 | infer 37.3 | to_cpu 0.7 | post 119.8 | masks 4 | triangles 3 => proc 157.7 ms
# [211/312] frame_00210.png  read 29.0 | infer 29.7 | to_cpu 0.9 | post 119.7 | masks 4 | triangles 3 => proc 150.3 ms
# [212/312] frame_00211.png  read 31.9 | infer 29.6 | to_cpu 0.7 | post 120.1 | masks 4 | triangles 2 => proc 150.4 ms
# [213/312] frame_00212.png  read 28.3 | infer 30.4 | to_cpu 1.2 | post 134.8 | masks 3 | triangles 3 => proc 166.3 ms
# [214/312] frame_00213.png  read 33.1 | infer 32.3 | to_cpu 0.6 | post 127.4 | masks 3 | triangles 3 => proc 160.3 ms
# [215/312] frame_00214.png  read 29.9 | infer 28.5 | to_cpu 0.6 | post 127.9 | masks 3 | triangles 3 => proc 157.0 ms
# [216/312] frame_00215.png  read 31.0 | infer 30.8 | to_cpu 1.0 | post 119.8 | masks 3 | triangles 2 => proc 151.6 ms
# [217/312] frame_00216.png  read 30.5 | infer 35.7 | to_cpu 0.9 | post 113.1 | masks 5 | triangles 2 => proc 149.7 ms
# [218/312] frame_00217.png  read 28.8 | infer 33.3 | to_cpu 0.8 | post 125.6 | masks 5 | triangles 2 => proc 159.7 ms
# [219/312] frame_00218.png  read 32.4 | infer 86.5 | to_cpu 0.7 | post 116.4 | masks 4 | triangles 2 => proc 203.6 ms
# [220/312] frame_00219.png  read 28.6 | infer 32.2 | to_cpu 0.7 | post 129.7 | masks 3 | triangles 2 => proc 162.7 ms
# [221/312] frame_00220.png  read 31.8 | infer 29.2 | to_cpu 0.8 | post 111.5 | masks 3 | triangles 1 => proc 141.5 ms
# [222/312] frame_00221.png  read 31.0 | infer 29.0 | to_cpu 0.6 | post 91.3 | masks 4 | triangles 1 => proc 120.9 ms
# [223/312] frame_00222.png  read 32.3 | infer 34.7 | to_cpu 0.9 | post 79.3 | masks 4 | triangles 1 => proc 115.0 ms
# [224/312] frame_00223.png  read 31.2 | infer 36.7 | to_cpu 0.8 | post 96.9 | masks 5 | triangles 1 => proc 134.3 ms
# [225/312] frame_00224.png  read 34.1 | infer 51.0 | to_cpu 0.9 | post 93.3 | masks 5 | triangles 1 => proc 145.2 ms
# [226/312] frame_00225.png  read 28.7 | infer 38.0 | to_cpu 0.8 | post 95.8 | masks 3 | triangles 1 => proc 134.7 ms
# [227/312] frame_00226.png  read 32.5 | infer 30.0 | to_cpu 1.7 | post 122.1 | masks 3 | triangles 2 => proc 153.8 ms
# [228/312] frame_00227.png  read 28.1 | infer 35.2 | to_cpu 0.7 | post 118.3 | masks 2 | triangles 2 => proc 154.3 ms
# [229/312] frame_00228.png  read 29.5 | infer 27.3 | to_cpu 1.4 | post 113.9 | masks 2 | triangles 2 => proc 142.6 ms
# [230/312] frame_00229.png  read 28.3 | infer 31.1 | to_cpu 0.8 | post 79.3 | masks 4 | triangles 1 => proc 111.2 ms
# [231/312] frame_00230.png  read 30.7 | infer 28.6 | to_cpu 0.8 | post 99.7 | masks 4 | triangles 1 => proc 129.1 ms
# [232/312] frame_00231.png  read 27.5 | infer 30.0 | to_cpu 0.8 | post 114.3 | masks 5 | triangles 2 => proc 145.1 ms
# [233/312] frame_00232.png  read 27.1 | infer 37.2 | to_cpu 0.7 | post 113.1 | masks 4 | triangles 2 => proc 151.0 ms
# [234/312] frame_00233.png  read 29.9 | infer 33.9 | to_cpu 0.9 | post 108.9 | masks 5 | triangles 2 => proc 143.6 ms
# [235/312] frame_00234.png  read 26.6 | infer 30.5 | to_cpu 0.6 | post 97.2 | masks 3 | triangles 2 => proc 128.3 ms
# [236/312] frame_00235.png  read 29.1 | infer 35.3 | to_cpu 0.7 | post 39.0 | masks 3 | triangles 0 => proc 75.0 ms
# [237/312] frame_00236.png  read 26.5 | infer 28.9 | to_cpu 0.6 | post 0.0 | masks 2 | triangles 0 => proc 29.5 ms
# [238/312] frame_00237.png  read 28.9 | infer 32.0 | to_cpu 0.7 | post 0.0 | masks 3 | triangles 0 => proc 32.7 ms
# [239/312] frame_00238.png  read 26.5 | infer 32.8 | to_cpu 0.8 | post 0.0 | masks 3 | triangles 0 => proc 33.5 ms
# [240/312] frame_00239.png  read 33.9 | infer 37.7 | to_cpu 0.8 | post 35.6 | masks 4 | triangles 1 => proc 74.1 ms
# [241/312] frame_00240.png  read 26.0 | infer 42.4 | to_cpu 0.9 | post 64.1 | masks 3 | triangles 1 => proc 107.4 ms
# [242/312] frame_00241.png  read 27.5 | infer 32.9 | to_cpu 0.8 | post 78.2 | masks 3 | triangles 1 => proc 111.9 ms
# [243/312] frame_00242.png  read 26.3 | infer 30.7 | to_cpu 0.8 | post 73.9 | masks 3 | triangles 1 => proc 105.4 ms
# [244/312] frame_00243.png  read 29.7 | infer 34.6 | to_cpu 0.8 | post 89.6 | masks 2 | triangles 1 => proc 125.0 ms
# [245/312] frame_00244.png  read 27.0 | infer 34.4 | to_cpu 0.7 | post 102.9 | masks 4 | triangles 3 => proc 138.1 ms
# [246/312] frame_00245.png  read 29.3 | infer 30.6 | to_cpu 0.5 | post 121.8 | masks 2 | triangles 2 => proc 152.9 ms
# [247/312] frame_00246.png  read 27.7 | infer 30.3 | to_cpu 0.7 | post 124.2 | masks 2 | triangles 2 => proc 155.2 ms
# [248/312] frame_00247.png  read 27.2 | infer 36.3 | to_cpu 0.7 | post 116.1 | masks 3 | triangles 2 => proc 153.2 ms
# [249/312] frame_00248.png  read 30.9 | infer 35.5 | to_cpu 0.8 | post 121.3 | masks 2 | triangles 2 => proc 157.7 ms
# [250/312] frame_00249.png  read 27.9 | infer 27.6 | to_cpu 0.6 | post 117.8 | masks 2 | triangles 2 => proc 146.0 ms
# [251/312] frame_00250.png  read 29.4 | infer 29.0 | to_cpu 0.6 | post 117.0 | masks 2 | triangles 2 => proc 146.6 ms
# [252/312] frame_00251.png  read 28.3 | infer 29.0 | to_cpu 0.8 | post 90.7 | masks 3 | triangles 1 => proc 120.5 ms
# [253/312] frame_00252.png  read 30.9 | infer 30.7 | to_cpu 0.7 | post 87.4 | masks 4 | triangles 1 => proc 118.8 ms
# [254/312] frame_00253.png  read 31.2 | infer 229.1 | to_cpu 0.7 | post 124.6 | masks 4 | triangles 1 => proc 354.4 ms
# [255/312] frame_00254.png  read 31.2 | infer 30.9 | to_cpu 0.8 | post 121.0 | masks 3 | triangles 2 => proc 152.6 ms
# [256/312] frame_00255.png  read 35.5 | infer 51.8 | to_cpu 0.7 | post 115.3 | masks 3 | triangles 2 => proc 167.8 ms
# [257/312] frame_00256.png  read 37.4 | infer 34.3 | to_cpu 1.6 | post 141.0 | masks 4 | triangles 2 => proc 177.0 ms
# [258/312] frame_00257.png  read 29.5 | infer 28.5 | to_cpu 0.7 | post 113.8 | masks 3 | triangles 2 => proc 143.0 ms
# [259/312] frame_00258.png  read 29.5 | infer 39.5 | to_cpu 0.9 | post 120.0 | masks 5 | triangles 2 => proc 160.3 ms
# [260/312] frame_00259.png  read 29.4 | infer 35.3 | to_cpu 0.8 | post 127.7 | masks 5 | triangles 2 => proc 163.8 ms
# [261/312] frame_00260.png  read 27.9 | infer 34.8 | to_cpu 0.9 | post 112.1 | masks 5 | triangles 2 => proc 147.7 ms
# [262/312] frame_00261.png  read 31.7 | infer 27.4 | to_cpu 0.7 | post 122.7 | masks 3 | triangles 2 => proc 150.9 ms
# [263/312] frame_00262.png  read 31.3 | infer 38.9 | to_cpu 1.6 | post 127.2 | masks 5 | triangles 2 => proc 167.7 ms
# [264/312] frame_00263.png  read 31.2 | infer 43.1 | to_cpu 0.9 | post 129.1 | masks 3 | triangles 2 => proc 173.1 ms
# [265/312] frame_00264.png  read 28.2 | infer 46.1 | to_cpu 2.7 | post 116.3 | masks 3 | triangles 2 => proc 165.2 ms
# [266/312] frame_00265.png  read 31.4 | infer 36.9 | to_cpu 5.0 | post 120.5 | masks 4 | triangles 2 => proc 162.4 ms
# [267/312] frame_00266.png  read 28.2 | infer 31.0 | to_cpu 0.7 | post 116.1 | masks 3 | triangles 2 => proc 147.8 ms
# [268/312] frame_00267.png  read 31.4 | infer 33.7 | to_cpu 0.9 | post 102.3 | masks 3 | triangles 2 => proc 136.9 ms
# [269/312] frame_00268.png  read 30.3 | infer 35.9 | to_cpu 0.6 | post 79.5 | masks 3 | triangles 1 => proc 116.0 ms
# [270/312] frame_00269.png  read 30.4 | infer 32.4 | to_cpu 0.9 | post 70.2 | masks 4 | triangles 1 => proc 103.5 ms
# [271/312] frame_00270.png  read 29.0 | infer 54.1 | to_cpu 0.7 | post 0.0 | masks 2 | triangles 0 => proc 54.7 ms
# [272/312] frame_00271.png  read 33.0 | infer 33.5 | to_cpu 0.9 | post 27.8 | masks 8 | triangles 1 => proc 62.2 ms
# [273/312] frame_00272.png  read 31.9 | infer 37.9 | to_cpu 2.0 | post 49.3 | masks 6 | triangles 2 => proc 89.1 ms
# [274/312] frame_00273.png  read 30.6 | infer 29.2 | to_cpu 1.0 | post 64.4 | masks 8 | triangles 2 => proc 94.7 ms
# [275/312] frame_00274.png  read 31.1 | infer 33.3 | to_cpu 0.8 | post 56.1 | masks 5 | triangles 2 => proc 90.1 ms
# [276/312] frame_00275.png  read 32.5 | infer 34.7 | to_cpu 1.1 | post 43.9 | masks 6 | triangles 1 => proc 79.6 ms
# [277/312] frame_00276.png  read 31.0 | infer 49.3 | to_cpu 2.5 | post 61.6 | masks 7 | triangles 2 => proc 113.4 ms
# [278/312] frame_00277.png  read 28.6 | infer 38.3 | to_cpu 1.0 | post 116.3 | masks 9 | triangles 2 => proc 155.5 ms
# [279/312] frame_00278.png  read 29.0 | infer 32.1 | to_cpu 0.9 | post 96.5 | masks 6 | triangles 2 => proc 129.4 ms
# [280/312] frame_00279.png  read 32.1 | infer 29.9 | to_cpu 0.8 | post 76.9 | masks 5 | triangles 2 => proc 107.6 ms
# [281/312] frame_00280.png  read 28.9 | infer 34.0 | to_cpu 0.8 | post 90.6 | masks 5 | triangles 1 => proc 125.4 ms
# [282/312] frame_00281.png  read 35.0 | infer 46.2 | to_cpu 1.0 | post 102.7 | masks 5 | triangles 2 => proc 149.8 ms
# [283/312] frame_00282.png  read 28.8 | infer 35.6 | to_cpu 0.7 | post 109.8 | masks 5 | triangles 2 => proc 146.2 ms
# [284/312] frame_00283.png  read 35.1 | infer 34.2 | to_cpu 0.8 | post 121.9 | masks 4 | triangles 2 => proc 156.8 ms
# [285/312] frame_00284.png  read 28.4 | infer 37.5 | to_cpu 0.8 | post 117.3 | masks 4 | triangles 2 => proc 155.6 ms
# [286/312] frame_00285.png  read 32.1 | infer 31.2 | to_cpu 0.7 | post 111.2 | masks 4 | triangles 2 => proc 143.1 ms
# [287/312] frame_00286.png  read 28.5 | infer 34.9 | to_cpu 0.8 | post 107.2 | masks 4 | triangles 2 => proc 142.9 ms
# [288/312] frame_00287.png  read 32.7 | infer 36.1 | to_cpu 0.6 | post 31.4 | masks 3 | triangles 1 => proc 68.2 ms
# [289/312] frame_00288.png  read 146.4 | infer 152.6 | to_cpu 1.0 | post 0.0 | masks 6 | triangles 0 => proc 153.5 ms
# [290/312] frame_00289.png  read 29.8 | infer 44.4 | to_cpu 1.2 | post 0.0 | masks 8 | triangles 0 => proc 45.6 ms
# [291/312] frame_00290.png  read 31.1 | infer 36.2 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 37.2 ms
# [292/312] frame_00291.png  read 32.5 | infer 35.7 | to_cpu 0.9 | post 0.0 | masks 7 | triangles 0 => proc 36.7 ms
# [293/312] frame_00292.png  read 31.7 | infer 41.3 | to_cpu 2.3 | post 0.0 | masks 7 | triangles 0 => proc 43.6 ms
# [294/312] frame_00293.png  read 32.6 | infer 35.8 | to_cpu 1.0 | post 0.0 | masks 7 | triangles 0 => proc 36.8 ms
# [295/312] frame_00294.png  read 33.1 | infer 42.5 | to_cpu 1.6 | post 0.0 | masks 8 | triangles 0 => proc 44.1 ms
# [296/312] frame_00295.png  read 32.3 | infer 37.0 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 38.1 ms
# [297/312] frame_00296.png  read 32.5 | infer 42.9 | to_cpu 1.1 | post 0.0 | masks 7 | triangles 0 => proc 44.0 ms
# [298/312] frame_00297.png  read 30.3 | infer 33.5 | to_cpu 1.0 | post 0.0 | masks 7 | triangles 0 => proc 34.5 ms
# [299/312] frame_00298.png  read 29.0 | infer 36.6 | to_cpu 3.4 | post 0.0 | masks 6 | triangles 0 => proc 39.9 ms
# [300/312] frame_00299.png  read 31.8 | infer 34.8 | to_cpu 0.8 | post 0.0 | masks 7 | triangles 0 => proc 35.6 ms
# [301/312] frame_00300.png  read 32.2 | infer 35.0 | to_cpu 1.0 | post 0.0 | masks 6 | triangles 0 => proc 36.0 ms
# [302/312] frame_00301.png  read 28.5 | infer 42.1 | to_cpu 1.7 | post 0.0 | masks 6 | triangles 0 => proc 43.8 ms
# [303/312] frame_00302.png  read 29.2 | infer 28.3 | to_cpu 0.8 | post 0.0 | masks 7 | triangles 0 => proc 29.0 ms
# [304/312] frame_00303.png  read 29.2 | infer 30.9 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 31.9 ms
# [305/312] frame_00304.png  read 28.4 | infer 30.5 | to_cpu 1.0 | post 0.0 | masks 8 | triangles 0 => proc 31.5 ms
# [306/312] frame_00305.png  read 29.0 | infer 30.2 | to_cpu 1.1 | post 0.0 | masks 8 | triangles 0 => proc 31.3 ms
# [307/312] frame_00306.png  read 29.4 | infer 34.0 | to_cpu 0.8 | post 0.0 | masks 7 | triangles 0 => proc 34.8 ms
# [308/312] frame_00307.png  read 14.1 | infer 20.6 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 20.6 ms
# [309/312] frame_00308.png  read 13.8 | infer 19.2 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 19.2 ms
# [310/312] frame_00309.png  read 13.7 | infer 20.6 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 20.6 ms
# [311/312] frame_00310.png  read 13.3 | infer 19.8 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 19.8 ms
# [312/312] frame_00311.png  read 13.6 | infer 20.9 | to_cpu 0.0 | post 0.0 | masks 0 | triangles 0 => proc 20.9 ms
